# %%
# ===========================
# Cell 0 — Config
# ===========================
DATA_ID = 'mackey_glass_tau30_n200'   # your dataset folder name

# Noise used in training & scoring
EVAL_SIGMA   = 0.20

# Windowing (must match qubit count for our QAE)
wind_size    = 4      # == n_qubits
wind_step    = 2

# Train/Test split on windows produced from the full series
split        = 0.75   # first 75% windows → train, last 25% → test

# Runs
INSTANCE_IDS = [1, 2, 3, 4, 5]
LAYER_OPTIONS = [1, 3]  # Stage-1/3 depth options

# Reset implementation for Stage-3:
#   'Jacob' → qml.measure(w, reset=True)  (keeps same wire count)
#   'swap'    → unitary SWAP to ancillas in |0>            (adds n_trash ancillas; enables adjoint on lightning)
RESET_MODE = 'swap'   # ← default approach

# Backends to use (you can keep both lightning; 'measure' may fall back from adjoint automatically)
STAGE1_BACKEND = 'lightning.qubit'
STAGE3_BACKEND = 'lightning.qubit'

# Logging
LOG_NAME = 'aintern'
CASE_NAME = 'half_qae'
DATA_PATH = f'{LOG_NAME}/data'
FIGURES_PATH = f'{LOG_NAME}/figures'
TRAIN_PATH = f'{LOG_NAME}/training'
PARAMS_PATH = f'{LOG_NAME}/params'
ANALYSIS_PATH = f'{LOG_NAME}/analysis'

# %%
# ===========================
# Cell 1 — Imports & utils
# ===========================
import os, sys, time, math, random, json
from pathlib import Path
import numpy as np
import pennylane as qml
from pennylane import numpy as pnp
import matplotlib.pyplot as plt

# repo utils
sys.path.append('.'); sys.path.append('..')
from qae_utils.Files import create_folder_if_needed, read_json_file, read_ts_file
from qae_utils.Window import ts_wind_make, ts_wind_split, ts_wind_flatten_avg
from qae_utils.Window import ts_add_noise
from qae_utils.Charts import multi_plot_flat_ts

# folders
for p in [FIGURES_PATH, TRAIN_PATH, PARAMS_PATH, ANALYSIS_PATH]:
    create_folder_if_needed(p)

# plotting
np.set_printoptions(suppress=True, precision=6)
plt.rcParams["figure.figsize"] = (6.5, 4)

def set_global_seed(instance_id: int):
    base = 10_000 + int(instance_id)
    random.seed(base + 11)
    np.random.seed(base + 22)
    try:
        pnp.random.seed(base + 33)
    except Exception:
        pass
    return dict(global_seed=base, numpy_seed=base+22, pnp_seed=base+33)

# %%
# ===========================
# Cell 2 — Load data & embed (robust paths)
# ===========================
import os

# keep your DATA_ID, LOG_NAME, DATA_PATH from Cell 0
# this resolver tries several roots so relative paths won't break
def _find_data_folder(data_id, log_name='aintern', preferred_root=None):
    candidates = []
    if preferred_root:
        candidates.append(preferred_root)
    # common locations
    candidates += [
        f'./{log_name}/data',
        f'../{log_name}/data',
        f'../../{log_name}/data',
        './jacobs_examples/aintern/data',
        '../jacobs_examples/aintern/data',
        '../../jacobs_examples/aintern/data',
    ]
    tried = []
    for root in candidates:
        folder = os.path.join(root, data_id)
        info_p = os.path.join(folder, 'info.json')
        x_p    = os.path.join(folder, 'x_org.arr')
        y_p    = os.path.join(folder, 'y_org.arr')
        tried.append(folder)
        if os.path.isdir(folder) and all(os.path.exists(p) for p in (info_p, x_p, y_p)):
            return folder
    raise FileNotFoundError(
        "Could not find dataset folder with required files.\n"
        f"DATA_ID='{data_id}'. Tried:\n - " + "\n - ".join(tried)
    )

# resolve the folder (uses your DATA_PATH from Cell 0 as a preference)
try:
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=DATA_PATH)
except Exception as e:
    # last resort: try without preferred_root
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=None)

data_info_path = f'{DATA_FOLDER}/info.json'
x_org_path     = f'{DATA_FOLDER}/x_org.arr'
y_org_path     = f'{DATA_FOLDER}/y_org.arr'

info = read_json_file(data_info_path)
X = read_ts_file(x_org_path).astype(int)  # indices (for plotting only)
y = read_ts_file(y_org_path)              # values (original domain)

scale_low  = float(info['scale_low'])
scale_high = float(info['scale_high'])
print(f'Using data folder: {DATA_FOLDER}')
print(f'Loaded {len(y)} samples; scale = [{scale_low:.3f}, {scale_high:.3f}]')

# quick plot (optional)
multi_plot_flat_ts([y], X_list=[0], colors=['blue'], labels=['Original'],
                   lines=['solid'], legend_cols=1, rcParams=(8, 3),
                   xlabel=f'Range (samples={len(y)})',
                   title=f'Data for model training (data=\"{DATA_ID}\")')

def embed_input(x, info_=None):
    """Map window values to RY(π·v01) with v01 from [scale_low, scale_high] → [0,1]."""
    if info_ is None: info_ = info
    lo, hi = float(info_['scale_low']), float(info_['scale_high'])
    xn = (pnp.array(x) - lo) / max(hi - lo, 1e-12)
    for i, v in enumerate(xn):
        qml.RY(v * pnp.pi, wires=i)
# Out:
# Using data folder: ../jacobs_examples/aintern/data/mackey_glass_tau30_n200
# Loaded 200 samples; scale = [0.200, 0.800]

# %%
# ===========================
# Cell 3 — Architecture (4q, 3 latent, 1 trash)
# ===========================
n_qubits = wind_size      # must equal window size
n_latent = 3
n_trash  = n_qubits - n_latent
trash_wires  = list(range(n_latent, n_qubits))  # [3] for 4q
signal_wires = list(range(n_qubits))            # diagnostics / full outputs

def make_device(nwires, backend='lightning.qubit'):
    return qml.device(backend, wires=nwires, shots=None)

def encoder_template(params, n_layers):
    """RX/RY/RZ per qubit + ring CNOT per layer."""
    assert len(params) == n_layers * n_qubits * 3
    for l in range(n_layers):
        for q in range(n_qubits):
            idx = l * n_qubits * 3 + q * 3
            qml.RX(params[idx + 0], wires=q)
            qml.RY(params[idx + 1], wires=q)
            qml.RZ(params[idx + 2], wires=q)
        for q in range(n_qubits - 1):
            qml.CNOT(wires=[q, q + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])

print(f"Architecture set: {n_qubits}q ({n_latent} latent, {n_trash} trash).")
# Out:
# Architecture set: 4q (3 latent, 1 trash).

# %%
# ===========================
# Cell 4 — Stage-1 training
# ===========================
def stage1_qnodes(n_layers):
    dev = make_device(n_qubits, backend=STAGE1_BACKEND)

    @qml.qnode(dev, interface="autograd", diff_method="adjoint")
    def trash_expectations(phi, x_clean):
        embed_input(x_clean)
        encoder_template(phi, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in trash_wires]

    return trash_expectations

def stage1_loss_on_windows(trash_expect, phi, windows_clean):
    # P(|1>) = (1 - Z)/2 on trash wires
    total = pnp.array(0.0)
    for w in windows_clean:
        z = pnp.array(trash_expect(phi, w))
        total = total + pnp.mean((1.0 - z) * 0.5)
    return total / max(len(windows_clean), 1)

def train_stage1_clean(windows_train_clean, n_layers, instance_id,
                       n_epochs=120, lr_init=0.010, patience=10, lr_patience=8):
    set_global_seed(instance_id)
    enc_shape = n_layers * n_qubits * 3
    phi = pnp.array(np.random.normal(0, 0.5, enc_shape), requires_grad=True)
    opt = qml.AdamOptimizer(stepsize=lr_init)
    lr = lr_init

    trash_expect = stage1_qnodes(n_layers)
    best_phi, best_cost = None, float("inf")
    no_improve = 0

    for ep in range(n_epochs):
        loss_fn = lambda p: stage1_loss_on_windows(trash_expect, p, windows_train_clean)
        phi, cost = opt.step_and_cost(loss_fn, phi)

        if cost < best_cost - 1e-9:
            best_cost, best_phi, no_improve = float(cost), pnp.array(phi, requires_grad=False), 0
        else:
            no_improve += 1
            if (no_improve % lr_patience) == 0:
                lr = max(lr * 0.5, 1e-4)
                opt = qml.AdamOptimizer(stepsize=lr)
                print(f"[Stage1] ↓ LR → {lr:.5f}")
            if no_improve >= patience:
                print("[Stage1] Early stopping."); break

        if ep % 5 == 0 or ep == n_epochs-1:
            print(f"[Stage1] L={n_layers} ep {ep:03d} | train {float(cost):.6f} | LR {lr:.5f}")

    return dict(phi=(best_phi if best_phi is not None else phi),
                best_train=float(best_cost))

# %%
# ===========================
# Cell 5 — Stage-3 QNodes
# ===========================
def stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET_MODE):

    need_anc = n_trash if (reset_mode == "swap" and n_trash > 0) else 0
    dev3 = make_device(n_qubits + need_anc)
    ancilla_wires = list(range(n_qubits, n_qubits + need_anc))

    theta_fixed = pnp.array(phi_stage1, requires_grad=False).reshape((n_layers, n_qubits, 3))

    def encoder_fixed_body(theta):
        for l in range(n_layers):
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=q)
                qml.RY(theta[l, q, 1], wires=q)
                qml.RZ(theta[l, q, 2], wires=q)
            for q in range(n_qubits-1):
                qml.CNOT(wires=[q, q+1])
            qml.CNOT(wires=[n_qubits-1, 0])

    def decoder_fixed():
        qml.adjoint(encoder_fixed_body)(theta_fixed)

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def encoder_only_expZ_all(flat_params, x_in):
        embed_input(x_in)
        encoder_template(flat_params, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def teacher_code_latents(x_clean):
        embed_input(x_clean)
        encoder_fixed_body(theta_fixed)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_latent)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def denoiser_qnode_all(flat_params, x_noisy):
        embed_input(x_noisy)
        encoder_template(flat_params, n_layers)

        # --- reset trash ---
        if n_trash > 0:
            if reset_mode == "Jacob":
                for w in trash_wires:
                    qml.measure(w, reset=True)
            elif reset_mode == "swap":
                # one clean ancilla per trash wire
                for t, a in zip(trash_wires, ancilla_wires):
                    # ancillas start in |0>, so SWAP puts |0> into trash, old trash into ancilla
                    qml.SWAP(wires=[t, a])

        decoder_fixed()
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    return dict(
        theta_fixed=theta_fixed,
        ancilla_wires=ancilla_wires,
        encoder_only_expZ_all=encoder_only_expZ_all,
        teacher_code_latents=teacher_code_latents,
        denoiser_qnode_all=denoiser_qnode_all
    )

def Z_to_values_autograd(z_all):
    z_all = pnp.clip(pnp.asarray(z_all), -0.999999, 0.999999)
    v01   = pnp.arccos(z_all) / pnp.pi
    return v01 * (scale_high - scale_low) + scale_low

def first_diff(x):
    x = pnp.array(x); return x[1:] - x[:-1]

def p1_from_expZ(z):
    return (1 - pnp.asarray(z)) * 0.5

def huber(residual, delta):
    r = pnp.abs(residual)
    return pnp.where(r <= delta, 0.5*r**2, delta*(r - 0.5*delta))

# %%
# ===========================
# Cell 6 — Noise & scoring helpers
# ===========================
def make_windows_from_series(y_vec, noise_sigma, seed, wind_size, wind_step):
    """
    Inject one noise vector into the whole series,
    then windowize both clean and noisy series the same way.
    """
    y_noisy = ts_add_noise(y_vec, noise=noise_sigma, noise_type='normal', clip=False,
                           range_low=scale_low, range_high=scale_high, seed=seed)

    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)

    # windows index array (not used by model, only for split helper)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])

    # split consistently
    X_tr, y_tr_clean, X_te, y_te_clean = ts_wind_split(X_ts, win_clean, split)
    X_tr, y_tr_noisy, X_te, y_te_noisy = ts_wind_split(X_ts, win_noisy, split)

    return (y_tr_clean, y_tr_noisy, y_te_clean, y_te_noisy)

def denoise_windows(params, denoise_qnode, windows_noisy):
    outs = []
    for w in windows_noisy:
        zD = pnp.array(denoise_qnode(params, w))
        outs.append(pnp.array(Z_to_values_autograd(zD)))
    return pnp.stack(outs)

def mse_on_windows(w_true, w_pred):
    w_true = np.asarray(w_true); w_pred = np.asarray(w_pred)
    return float(np.mean((w_true - w_pred)**2))

def mse_on_series_avg(w_true, w_pred, step):
    flat_true = ts_wind_flatten_avg(np.asarray(w_true), step)
    flat_pred = ts_wind_flatten_avg(np.asarray(w_pred), step)
    return float(np.mean((flat_true - flat_pred)**2))

# %%
# ===========================
# Cell 7 — Stage-3 (simple, fixed test seed, mini-batch)
# ===========================
def _series_to_train_test_windows(y_vec, sigma, seed):
    """Noise once → windowize → train/test split."""
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return np.asarray(tr_clean), np.asarray(tr_noisy), np.asarray(te_clean), np.asarray(te_noisy)

def _win_mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b)**2))

def _ser_mse(a, b):
    a = ts_wind_flatten_avg(np.asarray(a), wind_step)
    b = ts_wind_flatten_avg(np.asarray(b), wind_step)
    return float(np.mean((a - b)**2))

def train_stage3_series_noise_simple(
    y_full, phi_stage1, n_layers, instance_id,
    EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001, CLIP_NORM=1.0,
    USE_EMA=True, EMA_DECAY=0.995,
    TRAIN_SEED_BASE=88000, TEST_SEED_FIXED=99123,
    RESET=RESET_MODE,        # ← pass through
    BETA_TF=0.05,            # latent tug weight (teacher forcing)
    L_TV=0.02                # temporal smoothness weight
):
    set_global_seed(instance_id)
    handles = stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET)
    enc_all   = handles["encoder_only_expZ_all"]
    teacher_l = handles["teacher_code_latents"]
    denoise   = handles["denoiser_qnode_all"]

    # init ψ near φ
    phi_flat = pnp.array(phi_stage1, requires_grad=False)
    psi = pnp.array(np.array(phi_flat) + 0.05*np.random.randn(len(phi_flat)), requires_grad=True)

    opt = qml.AdamOptimizer(stepsize=LR)
    ema = pnp.array(psi, requires_grad=False) if USE_EMA else None

    hist_train_win_mse, hist_test_win_mse = [], []
    hist_train_ser_mse, hist_test_ser_mse = [], []

    def loss_on_batch(params, batch_clean, batch_noisy):
        total = pnp.array(0.0)
        for c, n in zip(batch_clean, batch_noisy):
            z_all = pnp.array(enc_all(params, n))
            z_sig, z_tr = z_all[:n_latent], z_all[n_latent:]
            zD   = pnp.array(denoise(params, n))
            vhat = Z_to_values_autograd(zD)

            L_rec = pnp.mean((pnp.array(c) - vhat)**2)
            L_tf  = pnp.mean(huber(pnp.array(teacher_l(c)) - z_sig, 0.25))
            L_tr  = pnp.mean(p1_from_expZ(z_tr))
            L_tv  = pnp.mean(huber(first_diff(c) - first_diff(vhat), 0.02))

            total = total + (L_rec + BETA_TF*L_tf + 0.5*L_tr + L_TV*L_tv)
        return total / max(len(batch_clean), 1)

    for ep in range(EPOCHS):
        # epoch-specific train noise
        tr_clean, tr_noisy, _, _ = make_windows_from_series(
            y_full, EVAL_SIGMA, TRAIN_SEED_BASE + ep, wind_size, wind_step
        )
        # fixed test noise
        _, _, te_clean, te_noisy = make_windows_from_series(
            y_full, EVAL_SIGMA, TEST_SEED_FIXED, wind_size, wind_step
        )

        # inner SGD steps with mini-batches
        for _ in range(INNER_STEPS):
            idx = np.random.randint(0, len(tr_clean), size=min(BATCH_SIZE, len(tr_clean)))
            batch_c = [tr_clean[i] for i in idx]
            batch_n = [tr_noisy[i] for i in idx]
            psi, _ = opt.step_and_cost(lambda p: loss_on_batch(p, batch_c, batch_n), psi)
            if USE_EMA:
                ema = EMA_DECAY * ema + (1 - EMA_DECAY) * psi

        eval_params = ema if USE_EMA else psi

        # ---- metrics
        tr_pred = denoise_windows(eval_params, denoise, tr_noisy)
        te_pred = denoise_windows(eval_params, denoise, te_noisy)

        train_mse_win = mse_on_windows(tr_clean, tr_pred)
        test_mse_win  = mse_on_windows(te_clean, te_pred)
        train_mse_ser = mse_on_series_avg(tr_clean, tr_pred, wind_step)
        test_mse_ser  = mse_on_series_avg(te_clean, te_pred, wind_step)

        hist_train_win_mse.append(float(train_mse_win))
        hist_test_win_mse.append(float(test_mse_win))
        hist_train_ser_mse.append(float(train_mse_ser))
        hist_test_ser_mse.append(float(test_mse_ser))

        print(f"[Stage3] L={n_layers} ep {ep:03d} | "
              f"train MSE(win) {train_mse_win:.5f} | "
              f"test MSE(win) {test_mse_win:.5f} | "
              f"test MSE(series) {test_mse_ser:.5f}")

    return dict(
        psi=(ema if USE_EMA else psi),
        hist_train_win_mse=hist_train_win_mse,
        hist_test_win_mse=hist_test_win_mse,
        hist_train_ser_mse=hist_train_ser_mse,
        hist_test_ser_mse=hist_test_ser_mse,
        TEST_SEED_FIXED=int(TEST_SEED_FIXED),
        RESET_MODE=str(RESET),
    )

# %%
# ===========================
# Cell 8 — Runs (instances × layers)
# ===========================
ALL_RUNS = []

for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        print("\n" + "="*30)
        print(f"Instance {inst} | Layers {L}")
        print("="*30)
        set_global_seed(inst)

        # ---- CLEAN windows once (for Stage-1 only)
        clean_windows = ts_wind_make(y, wind_size, wind_step)
        X_ts = np.array([i*wind_step for i in range(len(clean_windows))])
        _, win_tr_clean, _, win_te_clean = ts_wind_split(X_ts, clean_windows, split)
        print(f"[Windows] train={len(win_tr_clean)}, test={len(win_te_clean)} (W={wind_size}, step={wind_step})")

        # ---- Stage 1
        s1 = train_stage1_clean(
            win_tr_clean, n_layers=L, instance_id=inst,
            n_epochs=150, lr_init=0.010, patience=10, lr_patience=8
        )
        phi = s1["phi"]
        print(f"[Stage1] best train cost = {s1['best_train']:.6f}")

        # ---- Stage 3 (mentor-style reset by default)
        s3 = train_stage3_series_noise_simple(
                y_full=y, phi_stage1=phi, n_layers=L, instance_id=inst,
                EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001,
                RESET=RESET_MODE, BETA_TF=0.05, L_TV=0.02
        )

        # Final fixed-seed scoring (aligns with logs)
        seed_fix = s3.get("TEST_SEED_FIXED", 99123)
        trC, trN, teC, teN = _series_to_train_test_windows(y, EVAL_SIGMA, seed_fix)
        denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
        te_pred = denoise_windows(s3["psi"], denoise, teN)

        final_win = _win_mse(teC, te_pred)
        base_win  = _win_mse(teC, teN)
        final_ser = _ser_mse(teC, te_pred)
        base_ser  = _ser_mse(teC, teN)
        print(f"[Final TEST] MSE(win) {final_win:.6f} vs noisy {base_win:.6f} → Δ {100*(1-final_win/max(base_win,1e-12)):+.1f}%")
        print(f"[Final TEST] MSE(series) {final_ser:.6f} vs noisy {base_ser:.6f} → Δ {100*(1-final_ser/max(base_ser,1e-12)):+.1f}%")

        ALL_RUNS.append(dict(
            instance_id=inst, n_layers=L,
            stage1=dict(best_train=s1["best_train"], phi=np.array(phi)),
            stage3=dict(**s3)
        ))

print("\nCompleted", len(ALL_RUNS), "runs.")
# Out:
# ==============================
# Instance 1 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.484923 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.476481 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.468580 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.461630 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.455960 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.451638 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.448435 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.445899 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.443565 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.441087 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.438251 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.434921 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.430976 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.426283 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.420712 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.414194 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.406754 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.398516 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.389698 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.380598 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.371548 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.362870 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.354828 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.347594 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.341248 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.335798 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.331213 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.327432 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.324378 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.321966 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.320434 | LR 0.01000
# [Stage1] best train cost = 0.320434
# [Stage3] L=1 ep 000 | train MSE(win) 0.01964 | test MSE(win) 0.01809 | test MSE(series) 0.01718
# [Stage3] L=1 ep 001 | train MSE(win) 0.02046 | test MSE(win) 0.01809 | test MSE(series) 0.01718
# [Stage3] L=1 ep 002 | train MSE(win) 0.01965 | test MSE(win) 0.01809 | test MSE(series) 0.01718
# [Stage3] L=1 ep 003 | train MSE(win) 0.02005 | test MSE(win) 0.01809 | test MSE(series) 0.01719
# [Stage3] L=1 ep 004 | train MSE(win) 0.01884 | test MSE(win) 0.01810 | test MSE(series) 0.01719
# [Stage3] L=1 ep 005 | train MSE(win) 0.01994 | test MSE(win) 0.01810 | test MSE(series) 0.01719
# [Stage3] L=1 ep 006 | train MSE(win) 0.02146 | test MSE(win) 0.01810 | test MSE(series) 0.01719
# [Stage3] L=1 ep 007 | train MSE(win) 0.01927 | test MSE(win) 0.01810 | test MSE(series) 0.01719
# [Stage3] L=1 ep 008 | train MSE(win) 0.02051 | test MSE(win) 0.01810 | test MSE(series) 0.01720
# [Stage3] L=1 ep 009 | train MSE(win) 0.01942 | test MSE(win) 0.01811 | test MSE(series) 0.01720
# [Stage3] L=1 ep 010 | train MSE(win) 0.01999 | test MSE(win) 0.01811 | test MSE(series) 0.01720
# [Stage3] L=1 ep 011 | train MSE(win) 0.01973 | test MSE(win) 0.01811 | test MSE(series) 0.01720
# [Stage3] L=1 ep 012 | train MSE(win) 0.01941 | test MSE(win) 0.01812 | test MSE(series) 0.01721
# [Stage3] L=1 ep 013 | train MSE(win) 0.01980 | test MSE(win) 0.01812 | test MSE(series) 0.01721
# [Stage3] L=1 ep 014 | train MSE(win) 0.02019 | test MSE(win) 0.01812 | test MSE(series) 0.01721
# [Stage3] L=1 ep 015 | train MSE(win) 0.01991 | test MSE(win) 0.01812 | test MSE(series) 0.01722
# [Stage3] L=1 ep 016 | train MSE(win) 0.01890 | test MSE(win) 0.01813 | test MSE(series) 0.01722
# [Stage3] L=1 ep 017 | train MSE(win) 0.02079 | test MSE(win) 0.01813 | test MSE(series) 0.01722
# [Stage3] L=1 ep 018 | train MSE(win) 0.01960 | test MSE(win) 0.01813 | test MSE(series) 0.01722
# [Stage3] L=1 ep 019 | train MSE(win) 0.02109 | test MSE(win) 0.01813 | test MSE(series) 0.01722
# [Stage3] L=1 ep 020 | train MSE(win) 0.01859 | test MSE(win) 0.01813 | test MSE(series) 0.01722
# [Stage3] L=1 ep 021 | train MSE(win) 0.02110 | test MSE(win) 0.01813 | test MSE(series) 0.01723
# [Stage3] L=1 ep 022 | train MSE(win) 0.02085 | test MSE(win) 0.01814 | test MSE(series) 0.01723
# [Stage3] L=1 ep 023 | train MSE(win) 0.01980 | test MSE(win) 0.01814 | test MSE(series) 0.01723
# [Final TEST] MSE(win) 0.018135 vs noisy 0.019387 → Δ +6.5%
# [Final TEST] MSE(series) 0.017225 vs noisy 0.018958 → Δ +9.1%
#
# ==============================
# Instance 2 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.493463 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.486712 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.480022 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.473557 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.467541 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.462156 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.457490 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.453598 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.450452 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.447916 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.445775 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.443810 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.441834 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.439726 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.437433 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.434958 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.432325 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.429561 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.426679 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.423686 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.420578 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.417353 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.414006 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.410522 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.406878 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.403036 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.398955 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.394588 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.389893 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.384835 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.380518 | LR 0.01000
# [Stage1] best train cost = 0.380518
# [Stage3] L=1 ep 000 | train MSE(win) 0.02523 | test MSE(win) 0.02314 | test MSE(series) 0.02231
# [Stage3] L=1 ep 001 | train MSE(win) 0.02492 | test MSE(win) 0.02314 | test MSE(series) 0.02231
# [Stage3] L=1 ep 002 | train MSE(win) 0.02522 | test MSE(win) 0.02314 | test MSE(series) 0.02231
# [Stage3] L=1 ep 003 | train MSE(win) 0.02512 | test MSE(win) 0.02314 | test MSE(series) 0.02231
# [Stage3] L=1 ep 004 | train MSE(win) 0.02498 | test MSE(win) 0.02315 | test MSE(series) 0.02231
# [Stage3] L=1 ep 005 | train MSE(win) 0.02463 | test MSE(win) 0.02315 | test MSE(series) 0.02232
# [Stage3] L=1 ep 006 | train MSE(win) 0.02421 | test MSE(win) 0.02315 | test MSE(series) 0.02232
# [Stage3] L=1 ep 007 | train MSE(win) 0.02505 | test MSE(win) 0.02315 | test MSE(series) 0.02232
# [Stage3] L=1 ep 008 | train MSE(win) 0.02438 | test MSE(win) 0.02316 | test MSE(series) 0.02233
# [Stage3] L=1 ep 009 | train MSE(win) 0.02602 | test MSE(win) 0.02316 | test MSE(series) 0.02233
# [Stage3] L=1 ep 010 | train MSE(win) 0.02510 | test MSE(win) 0.02316 | test MSE(series) 0.02233
# [Stage3] L=1 ep 011 | train MSE(win) 0.02495 | test MSE(win) 0.02317 | test MSE(series) 0.02234
# [Stage3] L=1 ep 012 | train MSE(win) 0.02476 | test MSE(win) 0.02317 | test MSE(series) 0.02234
# [Stage3] L=1 ep 013 | train MSE(win) 0.02454 | test MSE(win) 0.02318 | test MSE(series) 0.02235
# [Stage3] L=1 ep 014 | train MSE(win) 0.02450 | test MSE(win) 0.02318 | test MSE(series) 0.02235
# [Stage3] L=1 ep 015 | train MSE(win) 0.02464 | test MSE(win) 0.02319 | test MSE(series) 0.02236
# [Stage3] L=1 ep 016 | train MSE(win) 0.02448 | test MSE(win) 0.02319 | test MSE(series) 0.02236
# [Stage3] L=1 ep 017 | train MSE(win) 0.02493 | test MSE(win) 0.02319 | test MSE(series) 0.02236
# [Stage3] L=1 ep 018 | train MSE(win) 0.02515 | test MSE(win) 0.02320 | test MSE(series) 0.02237
# [Stage3] L=1 ep 019 | train MSE(win) 0.02461 | test MSE(win) 0.02320 | test MSE(series) 0.02237
# [Stage3] L=1 ep 020 | train MSE(win) 0.02514 | test MSE(win) 0.02321 | test MSE(series) 0.02238
# [Stage3] L=1 ep 021 | train MSE(win) 0.02456 | test MSE(win) 0.02321 | test MSE(series) 0.02239
# [Stage3] L=1 ep 022 | train MSE(win) 0.02537 | test MSE(win) 0.02322 | test MSE(series) 0.02239
# [Stage3] L=1 ep 023 | train MSE(win) 0.02420 | test MSE(win) 0.02323 | test MSE(series) 0.02240
# [Final TEST] MSE(win) 0.023226 vs noisy 0.019387 → Δ -19.8%
# [Final TEST] MSE(series) 0.022397 vs noisy 0.018958 → Δ -18.1%
#
# ==============================
# Instance 3 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.487375 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.483551 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.480119 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.476714 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.472155 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.465579 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.456732 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.445757 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.433155 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.419717 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.406350 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.393834 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.382622 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.372870 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.364614 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.357795 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.352211 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.347569 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.343577 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.340022 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.336772 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.333746 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.330887 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.328176 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.325650 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.323381 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.321425 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.319798 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.318491 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.317493 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.316902 | LR 0.01000
# [Stage1] best train cost = 0.316902
# [Stage3] L=1 ep 000 | train MSE(win) 0.02115 | test MSE(win) 0.02084 | test MSE(series) 0.02009
# [Stage3] L=1 ep 001 | train MSE(win) 0.02213 | test MSE(win) 0.02084 | test MSE(series) 0.02009
# [Stage3] L=1 ep 002 | train MSE(win) 0.02125 | test MSE(win) 0.02084 | test MSE(series) 0.02009
# [Stage3] L=1 ep 003 | train MSE(win) 0.02173 | test MSE(win) 0.02084 | test MSE(series) 0.02008
# [Stage3] L=1 ep 004 | train MSE(win) 0.02053 | test MSE(win) 0.02083 | test MSE(series) 0.02008
# [Stage3] L=1 ep 005 | train MSE(win) 0.02192 | test MSE(win) 0.02083 | test MSE(series) 0.02008
# [Stage3] L=1 ep 006 | train MSE(win) 0.02322 | test MSE(win) 0.02082 | test MSE(series) 0.02007
# [Stage3] L=1 ep 007 | train MSE(win) 0.02100 | test MSE(win) 0.02082 | test MSE(series) 0.02007
# [Stage3] L=1 ep 008 | train MSE(win) 0.02239 | test MSE(win) 0.02081 | test MSE(series) 0.02006
# [Stage3] L=1 ep 009 | train MSE(win) 0.02060 | test MSE(win) 0.02081 | test MSE(series) 0.02005
# [Stage3] L=1 ep 010 | train MSE(win) 0.02177 | test MSE(win) 0.02080 | test MSE(series) 0.02005
# [Stage3] L=1 ep 011 | train MSE(win) 0.02166 | test MSE(win) 0.02079 | test MSE(series) 0.02004
# [Stage3] L=1 ep 012 | train MSE(win) 0.02136 | test MSE(win) 0.02079 | test MSE(series) 0.02004
# [Stage3] L=1 ep 013 | train MSE(win) 0.02159 | test MSE(win) 0.02078 | test MSE(series) 0.02003
# [Stage3] L=1 ep 014 | train MSE(win) 0.02231 | test MSE(win) 0.02078 | test MSE(series) 0.02002
# [Stage3] L=1 ep 015 | train MSE(win) 0.02161 | test MSE(win) 0.02077 | test MSE(series) 0.02002
# [Stage3] L=1 ep 016 | train MSE(win) 0.02109 | test MSE(win) 0.02076 | test MSE(series) 0.02001
# [Stage3] L=1 ep 017 | train MSE(win) 0.02237 | test MSE(win) 0.02076 | test MSE(series) 0.02000
# [Stage3] L=1 ep 018 | train MSE(win) 0.02158 | test MSE(win) 0.02075 | test MSE(series) 0.02000
# [Stage3] L=1 ep 019 | train MSE(win) 0.02282 | test MSE(win) 0.02074 | test MSE(series) 0.01999
# [Stage3] L=1 ep 020 | train MSE(win) 0.02030 | test MSE(win) 0.02073 | test MSE(series) 0.01998
# [Stage3] L=1 ep 021 | train MSE(win) 0.02263 | test MSE(win) 0.02073 | test MSE(series) 0.01997
# [Stage3] L=1 ep 022 | train MSE(win) 0.02213 | test MSE(win) 0.02072 | test MSE(series) 0.01997
# [Stage3] L=1 ep 023 | train MSE(win) 0.02183 | test MSE(win) 0.02071 | test MSE(series) 0.01996
# [Final TEST] MSE(win) 0.020709 vs noisy 0.019387 → Δ -6.8%
# [Final TEST] MSE(series) 0.019957 vs noisy 0.018958 → Δ -5.3%
#
# ==============================
# Instance 4 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.507599 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.499606 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.492089 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.484860 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.478078 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.471947 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.466483 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.461624 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.457308 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.453446 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.449909 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.446550 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.443245 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.439894 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.436388 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.432590 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.428348 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.423502 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.417917 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.411514 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.404314 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.396452 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.388171 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.379775 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.371570 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.363809 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.356660 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.350209 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.344478 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.339438 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.335868 | LR 0.01000
# [Stage1] best train cost = 0.335868
# [Stage3] L=1 ep 000 | train MSE(win) 0.02259 | test MSE(win) 0.02307 | test MSE(series) 0.02240
# [Stage3] L=1 ep 001 | train MSE(win) 0.02349 | test MSE(win) 0.02307 | test MSE(series) 0.02240
# [Stage3] L=1 ep 002 | train MSE(win) 0.02301 | test MSE(win) 0.02307 | test MSE(series) 0.02240
# [Stage3] L=1 ep 003 | train MSE(win) 0.02293 | test MSE(win) 0.02307 | test MSE(series) 0.02240
# [Stage3] L=1 ep 004 | train MSE(win) 0.02233 | test MSE(win) 0.02306 | test MSE(series) 0.02240
# [Stage3] L=1 ep 005 | train MSE(win) 0.02350 | test MSE(win) 0.02306 | test MSE(series) 0.02240
# [Stage3] L=1 ep 006 | train MSE(win) 0.02422 | test MSE(win) 0.02306 | test MSE(series) 0.02239
# [Stage3] L=1 ep 007 | train MSE(win) 0.02286 | test MSE(win) 0.02305 | test MSE(series) 0.02239
# [Stage3] L=1 ep 008 | train MSE(win) 0.02338 | test MSE(win) 0.02305 | test MSE(series) 0.02239
# [Stage3] L=1 ep 009 | train MSE(win) 0.02190 | test MSE(win) 0.02305 | test MSE(series) 0.02238
# [Stage3] L=1 ep 010 | train MSE(win) 0.02327 | test MSE(win) 0.02304 | test MSE(series) 0.02238
# [Stage3] L=1 ep 011 | train MSE(win) 0.02311 | test MSE(win) 0.02304 | test MSE(series) 0.02238
# [Stage3] L=1 ep 012 | train MSE(win) 0.02327 | test MSE(win) 0.02303 | test MSE(series) 0.02237
# [Stage3] L=1 ep 013 | train MSE(win) 0.02333 | test MSE(win) 0.02303 | test MSE(series) 0.02237
# [Stage3] L=1 ep 014 | train MSE(win) 0.02360 | test MSE(win) 0.02303 | test MSE(series) 0.02236
# [Stage3] L=1 ep 015 | train MSE(win) 0.02318 | test MSE(win) 0.02302 | test MSE(series) 0.02236
# [Stage3] L=1 ep 016 | train MSE(win) 0.02294 | test MSE(win) 0.02302 | test MSE(series) 0.02236
# [Stage3] L=1 ep 017 | train MSE(win) 0.02349 | test MSE(win) 0.02302 | test MSE(series) 0.02235
# [Stage3] L=1 ep 018 | train MSE(win) 0.02311 | test MSE(win) 0.02301 | test MSE(series) 0.02235
# [Stage3] L=1 ep 019 | train MSE(win) 0.02396 | test MSE(win) 0.02301 | test MSE(series) 0.02235
# [Stage3] L=1 ep 020 | train MSE(win) 0.02235 | test MSE(win) 0.02301 | test MSE(series) 0.02234
# [Stage3] L=1 ep 021 | train MSE(win) 0.02352 | test MSE(win) 0.02300 | test MSE(series) 0.02234
# [Stage3] L=1 ep 022 | train MSE(win) 0.02350 | test MSE(win) 0.02300 | test MSE(series) 0.02234
# [Stage3] L=1 ep 023 | train MSE(win) 0.02378 | test MSE(win) 0.02299 | test MSE(series) 0.02233
# [Final TEST] MSE(win) 0.022993 vs noisy 0.019387 → Δ -18.6%
# [Final TEST] MSE(series) 0.022333 vs noisy 0.018958 → Δ -17.8%
#
# ==============================
# Instance 5 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.484660 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.479571 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.475095 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.471191 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.467488 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.463864 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.460321 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.456847 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.453420 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.450003 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.446536 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.442944 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.439152 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.435099 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.430748 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.426100 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.421204 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.416133 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.410958 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.405708 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.400361 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.394863 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.389155 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.383199 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.376987 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.370550 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.363965 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.357351 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.350862 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.344674 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.340054 | LR 0.01000
# [Stage1] best train cost = 0.340054
# [Stage3] L=1 ep 000 | train MSE(win) 0.02367 | test MSE(win) 0.02332 | test MSE(series) 0.02282
# [Stage3] L=1 ep 001 | train MSE(win) 0.02399 | test MSE(win) 0.02332 | test MSE(series) 0.02282
# [Stage3] L=1 ep 002 | train MSE(win) 0.02373 | test MSE(win) 0.02332 | test MSE(series) 0.02282
# [Stage3] L=1 ep 003 | train MSE(win) 0.02367 | test MSE(win) 0.02332 | test MSE(series) 0.02282
# [Stage3] L=1 ep 004 | train MSE(win) 0.02348 | test MSE(win) 0.02332 | test MSE(series) 0.02282
# [Stage3] L=1 ep 005 | train MSE(win) 0.02401 | test MSE(win) 0.02331 | test MSE(series) 0.02282
# [Stage3] L=1 ep 006 | train MSE(win) 0.02440 | test MSE(win) 0.02331 | test MSE(series) 0.02282
# [Stage3] L=1 ep 007 | train MSE(win) 0.02354 | test MSE(win) 0.02331 | test MSE(series) 0.02282
# [Stage3] L=1 ep 008 | train MSE(win) 0.02422 | test MSE(win) 0.02331 | test MSE(series) 0.02281
# [Stage3] L=1 ep 009 | train MSE(win) 0.02340 | test MSE(win) 0.02331 | test MSE(series) 0.02281
# [Stage3] L=1 ep 010 | train MSE(win) 0.02387 | test MSE(win) 0.02330 | test MSE(series) 0.02281
# [Stage3] L=1 ep 011 | train MSE(win) 0.02381 | test MSE(win) 0.02330 | test MSE(series) 0.02281
# [Stage3] L=1 ep 012 | train MSE(win) 0.02389 | test MSE(win) 0.02330 | test MSE(series) 0.02280
# [Stage3] L=1 ep 013 | train MSE(win) 0.02396 | test MSE(win) 0.02329 | test MSE(series) 0.02280
# [Stage3] L=1 ep 014 | train MSE(win) 0.02417 | test MSE(win) 0.02329 | test MSE(series) 0.02280
# [Stage3] L=1 ep 015 | train MSE(win) 0.02388 | test MSE(win) 0.02329 | test MSE(series) 0.02280
# [Stage3] L=1 ep 016 | train MSE(win) 0.02379 | test MSE(win) 0.02329 | test MSE(series) 0.02279
# [Stage3] L=1 ep 017 | train MSE(win) 0.02412 | test MSE(win) 0.02328 | test MSE(series) 0.02279
# [Stage3] L=1 ep 018 | train MSE(win) 0.02383 | test MSE(win) 0.02328 | test MSE(series) 0.02279
# [Stage3] L=1 ep 019 | train MSE(win) 0.02411 | test MSE(win) 0.02328 | test MSE(series) 0.02279
# [Stage3] L=1 ep 020 | train MSE(win) 0.02333 | test MSE(win) 0.02328 | test MSE(series) 0.02278
# [Stage3] L=1 ep 021 | train MSE(win) 0.02418 | test MSE(win) 0.02327 | test MSE(series) 0.02278
# [Stage3] L=1 ep 022 | train MSE(win) 0.02400 | test MSE(win) 0.02327 | test MSE(series) 0.02278
# [Stage3] L=1 ep 023 | train MSE(win) 0.02409 | test MSE(win) 0.02327 | test MSE(series) 0.02277
# [Final TEST] MSE(win) 0.023267 vs noisy 0.019387 → Δ -20.0%
# [Final TEST] MSE(series) 0.022775 vs noisy 0.018958 → Δ -20.1%
#
# ==============================
# Instance 1 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.450888 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.396639 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.353433 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.321728 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.296454 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.273865 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.252393 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.232086 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.213244 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.196340 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.181769 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.169575 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.159301 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.150332 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.142113 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.134212 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.126358 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.118416 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.110282 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.101958 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.093702 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.085959 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.079123 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.073344 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.068488 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.064255 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.060369 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.056668 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.053104 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.049705 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.047139 | LR 0.01000
# [Stage1] best train cost = 0.047139
# [Stage3] L=3 ep 000 | train MSE(win) 0.01142 | test MSE(win) 0.00979 | test MSE(series) 0.00877
# [Stage3] L=3 ep 001 | train MSE(win) 0.01092 | test MSE(win) 0.00979 | test MSE(series) 0.00877
# [Stage3] L=3 ep 002 | train MSE(win) 0.01039 | test MSE(win) 0.00979 | test MSE(series) 0.00877
# [Stage3] L=3 ep 003 | train MSE(win) 0.00852 | test MSE(win) 0.00978 | test MSE(series) 0.00877
# [Stage3] L=3 ep 004 | train MSE(win) 0.00892 | test MSE(win) 0.00978 | test MSE(series) 0.00876
# [Stage3] L=3 ep 005 | train MSE(win) 0.01021 | test MSE(win) 0.00977 | test MSE(series) 0.00876
# [Stage3] L=3 ep 006 | train MSE(win) 0.01101 | test MSE(win) 0.00977 | test MSE(series) 0.00875
# [Stage3] L=3 ep 007 | train MSE(win) 0.01041 | test MSE(win) 0.00976 | test MSE(series) 0.00875
# [Stage3] L=3 ep 008 | train MSE(win) 0.00981 | test MSE(win) 0.00975 | test MSE(series) 0.00874
# [Stage3] L=3 ep 009 | train MSE(win) 0.01114 | test MSE(win) 0.00974 | test MSE(series) 0.00873
# [Stage3] L=3 ep 010 | train MSE(win) 0.01031 | test MSE(win) 0.00974 | test MSE(series) 0.00872
# [Stage3] L=3 ep 011 | train MSE(win) 0.00895 | test MSE(win) 0.00973 | test MSE(series) 0.00872
# [Stage3] L=3 ep 012 | train MSE(win) 0.01145 | test MSE(win) 0.00972 | test MSE(series) 0.00871
# [Stage3] L=3 ep 013 | train MSE(win) 0.00966 | test MSE(win) 0.00971 | test MSE(series) 0.00870
# [Stage3] L=3 ep 014 | train MSE(win) 0.00843 | test MSE(win) 0.00970 | test MSE(series) 0.00869
# [Stage3] L=3 ep 015 | train MSE(win) 0.00974 | test MSE(win) 0.00969 | test MSE(series) 0.00868
# [Stage3] L=3 ep 016 | train MSE(win) 0.00972 | test MSE(win) 0.00968 | test MSE(series) 0.00867
# [Stage3] L=3 ep 017 | train MSE(win) 0.01081 | test MSE(win) 0.00967 | test MSE(series) 0.00866
# [Stage3] L=3 ep 018 | train MSE(win) 0.01035 | test MSE(win) 0.00966 | test MSE(series) 0.00865
# [Stage3] L=3 ep 019 | train MSE(win) 0.01126 | test MSE(win) 0.00964 | test MSE(series) 0.00864
# [Stage3] L=3 ep 020 | train MSE(win) 0.00991 | test MSE(win) 0.00963 | test MSE(series) 0.00863
# [Stage3] L=3 ep 021 | train MSE(win) 0.00977 | test MSE(win) 0.00962 | test MSE(series) 0.00862
# [Stage3] L=3 ep 022 | train MSE(win) 0.01218 | test MSE(win) 0.00961 | test MSE(series) 0.00861
# [Stage3] L=3 ep 023 | train MSE(win) 0.00977 | test MSE(win) 0.00960 | test MSE(series) 0.00860
# [Final TEST] MSE(win) 0.009602 vs noisy 0.019387 → Δ +50.5%
# [Final TEST] MSE(series) 0.008601 vs noisy 0.018958 → Δ +54.6%
#
# ==============================
# Instance 2 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.487931 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.429464 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.372686 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.323399 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.281181 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.245623 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.217157 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.194474 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.175129 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.157585 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.141984 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.128260 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.115900 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.104918 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.095736 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.088370 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.082598 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.078191 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.074796 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.072034 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.069664 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.067527 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.065503 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.063500 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.061454 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.059340 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.057167 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.054979 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.052851 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.050856 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.049383 | LR 0.01000
# [Stage1] best train cost = 0.049383
# [Stage3] L=3 ep 000 | train MSE(win) 0.00974 | test MSE(win) 0.00848 | test MSE(series) 0.00788
# [Stage3] L=3 ep 001 | train MSE(win) 0.00993 | test MSE(win) 0.00848 | test MSE(series) 0.00788
# [Stage3] L=3 ep 002 | train MSE(win) 0.00917 | test MSE(win) 0.00848 | test MSE(series) 0.00788
# [Stage3] L=3 ep 003 | train MSE(win) 0.00791 | test MSE(win) 0.00848 | test MSE(series) 0.00788
# [Stage3] L=3 ep 004 | train MSE(win) 0.00744 | test MSE(win) 0.00847 | test MSE(series) 0.00788
# [Stage3] L=3 ep 005 | train MSE(win) 0.00936 | test MSE(win) 0.00847 | test MSE(series) 0.00788
# [Stage3] L=3 ep 006 | train MSE(win) 0.00948 | test MSE(win) 0.00847 | test MSE(series) 0.00787
# [Stage3] L=3 ep 007 | train MSE(win) 0.00892 | test MSE(win) 0.00846 | test MSE(series) 0.00787
# [Stage3] L=3 ep 008 | train MSE(win) 0.00854 | test MSE(win) 0.00846 | test MSE(series) 0.00787
# [Stage3] L=3 ep 009 | train MSE(win) 0.00979 | test MSE(win) 0.00845 | test MSE(series) 0.00786
# [Stage3] L=3 ep 010 | train MSE(win) 0.00970 | test MSE(win) 0.00845 | test MSE(series) 0.00786
# [Stage3] L=3 ep 011 | train MSE(win) 0.00798 | test MSE(win) 0.00844 | test MSE(series) 0.00785
# [Stage3] L=3 ep 012 | train MSE(win) 0.01009 | test MSE(win) 0.00844 | test MSE(series) 0.00785
# [Stage3] L=3 ep 013 | train MSE(win) 0.00792 | test MSE(win) 0.00843 | test MSE(series) 0.00785
# [Stage3] L=3 ep 014 | train MSE(win) 0.00733 | test MSE(win) 0.00843 | test MSE(series) 0.00784
# [Stage3] L=3 ep 015 | train MSE(win) 0.00891 | test MSE(win) 0.00843 | test MSE(series) 0.00784
# [Stage3] L=3 ep 016 | train MSE(win) 0.00833 | test MSE(win) 0.00842 | test MSE(series) 0.00784
# [Stage3] L=3 ep 017 | train MSE(win) 0.01022 | test MSE(win) 0.00842 | test MSE(series) 0.00783
# [Stage3] L=3 ep 018 | train MSE(win) 0.00932 | test MSE(win) 0.00841 | test MSE(series) 0.00783
# [Stage3] L=3 ep 019 | train MSE(win) 0.01089 | test MSE(win) 0.00841 | test MSE(series) 0.00783
# [Stage3] L=3 ep 020 | train MSE(win) 0.00868 | test MSE(win) 0.00841 | test MSE(series) 0.00783
# [Stage3] L=3 ep 021 | train MSE(win) 0.00890 | test MSE(win) 0.00840 | test MSE(series) 0.00782
# [Stage3] L=3 ep 022 | train MSE(win) 0.01063 | test MSE(win) 0.00840 | test MSE(series) 0.00782
# [Stage3] L=3 ep 023 | train MSE(win) 0.00856 | test MSE(win) 0.00840 | test MSE(series) 0.00782
# [Final TEST] MSE(win) 0.008397 vs noisy 0.019387 → Δ +56.7%
# [Final TEST] MSE(series) 0.007818 vs noisy 0.018958 → Δ +58.8%
#
# ==============================
# Instance 3 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.492497 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.450070 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.416302 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.381683 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.346017 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.310820 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.275869 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.242838 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.215589 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.196160 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.180755 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.165247 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.150361 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.137798 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.127949 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.120971 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.116449 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.113392 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.110972 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.108630 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.106004 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.102956 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.099420 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.095331 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.090611 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.085208 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.079171 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.072695 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.066124 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.059879 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.055388 | LR 0.01000
# [Stage1] best train cost = 0.055388
# [Stage3] L=3 ep 000 | train MSE(win) 0.01020 | test MSE(win) 0.00948 | test MSE(series) 0.00793
# [Stage3] L=3 ep 001 | train MSE(win) 0.00970 | test MSE(win) 0.00947 | test MSE(series) 0.00792
# [Stage3] L=3 ep 002 | train MSE(win) 0.00954 | test MSE(win) 0.00947 | test MSE(series) 0.00792
# [Stage3] L=3 ep 003 | train MSE(win) 0.00847 | test MSE(win) 0.00947 | test MSE(series) 0.00792
# [Stage3] L=3 ep 004 | train MSE(win) 0.00769 | test MSE(win) 0.00947 | test MSE(series) 0.00791
# [Stage3] L=3 ep 005 | train MSE(win) 0.00953 | test MSE(win) 0.00946 | test MSE(series) 0.00791
# [Stage3] L=3 ep 006 | train MSE(win) 0.00997 | test MSE(win) 0.00946 | test MSE(series) 0.00790
# [Stage3] L=3 ep 007 | train MSE(win) 0.00896 | test MSE(win) 0.00945 | test MSE(series) 0.00789
# [Stage3] L=3 ep 008 | train MSE(win) 0.00867 | test MSE(win) 0.00945 | test MSE(series) 0.00789
# [Stage3] L=3 ep 009 | train MSE(win) 0.01001 | test MSE(win) 0.00944 | test MSE(series) 0.00788
# [Stage3] L=3 ep 010 | train MSE(win) 0.00926 | test MSE(win) 0.00943 | test MSE(series) 0.00787
# [Stage3] L=3 ep 011 | train MSE(win) 0.00819 | test MSE(win) 0.00943 | test MSE(series) 0.00787
# [Stage3] L=3 ep 012 | train MSE(win) 0.01040 | test MSE(win) 0.00943 | test MSE(series) 0.00786
# [Stage3] L=3 ep 013 | train MSE(win) 0.00798 | test MSE(win) 0.00942 | test MSE(series) 0.00785
# [Stage3] L=3 ep 014 | train MSE(win) 0.00781 | test MSE(win) 0.00942 | test MSE(series) 0.00785
# [Stage3] L=3 ep 015 | train MSE(win) 0.00920 | test MSE(win) 0.00942 | test MSE(series) 0.00784
# [Stage3] L=3 ep 016 | train MSE(win) 0.00878 | test MSE(win) 0.00941 | test MSE(series) 0.00783
# [Stage3] L=3 ep 017 | train MSE(win) 0.01016 | test MSE(win) 0.00941 | test MSE(series) 0.00783
# [Stage3] L=3 ep 018 | train MSE(win) 0.00990 | test MSE(win) 0.00941 | test MSE(series) 0.00782
# [Stage3] L=3 ep 019 | train MSE(win) 0.01160 | test MSE(win) 0.00940 | test MSE(series) 0.00781
# [Stage3] L=3 ep 020 | train MSE(win) 0.00941 | test MSE(win) 0.00939 | test MSE(series) 0.00781
# [Stage3] L=3 ep 021 | train MSE(win) 0.00862 | test MSE(win) 0.00939 | test MSE(series) 0.00780
# [Stage3] L=3 ep 022 | train MSE(win) 0.01124 | test MSE(win) 0.00938 | test MSE(series) 0.00779
# [Stage3] L=3 ep 023 | train MSE(win) 0.00904 | test MSE(win) 0.00938 | test MSE(series) 0.00778
# [Final TEST] MSE(win) 0.009377 vs noisy 0.019387 → Δ +51.6%
# [Final TEST] MSE(series) 0.007782 vs noisy 0.018958 → Δ +59.0%
#
# ==============================
# Instance 4 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.506228 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.459321 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.410941 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.363985 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.321246 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.283990 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.252311 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.226338 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.205219 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.187756 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.173389 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.161764 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.152353 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.144470 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.137701 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.131838 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.126617 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.121848 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.117458 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.113367 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.109511 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.105863 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.102400 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.099096 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.095917 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.092820 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.089768 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.086735 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.083704 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.080668 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.078243 | LR 0.01000
# [Stage1] best train cost = 0.078243
# [Stage3] L=3 ep 000 | train MSE(win) 0.01010 | test MSE(win) 0.00842 | test MSE(series) 0.00809
# [Stage3] L=3 ep 001 | train MSE(win) 0.01022 | test MSE(win) 0.00842 | test MSE(series) 0.00809
# [Stage3] L=3 ep 002 | train MSE(win) 0.00982 | test MSE(win) 0.00842 | test MSE(series) 0.00809
# [Stage3] L=3 ep 003 | train MSE(win) 0.00850 | test MSE(win) 0.00843 | test MSE(series) 0.00809
# [Stage3] L=3 ep 004 | train MSE(win) 0.00833 | test MSE(win) 0.00843 | test MSE(series) 0.00810
# [Stage3] L=3 ep 005 | train MSE(win) 0.01015 | test MSE(win) 0.00843 | test MSE(series) 0.00810
# [Stage3] L=3 ep 006 | train MSE(win) 0.01023 | test MSE(win) 0.00843 | test MSE(series) 0.00810
# [Stage3] L=3 ep 007 | train MSE(win) 0.01021 | test MSE(win) 0.00843 | test MSE(series) 0.00810
# [Stage3] L=3 ep 008 | train MSE(win) 0.00905 | test MSE(win) 0.00843 | test MSE(series) 0.00811
# [Stage3] L=3 ep 009 | train MSE(win) 0.01047 | test MSE(win) 0.00843 | test MSE(series) 0.00811
# [Stage3] L=3 ep 010 | train MSE(win) 0.01030 | test MSE(win) 0.00844 | test MSE(series) 0.00811
# [Stage3] L=3 ep 011 | train MSE(win) 0.00909 | test MSE(win) 0.00844 | test MSE(series) 0.00811
# [Stage3] L=3 ep 012 | train MSE(win) 0.01015 | test MSE(win) 0.00844 | test MSE(series) 0.00812
# [Stage3] L=3 ep 013 | train MSE(win) 0.00870 | test MSE(win) 0.00844 | test MSE(series) 0.00812
# [Stage3] L=3 ep 014 | train MSE(win) 0.00824 | test MSE(win) 0.00844 | test MSE(series) 0.00812
# [Stage3] L=3 ep 015 | train MSE(win) 0.00958 | test MSE(win) 0.00844 | test MSE(series) 0.00812
# [Stage3] L=3 ep 016 | train MSE(win) 0.00902 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 017 | train MSE(win) 0.01027 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 018 | train MSE(win) 0.00977 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 019 | train MSE(win) 0.01164 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 020 | train MSE(win) 0.00956 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 021 | train MSE(win) 0.00908 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 022 | train MSE(win) 0.01090 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Stage3] L=3 ep 023 | train MSE(win) 0.00916 | test MSE(win) 0.00844 | test MSE(series) 0.00813
# [Final TEST] MSE(win) 0.008440 vs noisy 0.019387 → Δ +56.5%
# [Final TEST] MSE(series) 0.008133 vs noisy 0.018958 → Δ +57.1%
#
# ==============================
# Instance 5 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.598835 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.537814 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.470187 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.401898 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.339199 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.287751 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.250020 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.223975 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.204719 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.187541 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.170653 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.154518 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.140241 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.128692 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.119809 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.112605 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.106197 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.100422 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.095415 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.091158 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.087473 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.084182 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.081180 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.078413 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.075849 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.073474 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.071295 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.069330 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.067582 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.066037 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.064929 | LR 0.01000
# [Stage1] best train cost = 0.064929
# [Stage3] L=3 ep 000 | train MSE(win) 0.01013 | test MSE(win) 0.00810 | test MSE(series) 0.00774
# [Stage3] L=3 ep 001 | train MSE(win) 0.00964 | test MSE(win) 0.00810 | test MSE(series) 0.00774
# [Stage3] L=3 ep 002 | train MSE(win) 0.00870 | test MSE(win) 0.00810 | test MSE(series) 0.00774
# [Stage3] L=3 ep 003 | train MSE(win) 0.00832 | test MSE(win) 0.00810 | test MSE(series) 0.00774
# [Stage3] L=3 ep 004 | train MSE(win) 0.00748 | test MSE(win) 0.00809 | test MSE(series) 0.00773
# [Stage3] L=3 ep 005 | train MSE(win) 0.00906 | test MSE(win) 0.00809 | test MSE(series) 0.00773
# [Stage3] L=3 ep 006 | train MSE(win) 0.00912 | test MSE(win) 0.00809 | test MSE(series) 0.00773
# [Stage3] L=3 ep 007 | train MSE(win) 0.00959 | test MSE(win) 0.00808 | test MSE(series) 0.00773
# [Stage3] L=3 ep 008 | train MSE(win) 0.00897 | test MSE(win) 0.00808 | test MSE(series) 0.00772
# [Stage3] L=3 ep 009 | train MSE(win) 0.00964 | test MSE(win) 0.00808 | test MSE(series) 0.00772
# [Stage3] L=3 ep 010 | train MSE(win) 0.00955 | test MSE(win) 0.00807 | test MSE(series) 0.00772
# [Stage3] L=3 ep 011 | train MSE(win) 0.00787 | test MSE(win) 0.00807 | test MSE(series) 0.00772
# [Stage3] L=3 ep 012 | train MSE(win) 0.00988 | test MSE(win) 0.00807 | test MSE(series) 0.00771
# [Stage3] L=3 ep 013 | train MSE(win) 0.00846 | test MSE(win) 0.00806 | test MSE(series) 0.00771
# [Stage3] L=3 ep 014 | train MSE(win) 0.00805 | test MSE(win) 0.00806 | test MSE(series) 0.00771
# [Stage3] L=3 ep 015 | train MSE(win) 0.00881 | test MSE(win) 0.00805 | test MSE(series) 0.00770
# [Stage3] L=3 ep 016 | train MSE(win) 0.00811 | test MSE(win) 0.00805 | test MSE(series) 0.00770
# [Stage3] L=3 ep 017 | train MSE(win) 0.00895 | test MSE(win) 0.00804 | test MSE(series) 0.00770
# [Stage3] L=3 ep 018 | train MSE(win) 0.00935 | test MSE(win) 0.00803 | test MSE(series) 0.00769
# [Stage3] L=3 ep 019 | train MSE(win) 0.01074 | test MSE(win) 0.00803 | test MSE(series) 0.00769
# [Stage3] L=3 ep 020 | train MSE(win) 0.00870 | test MSE(win) 0.00802 | test MSE(series) 0.00768
# [Stage3] L=3 ep 021 | train MSE(win) 0.00864 | test MSE(win) 0.00802 | test MSE(series) 0.00768
# [Stage3] L=3 ep 022 | train MSE(win) 0.01004 | test MSE(win) 0.00802 | test MSE(series) 0.00768
# [Stage3] L=3 ep 023 | train MSE(win) 0.00850 | test MSE(win) 0.00801 | test MSE(series) 0.00768
# [Final TEST] MSE(win) 0.008012 vs noisy 0.019387 → Δ +58.7%
# [Final TEST] MSE(series) 0.007676 vs noisy 0.018958 → Δ +59.5%
#
# Completed 10 runs.

# %%
# ===============================
# Cell 9 — final plots & stats for all instances
# ===============================
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

ARCH_TAG = f"{n_qubits}q_{n_latent}l_{n_trash}t"
SAVE_PLOTS = True  # set False if you don't want PNGs on disk

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _seed_for_run(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3:
        return int(s3["TEST_SEED_FIXED"])
    hist = s3.get("hist_train", [])
    return 88_000 + 100*instance_id + (len(hist) - 1 if len(hist) else 0)

def plot_one(run, save_dir=None, title_note=""):
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    seed = _seed_for_run(run, inst)

    denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed)
    tr_rec = denoise_windows(psi, denoise, tr_n)
    te_rec = denoise_windows(psi, denoise, te_n)

    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_rec);te_hat  = _flatten_avg(te_rec)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    x_tr = np.arange(len(tr_pure)); x_te = np.arange(len(tr_pure), len(tr_pure)+len(te_pure))
    x_split = len(tr_pure)

    plt.figure(figsize=(12, 6))
    plt.scatter(x_tr, tr_noi, s=10, alpha=0.55, label=f"Train Noise (MSE={mse_tr_noise:0.5f})")
    plt.scatter(x_te, te_noi, s=10, alpha=0.55, label=f"Test  Noise (MSE={mse_te_noise:0.5f})")
    plt.plot(x_tr, tr_pure, linewidth=1.8, label="Train Pure")
    plt.plot(x_te, te_pure, linewidth=1.8, label="Test Pure")
    plt.plot(x_tr, tr_hat, linestyle="--", linewidth=2.0, label=f"Train Recovered (MSE={mse_tr_hat:0.5f})")
    plt.plot(x_te, te_hat, linestyle="--", linewidth=2.0, label=f"Test  Recovered (MSE={mse_te_hat:0.5f})")
    plt.axvline(x_split, color="grey", linestyle="--", alpha=0.7)
    plt.ylim(scale_low - 0.05*(scale_high - scale_low), scale_high + 0.05*(scale_high - scale_low))
    plt.xlabel(f'Range (samples={len(y)}, window size={wind_size}, step={wind_step})')
    plt.title(f'Pure vs Recovered (data=\"{DATA_ID}\", σ={EVAL_SIGMA:.3f}, '
              f'W={wind_size}, step={wind_step}, L={L}, inst={inst}) {title_note}')
    plt.legend(loc="upper center", ncol=3, frameon=False)
    plt.tight_layout()

    if SAVE_PLOTS and save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        out_png = Path(save_dir) / f"plot_{ARCH_TAG}_L{L}_inst{inst:02d}.png"
        plt.savefig(out_png, dpi=200, bbox_inches="tight", pad_inches=0.08)
        print(f"Saved plot → {out_png}")
    plt.show()

    dtr = 100*(1 - mse_tr_hat/max(mse_tr_noise,1e-12))
    dte = 100*(1 - mse_te_hat/max(mse_te_noise,1e-12))
    print(f"[Series-avg] TRAIN: noise={mse_tr_noise:0.8f}  recovered={mse_tr_hat:0.8f}  Δ={dtr:+.1f}%")
    print(f"[Series-avg] TEST : noise={mse_te_noise:0.8f}  recovered={mse_te_hat:0.8f}  Δ={dte:+.1f}%")

# -- Run plots for every trained (instance, L)
for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        if any(r["n_layers"] == L and r["instance_id"] == inst for r in ALL_RUNS):
            run = next(r for r in ALL_RUNS if r["n_layers"] == L and r["instance_id"] == inst)
            print(f"\n=== Final plot for L={L}, inst={inst} ===")
            plot_one(run, save_dir=f"{FIGURES_PATH}/final2/{ARCH_TAG}/L{L}")
# Out:
# === Final plot for L=1, inst=1 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02046738  Δ=-6.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01722547  Δ=+9.1%
#
# === Final plot for L=1, inst=2 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02373348  Δ=-23.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02239704  Δ=-18.1%
#
# === Final plot for L=1, inst=3 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02206431  Δ=-14.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01995709  Δ=-5.3%
#
# === Final plot for L=1, inst=4 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02295842  Δ=-19.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02233297  Δ=-17.8%
#
# === Final plot for L=1, inst=5 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02389320  Δ=-24.0%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02277486  Δ=-20.1%
#
# === Final plot for L=3, inst=1 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01158757  Δ=+39.9%
# [Series-avg] TEST : noise=0.01895794  recovered=0.00860105  Δ=+54.6%
#
# === Final plot for L=3, inst=2 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01028480  Δ=+46.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.00781802  Δ=+58.8%
#
# === Final plot for L=3, inst=3 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.00992156  Δ=+48.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.00778180  Δ=+59.0%
#
# === Final plot for L=3, inst=4 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01112113  Δ=+42.3%
# [Series-avg] TEST : noise=0.01895794  recovered=0.00813327  Δ=+57.1%
#
# === Final plot for L=3, inst=5 ===
# Saved plot → aintern/figures/final2/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01028465  Δ=+46.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.00767630  Δ=+59.5%

# %%
# ===============================
# Cell A — Circuit renderer (ψ + SWAP-reset + adjoint(φ))
# ===============================
from pathlib import Path
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as pnp

def render_and_save_circuit(
    L, phi_vec, psi_vec, save_dir, inst,
    style="pennylane", level="device", fname_prefix="circuit"
):
    """
    Draw the denoiser circuit exactly as used in Stage-3:
      1) embed_input(x)
      2) encoder with ψ
      3) SWAP-reset of the trash qubits using |0> ancillas
      4) adjoint(encoder) with fixed φ
      5) Z measurements (on the main data wires only)

    Notes:
    - Device wires: [0, 1, ..., n_qubits-1, 'anc0', 'anc1', ...]
    - SWAPs occur between trash wires (n_latent ... n_qubits-1) and the ancillas.
    """
    # --- wires: main data wires + ancillas for reset ---
    main_wires = list(range(n_qubits))
    anc_wires  = [f"anc{k}" for k in range(n_trash)]  # pretty labels
    dev_wires  = main_wires + anc_wires

    dev = qml.device("default.qubit", wires=dev_wires, shots=None)

    # freeze φ & ψ for drawing
    theta_fixed = pnp.array(phi_vec, requires_grad=False).reshape((L, n_qubits, 3))
    psi_flat    = pnp.array(psi_vec, requires_grad=False)

    # ----- Encoder body used in Stage-1/3 (matches your training template) -----
    def encoder_body(theta):
        # theta shape: (L, n_qubits, 3) for RX/RY/RZ on each qubit per layer
        for l in range(L):
            # single-qubit rotations
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=main_wires[q])
                qml.RY(theta[l, q, 1], wires=main_wires[q])
                qml.RZ(theta[l, q, 2], wires=main_wires[q])
            # ring CNOT entanglers across data wires
            for q in range(n_qubits - 1):
                qml.CNOT(wires=[main_wires[q], main_wires[q + 1]])
            qml.CNOT(wires=[main_wires[-1], main_wires[0]])

    # fixed decoder = adjoint(φ)
    def decoder_fixed():
        qml.adjoint(encoder_body)(theta_fixed)

    # --- explicit SWAP-reset (trash -> ancilla, main trash becomes |0>)
    def swap_reset_trash_to_ancilla():
        for k in range(n_trash):
            t_wire = main_wires[n_latent + k]  # trash wire in main register
            a_wire = anc_wires[k]              # corresponding ancilla at |0>
            qml.SWAP(wires=[t_wire, a_wire])

    # --- QNode for drawing (deterministic dummy input) ---
    @qml.qnode(dev)
    def denoiser_for_draw(x_in):
        # 1) input embedding on main wires (same function you use in training)
        embed_input(x_in)

        # 2) encoder with learned ψ (reuse your training helper if you prefer)
        #    If your 'encoder_template' writes to the current device wires,
        #    it will act on main_wires because those are numbered 0..n_qubits-1.
        encoder_template(psi_flat, L)

        # 3) SWAP-reset of trash qubits into ancillas
        if n_trash > 0:
            swap_reset_trash_to_ancilla()

        # 4) fixed decoder = adjoint(φ)
        decoder_fixed()

        # 5) measure main data wires (not the ancillas)
        return [qml.expval(qml.PauliZ(w)) for w in main_wires]

    # ---- render & save ----
    x_dummy = pnp.zeros(wind_size, dtype=float)  # just to build the tape
    qml.drawer.use_style(style)
    fig, ax = qml.draw_mpl(denoiser_for_draw, decimals=2, level=level)(x_dummy)

    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    out_png = save_dir / f"{fname_prefix}_L{L}_inst{int(inst):02d}.png"
    fig.savefig(out_png, dpi=220, bbox_inches="tight", pad_inches=0.1)
    plt.close(fig)
    return out_png

# %%
# ===============================
# Cell B — Save φ/ψ + circuit PNGs + CSVs
# ===============================
import json, csv, time, os
from pathlib import Path
import numpy as np
import pandas as pd

# --- helpers (local, robust) ---
def ensure_dir(p: str | Path) -> Path:
    p = Path(p); p.mkdir(parents=True, exist_ok=True); return p

def arch_tag():
    # e.g. "4q_3l_1t"
    return f"{n_qubits}q_{n_latent}l_{n_trash}t"

def inst_fname(L, inst):
    return f"inst{int(inst):02d}_L{int(L)}"

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _choose_eval_seed(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3 and s3["TEST_SEED_FIXED"] is not None:
        return int(s3["TEST_SEED_FIXED"])
    # fallback to "last-epoch" convention
    eplen = len(s3.get("hist_train", []))
    return 88_000 + 100*instance_id + max(eplen - 1, 0)

# Respect global choices if set elsewhere
DEV_NAME   = globals().get("DEV_NAME", "default.qubit")
RESET_MODE = globals().get("RESET_MODE", "swap")   # "swap" (unitary) or "measure"

# --- roots ---
ROOT = ensure_dir("qae_runs")
DATA_ROOT = ensure_dir(ROOT / DATA_ID)
ARCH_ROOT = ensure_dir(DATA_ROOT / arch_tag())

# per-layer dirs
dir_L = {L: ensure_dir(ARCH_ROOT / f"L{int(L)}") for L in set(LAYER_OPTIONS)}

# CSV paths (within arch folder)
CSV_RUNS   = ARCH_ROOT / "metrics_by_run.csv"
CSV_SUMMARY= ARCH_ROOT / "summary_by_layer.csv"

# create/ensure CSV headers
RUNS_HEADER = [
    "dataset","arch","instance_id","layer",
    "window_size","step","sigma_eval",
    "mse_train_noise","mse_train_recovered","delta_train_pct",
    "mse_test_noise","mse_test_recovered","delta_test_pct",
    "s1_best_train_cost","timestamp","bundle_json"
]
if not CSV_RUNS.exists():
    with open(CSV_RUNS, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow(RUNS_HEADER)

# ---- iterate runs and save artifacts ----
rows = []
for run in ALL_RUNS:
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    # --- params to .npy ---
    np.save(dir_L[L] / f"phi_{inst_fname(L, inst)}.npy", phi)
    np.save(dir_L[L] / f"psi_{inst_fname(L, inst)}.npy", psi)

    # --- evaluate metrics on the run's fixed test seed (or fallback) ---
    seed_eval = _choose_eval_seed(run, inst)
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed_eval)

    # Use the same reset mode as training (ensures denoiser matches what was trained)
    handles  = stage3_qnodes(L, phi, reset_mode=RESET_MODE)
    denoiser = handles["denoiser_qnode_all"]

    tr_hat_w = denoise_windows(psi, denoiser, tr_n)
    te_hat_w = denoise_windows(psi, denoiser, te_n)

    # series-level (flattened) MSEs
    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_hat_w); te_hat = _flatten_avg(te_hat_w)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    d_tr = 100.0 * (1.0 - mse_tr_hat / max(mse_tr_noise, 1e-12))
    d_te = 100.0 * (1.0 - mse_te_hat / max(mse_te_noise, 1e-12))

    # --- save circuit PNG (in arch folder, NOT inside Lx) ---
    png_path = render_and_save_circuit(L, phi, psi, save_dir=ARCH_ROOT, inst=inst,
                                       style="pennylane", level="device",
                                       fname_prefix="circuit")

    # --- compact JSON bundle (path saved in CSV for traceability) ---
    bundle = {
        "schema": {"name": "half_qae_bundle", "version": "1.0"},
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "dataset": {
            "id": DATA_ID,
            "scale_low":  float(scale_low),
            "scale_high": float(scale_high),
            "window_size": int(wind_size),
            "window_step": int(wind_step),
            "split": float(split),
        },
        "run": {
            "instance_id": inst,
            "layer": L,
            "sigma_eval": float(EVAL_SIGMA),
            "test_seed_fixed": int(run["stage3"].get("TEST_SEED_FIXED", seed_eval)),
        },
        "environment": {
            "device": DEV_NAME,
            "reset_mode": RESET_MODE,
        },
        "architecture": {
            "n_qubits": int(n_qubits),
            "n_latent": int(n_latent),
            "n_trash":  int(n_trash),
        },
        "parameters": {
            "phi": phi.tolist(),
            "psi": psi.tolist(),
        },
        "metrics_series": {
            "mse_train_noise": mse_tr_noise,
            "mse_train_recovered": mse_tr_hat,
            "delta_train_pct": d_tr,
            "mse_test_noise": mse_te_noise,
            "mse_test_recovered": mse_te_hat,
            "delta_test_pct": d_te,
        }
    }
    bundle_path = dir_L[L] / f"bundle_{inst_fname(L, inst)}.json"
    with open(bundle_path, "w", encoding="utf-8") as f:
        json.dump(bundle, f, indent=2)

    # --- row for runs CSV ---
    rows.append([
        DATA_ID, arch_tag(), inst, L,
        int(wind_size), int(wind_step), float(EVAL_SIGMA),
        mse_tr_noise, mse_tr_hat, d_tr,
        mse_te_noise, mse_te_hat, d_te,
        float(run["stage1"].get("best_train", np.nan)),
        bundle["timestamp"],
        str(bundle_path)
    ])

# upsert rows into metrics_by_run.csv (deduplicate by instance_id+layer)
if rows:
    df_new = pd.DataFrame(rows, columns=RUNS_HEADER)
    if CSV_RUNS.exists():
        df_old = pd.read_csv(CSV_RUNS)
        key_cols = ["dataset","arch","instance_id","layer"]
        df_old = df_old.drop_duplicates(subset=key_cols, keep="last")
        df_new = pd.concat([df_old, df_new], ignore_index=True)
        df_new = df_new.drop_duplicates(subset=key_cols, keep="last")
    df_new.to_csv(CSV_RUNS, index=False)
    print(f"Updated per-run metrics → {CSV_RUNS}")

# # build a tiny per-layer summary
if Path(CSV_RUNS).exists():
    df = pd.read_csv(CSV_RUNS)
    summary = (df
        .groupby("layer", as_index=True)
        .agg(
            runs=("instance_id","count"),
            mse_test_noise_mean=("mse_test_noise","mean"),
            mse_test_recovered_mean=("mse_test_recovered","mean"),
            delta_test_pct_mean=("delta_test_pct","mean"),
        )
    )
    summary.to_csv(CSV_SUMMARY)
    print(f"Saved per-layer summary → {CSV_SUMMARY}")

print(f"Artifacts saved under → {ARCH_ROOT}")
# Out:
# Updated per-run metrics → qae_runs/mackey_glass_tau30_n200/4q_3l_1t/metrics_by_run.csv
# Saved per-layer summary → qae_runs/mackey_glass_tau30_n200/4q_3l_1t/summary_by_layer.csv
# Artifacts saved under → qae_runs/mackey_glass_tau30_n200/4q_3l_1t

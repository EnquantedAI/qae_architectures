# %%
# ===========================
# Cell 0 — Config
# ===========================
DATA_ID = 'mackey_glass_tau17_n200'   # your dataset folder name

# Noise used in training & scoring
EVAL_SIGMA   = 0.20

# Windowing (must match qubit count for our QAE)
wind_size    = 4      # == n_qubits
wind_step    = 2

# Train/Test split on windows produced from the full series
split        = 0.75   # first 75% windows → train, last 25% → test

# Runs
INSTANCE_IDS = [1, 2, 3, 4, 5]
LAYER_OPTIONS = [1, 3]  # Stage-1/3 depth options

# Reset implementation for Stage-3:
#   'Jacob' → qml.measure(w, reset=True)  (keeps same wire count)
#   'swap'    → unitary SWAP to ancillas in |0>            (adds n_trash ancillas; enables adjoint on lightning)
RESET_MODE = 'swap'   # ← default approach

# Backends to use (you can keep both lightning; 'measure' may fall back from adjoint automatically)
STAGE1_BACKEND = 'lightning.qubit'
STAGE3_BACKEND = 'lightning.qubit'

# Logging
LOG_NAME = 'aintern'
CASE_NAME = 'half_qae'
DATA_PATH = f'{LOG_NAME}/data'
FIGURES_PATH = f'{LOG_NAME}/figures'
TRAIN_PATH = f'{LOG_NAME}/training'
PARAMS_PATH = f'{LOG_NAME}/params'
ANALYSIS_PATH = f'{LOG_NAME}/analysis'

# %%
# ===========================
# Cell 1 — Imports & utils
# ===========================
import os, sys, time, math, random, json
from pathlib import Path
import numpy as np
import pennylane as qml
from pennylane import numpy as pnp
import matplotlib.pyplot as plt

# repo utils
sys.path.append('.'); sys.path.append('..')
from qae_utils.Files import create_folder_if_needed, read_json_file, read_ts_file
from qae_utils.Window import ts_wind_make, ts_wind_split, ts_wind_flatten_avg
from qae_utils.Window import ts_add_noise
from qae_utils.Charts import multi_plot_flat_ts

# folders
for p in [FIGURES_PATH, TRAIN_PATH, PARAMS_PATH, ANALYSIS_PATH]:
    create_folder_if_needed(p)

# plotting
np.set_printoptions(suppress=True, precision=6)
plt.rcParams["figure.figsize"] = (6.5, 4)

def set_global_seed(instance_id: int):
    base = 10_000 + int(instance_id)
    random.seed(base + 11)
    np.random.seed(base + 22)
    try:
        pnp.random.seed(base + 33)
    except Exception:
        pass
    return dict(global_seed=base, numpy_seed=base+22, pnp_seed=base+33)

# %%
# ===========================
# Cell 2 — Load data & embed (robust paths)
# ===========================
import os

# keep your DATA_ID, LOG_NAME, DATA_PATH from Cell 0
# this resolver tries several roots so relative paths won't break
def _find_data_folder(data_id, log_name='aintern', preferred_root=None):
    candidates = []
    if preferred_root:
        candidates.append(preferred_root)
    # common locations
    candidates += [
        f'./{log_name}/data',
        f'../{log_name}/data',
        f'../../{log_name}/data',
        './jacobs_examples/aintern/data',
        '../jacobs_examples/aintern/data',
        '../../jacobs_examples/aintern/data',
    ]
    tried = []
    for root in candidates:
        folder = os.path.join(root, data_id)
        info_p = os.path.join(folder, 'info.json')
        x_p    = os.path.join(folder, 'x_org.arr')
        y_p    = os.path.join(folder, 'y_org.arr')
        tried.append(folder)
        if os.path.isdir(folder) and all(os.path.exists(p) for p in (info_p, x_p, y_p)):
            return folder
    raise FileNotFoundError(
        "Could not find dataset folder with required files.\n"
        f"DATA_ID='{data_id}'. Tried:\n - " + "\n - ".join(tried)
    )

# resolve the folder (uses your DATA_PATH from Cell 0 as a preference)
try:
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=DATA_PATH)
except Exception as e:
    # last resort: try without preferred_root
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=None)

data_info_path = f'{DATA_FOLDER}/info.json'
x_org_path     = f'{DATA_FOLDER}/x_org.arr'
y_org_path     = f'{DATA_FOLDER}/y_org.arr'

info = read_json_file(data_info_path)
X = read_ts_file(x_org_path).astype(int)  # indices (for plotting only)
y = read_ts_file(y_org_path)              # values (original domain)

scale_low  = float(info['scale_low'])
scale_high = float(info['scale_high'])
print(f'Using data folder: {DATA_FOLDER}')
print(f'Loaded {len(y)} samples; scale = [{scale_low:.3f}, {scale_high:.3f}]')

# quick plot (optional)
multi_plot_flat_ts([y], X_list=[0], colors=['blue'], labels=['Original'],
                   lines=['solid'], legend_cols=1, rcParams=(8, 3),
                   xlabel=f'Range (samples={len(y)})',
                   title=f'Data for model training (data=\"{DATA_ID}\")')

def embed_input(x, info_=None):
    """Map window values to RY(π·v01) with v01 from [scale_low, scale_high] → [0,1]."""
    if info_ is None: info_ = info
    lo, hi = float(info_['scale_low']), float(info_['scale_high'])
    xn = (pnp.array(x) - lo) / max(hi - lo, 1e-12)
    for i, v in enumerate(xn):
        qml.RY(v * pnp.pi, wires=i)
# Out:
# Using data folder: ../jacobs_examples/aintern/data/mackey_glass_tau17_n200
# Loaded 200 samples; scale = [0.200, 0.800]

# %%
# ===========================
# Cell 3 — Architecture (4q, 3 latent, 1 trash)
# ===========================
n_qubits = wind_size      # must equal window size
n_latent = 3
n_trash  = n_qubits - n_latent
trash_wires  = list(range(n_latent, n_qubits))  # [3] for 4q
signal_wires = list(range(n_qubits))            # diagnostics / full outputs

def make_device(nwires, backend='lightning.qubit'):
    return qml.device(backend, wires=nwires, shots=None)

def encoder_template(params, n_layers):
    """RX/RY/RZ per qubit + ring CNOT per layer."""
    assert len(params) == n_layers * n_qubits * 3
    for l in range(n_layers):
        for q in range(n_qubits):
            idx = l * n_qubits * 3 + q * 3
            qml.RX(params[idx + 0], wires=q)
            qml.RY(params[idx + 1], wires=q)
            qml.RZ(params[idx + 2], wires=q)
        for q in range(n_qubits - 1):
            qml.CNOT(wires=[q, q + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])

print(f"Architecture set: {n_qubits}q ({n_latent} latent, {n_trash} trash).")
# Out:
# Architecture set: 4q (3 latent, 1 trash).

# %%
# ===========================
# Cell 4 — Stage-1 training
# ===========================
def stage1_qnodes(n_layers):
    dev = make_device(n_qubits, backend=STAGE1_BACKEND)

    @qml.qnode(dev, interface="autograd", diff_method="adjoint")
    def trash_expectations(phi, x_clean):
        embed_input(x_clean)
        encoder_template(phi, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in trash_wires]

    return trash_expectations

def stage1_loss_on_windows(trash_expect, phi, windows_clean):
    # P(|1>) = (1 - Z)/2 on trash wires
    total = pnp.array(0.0)
    for w in windows_clean:
        z = pnp.array(trash_expect(phi, w))
        total = total + pnp.mean((1.0 - z) * 0.5)
    return total / max(len(windows_clean), 1)

def train_stage1_clean(windows_train_clean, n_layers, instance_id,
                       n_epochs=120, lr_init=0.010, patience=10, lr_patience=8):
    set_global_seed(instance_id)
    enc_shape = n_layers * n_qubits * 3
    phi = pnp.array(np.random.normal(0, 0.5, enc_shape), requires_grad=True)
    opt = qml.AdamOptimizer(stepsize=lr_init)
    lr = lr_init

    trash_expect = stage1_qnodes(n_layers)
    best_phi, best_cost = None, float("inf")
    no_improve = 0

    for ep in range(n_epochs):
        loss_fn = lambda p: stage1_loss_on_windows(trash_expect, p, windows_train_clean)
        phi, cost = opt.step_and_cost(loss_fn, phi)

        if cost < best_cost - 1e-9:
            best_cost, best_phi, no_improve = float(cost), pnp.array(phi, requires_grad=False), 0
        else:
            no_improve += 1
            if (no_improve % lr_patience) == 0:
                lr = max(lr * 0.5, 1e-4)
                opt = qml.AdamOptimizer(stepsize=lr)
                print(f"[Stage1] ↓ LR → {lr:.5f}")
            if no_improve >= patience:
                print("[Stage1] Early stopping."); break

        if ep % 5 == 0 or ep == n_epochs-1:
            print(f"[Stage1] L={n_layers} ep {ep:03d} | train {float(cost):.6f} | LR {lr:.5f}")

    return dict(phi=(best_phi if best_phi is not None else phi),
                best_train=float(best_cost))

# %%
# ===========================
# Cell 5 — Stage-3 QNodes
# ===========================
def stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET_MODE):

    need_anc = n_trash if (reset_mode == "swap" and n_trash > 0) else 0
    dev3 = make_device(n_qubits + need_anc)
    ancilla_wires = list(range(n_qubits, n_qubits + need_anc))

    theta_fixed = pnp.array(phi_stage1, requires_grad=False).reshape((n_layers, n_qubits, 3))

    def encoder_fixed_body(theta):
        for l in range(n_layers):
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=q)
                qml.RY(theta[l, q, 1], wires=q)
                qml.RZ(theta[l, q, 2], wires=q)
            for q in range(n_qubits-1):
                qml.CNOT(wires=[q, q+1])
            qml.CNOT(wires=[n_qubits-1, 0])

    def decoder_fixed():
        qml.adjoint(encoder_fixed_body)(theta_fixed)

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def encoder_only_expZ_all(flat_params, x_in):
        embed_input(x_in)
        encoder_template(flat_params, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def teacher_code_latents(x_clean):
        embed_input(x_clean)
        encoder_fixed_body(theta_fixed)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_latent)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def denoiser_qnode_all(flat_params, x_noisy):
        embed_input(x_noisy)
        encoder_template(flat_params, n_layers)

        # --- reset trash ---
        if n_trash > 0:
            if reset_mode == "Jacob":
                for w in trash_wires:
                    qml.measure(w, reset=True)
            elif reset_mode == "swap":
                # one clean ancilla per trash wire
                for t, a in zip(trash_wires, ancilla_wires):
                    # ancillas start in |0>, so SWAP puts |0> into trash, old trash into ancilla
                    qml.SWAP(wires=[t, a])

        decoder_fixed()
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    return dict(
        theta_fixed=theta_fixed,
        ancilla_wires=ancilla_wires,
        encoder_only_expZ_all=encoder_only_expZ_all,
        teacher_code_latents=teacher_code_latents,
        denoiser_qnode_all=denoiser_qnode_all
    )

def Z_to_values_autograd(z_all):
    z_all = pnp.clip(pnp.asarray(z_all), -0.999999, 0.999999)
    v01   = pnp.arccos(z_all) / pnp.pi
    return v01 * (scale_high - scale_low) + scale_low

def first_diff(x):
    x = pnp.array(x); return x[1:] - x[:-1]

def p1_from_expZ(z):
    return (1 - pnp.asarray(z)) * 0.5

def huber(residual, delta):
    r = pnp.abs(residual)
    return pnp.where(r <= delta, 0.5*r**2, delta*(r - 0.5*delta))

# %%
# ===========================
# Cell 6 — Noise & scoring helpers
# ===========================
def make_windows_from_series(y_vec, noise_sigma, seed, wind_size, wind_step):
    """
    Inject one noise vector into the whole series,
    then windowize both clean and noisy series the same way.
    """
    y_noisy = ts_add_noise(y_vec, noise=noise_sigma, noise_type='normal', clip=False,
                           range_low=scale_low, range_high=scale_high, seed=seed)

    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)

    # windows index array (not used by model, only for split helper)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])

    # split consistently
    X_tr, y_tr_clean, X_te, y_te_clean = ts_wind_split(X_ts, win_clean, split)
    X_tr, y_tr_noisy, X_te, y_te_noisy = ts_wind_split(X_ts, win_noisy, split)

    return (y_tr_clean, y_tr_noisy, y_te_clean, y_te_noisy)

def denoise_windows(params, denoise_qnode, windows_noisy):
    outs = []
    for w in windows_noisy:
        zD = pnp.array(denoise_qnode(params, w))
        outs.append(pnp.array(Z_to_values_autograd(zD)))
    return pnp.stack(outs)

def mse_on_windows(w_true, w_pred):
    w_true = np.asarray(w_true); w_pred = np.asarray(w_pred)
    return float(np.mean((w_true - w_pred)**2))

def mse_on_series_avg(w_true, w_pred, step):
    flat_true = ts_wind_flatten_avg(np.asarray(w_true), step)
    flat_pred = ts_wind_flatten_avg(np.asarray(w_pred), step)
    return float(np.mean((flat_true - flat_pred)**2))

# %%
# ===========================
# Cell 7 — Stage-3 (simple, fixed test seed, mini-batch)
# ===========================
def _series_to_train_test_windows(y_vec, sigma, seed):
    """Noise once → windowize → train/test split."""
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return np.asarray(tr_clean), np.asarray(tr_noisy), np.asarray(te_clean), np.asarray(te_noisy)

def _win_mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b)**2))

def _ser_mse(a, b):
    a = ts_wind_flatten_avg(np.asarray(a), wind_step)
    b = ts_wind_flatten_avg(np.asarray(b), wind_step)
    return float(np.mean((a - b)**2))

def train_stage3_series_noise_simple(
    y_full, phi_stage1, n_layers, instance_id,
    EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001, CLIP_NORM=1.0,
    USE_EMA=True, EMA_DECAY=0.995,
    TRAIN_SEED_BASE=88000, TEST_SEED_FIXED=99123,
    RESET=RESET_MODE,        # ← pass through
    BETA_TF=0.05,            # latent tug weight (teacher forcing)
    L_TV=0.02                # temporal smoothness weight
):
    set_global_seed(instance_id)
    handles = stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET)
    enc_all   = handles["encoder_only_expZ_all"]
    teacher_l = handles["teacher_code_latents"]
    denoise   = handles["denoiser_qnode_all"]

    # init ψ near φ
    phi_flat = pnp.array(phi_stage1, requires_grad=False)
    psi = pnp.array(np.array(phi_flat) + 0.05*np.random.randn(len(phi_flat)), requires_grad=True)

    opt = qml.AdamOptimizer(stepsize=LR)
    ema = pnp.array(psi, requires_grad=False) if USE_EMA else None

    hist_train_win_mse, hist_test_win_mse = [], []
    hist_train_ser_mse, hist_test_ser_mse = [], []

    def loss_on_batch(params, batch_clean, batch_noisy):
        total = pnp.array(0.0)
        for c, n in zip(batch_clean, batch_noisy):
            z_all = pnp.array(enc_all(params, n))
            z_sig, z_tr = z_all[:n_latent], z_all[n_latent:]
            zD   = pnp.array(denoise(params, n))
            vhat = Z_to_values_autograd(zD)

            L_rec = pnp.mean((pnp.array(c) - vhat)**2)
            L_tf  = pnp.mean(huber(pnp.array(teacher_l(c)) - z_sig, 0.25))
            L_tr  = pnp.mean(p1_from_expZ(z_tr))
            L_tv  = pnp.mean(huber(first_diff(c) - first_diff(vhat), 0.02))

            total = total + (L_rec + BETA_TF*L_tf + 0.5*L_tr + L_TV*L_tv)
        return total / max(len(batch_clean), 1)

    for ep in range(EPOCHS):
        # epoch-specific train noise
        tr_clean, tr_noisy, _, _ = make_windows_from_series(
            y_full, EVAL_SIGMA, TRAIN_SEED_BASE + ep, wind_size, wind_step
        )
        # fixed test noise
        _, _, te_clean, te_noisy = make_windows_from_series(
            y_full, EVAL_SIGMA, TEST_SEED_FIXED, wind_size, wind_step
        )

        # inner SGD steps with mini-batches
        for _ in range(INNER_STEPS):
            idx = np.random.randint(0, len(tr_clean), size=min(BATCH_SIZE, len(tr_clean)))
            batch_c = [tr_clean[i] for i in idx]
            batch_n = [tr_noisy[i] for i in idx]
            psi, _ = opt.step_and_cost(lambda p: loss_on_batch(p, batch_c, batch_n), psi)
            if USE_EMA:
                ema = EMA_DECAY * ema + (1 - EMA_DECAY) * psi

        eval_params = ema if USE_EMA else psi

        # ---- metrics
        tr_pred = denoise_windows(eval_params, denoise, tr_noisy)
        te_pred = denoise_windows(eval_params, denoise, te_noisy)

        train_mse_win = mse_on_windows(tr_clean, tr_pred)
        test_mse_win  = mse_on_windows(te_clean, te_pred)
        train_mse_ser = mse_on_series_avg(tr_clean, tr_pred, wind_step)
        test_mse_ser  = mse_on_series_avg(te_clean, te_pred, wind_step)

        hist_train_win_mse.append(float(train_mse_win))
        hist_test_win_mse.append(float(test_mse_win))
        hist_train_ser_mse.append(float(train_mse_ser))
        hist_test_ser_mse.append(float(test_mse_ser))

        print(f"[Stage3] L={n_layers} ep {ep:03d} | "
              f"train MSE(win) {train_mse_win:.5f} | "
              f"test MSE(win) {test_mse_win:.5f} | "
              f"test MSE(series) {test_mse_ser:.5f}")

    return dict(
        psi=(ema if USE_EMA else psi),
        hist_train_win_mse=hist_train_win_mse,
        hist_test_win_mse=hist_test_win_mse,
        hist_train_ser_mse=hist_train_ser_mse,
        hist_test_ser_mse=hist_test_ser_mse,
        TEST_SEED_FIXED=int(TEST_SEED_FIXED),
        RESET_MODE=str(RESET),
    )

# %%
# ===========================
# Cell 8 — Runs (instances × layers)
# ===========================
ALL_RUNS = []

for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        print("\n" + "="*30)
        print(f"Instance {inst} | Layers {L}")
        print("="*30)
        set_global_seed(inst)

        # ---- CLEAN windows once (for Stage-1 only)
        clean_windows = ts_wind_make(y, wind_size, wind_step)
        X_ts = np.array([i*wind_step for i in range(len(clean_windows))])
        _, win_tr_clean, _, win_te_clean = ts_wind_split(X_ts, clean_windows, split)
        print(f"[Windows] train={len(win_tr_clean)}, test={len(win_te_clean)} (W={wind_size}, step={wind_step})")

        # ---- Stage 1
        s1 = train_stage1_clean(
            win_tr_clean, n_layers=L, instance_id=inst,
            n_epochs=150, lr_init=0.010, patience=10, lr_patience=8
        )
        phi = s1["phi"]
        print(f"[Stage1] best train cost = {s1['best_train']:.6f}")

        # ---- Stage 3 (mentor-style reset by default)
        s3 = train_stage3_series_noise_simple(
                y_full=y, phi_stage1=phi, n_layers=L, instance_id=inst,
                EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001,
                RESET=RESET_MODE, BETA_TF=0.05, L_TV=0.02
        )

        # Final fixed-seed scoring (aligns with logs)
        seed_fix = s3.get("TEST_SEED_FIXED", 99123)
        trC, trN, teC, teN = _series_to_train_test_windows(y, EVAL_SIGMA, seed_fix)
        denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
        te_pred = denoise_windows(s3["psi"], denoise, teN)

        final_win = _win_mse(teC, te_pred)
        base_win  = _win_mse(teC, teN)
        final_ser = _ser_mse(teC, te_pred)
        base_ser  = _ser_mse(teC, teN)
        print(f"[Final TEST] MSE(win) {final_win:.6f} vs noisy {base_win:.6f} → Δ {100*(1-final_win/max(base_win,1e-12)):+.1f}%")
        print(f"[Final TEST] MSE(series) {final_ser:.6f} vs noisy {base_ser:.6f} → Δ {100*(1-final_ser/max(base_ser,1e-12)):+.1f}%")

        ALL_RUNS.append(dict(
            instance_id=inst, n_layers=L,
            stage1=dict(best_train=s1["best_train"], phi=np.array(phi)),
            stage3=dict(**s3)
        ))

print("\nCompleted", len(ALL_RUNS), "runs.")
# Out:
# ==============================
# Instance 1 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.511713 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.505082 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.498845 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.492422 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.485624 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.478115 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.469770 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.460831 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.451671 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.442573 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.433633 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.424863 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.416301 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.407994 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.399961 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.392206 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.384774 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.377800 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.371423 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.365700 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.360606 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.356076 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.352040 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.348432 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.345190 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.342267 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.339635 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.337277 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.335179 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.333326 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.332011 | LR 0.01000
# [Stage1] best train cost = 0.332011
# [Stage3] L=1 ep 000 | train MSE(win) 0.02036 | test MSE(win) 0.02178 | test MSE(series) 0.01960
# [Stage3] L=1 ep 001 | train MSE(win) 0.01897 | test MSE(win) 0.02178 | test MSE(series) 0.01960
# [Stage3] L=1 ep 002 | train MSE(win) 0.01972 | test MSE(win) 0.02178 | test MSE(series) 0.01960
# [Stage3] L=1 ep 003 | train MSE(win) 0.01806 | test MSE(win) 0.02178 | test MSE(series) 0.01960
# [Stage3] L=1 ep 004 | train MSE(win) 0.01797 | test MSE(win) 0.02178 | test MSE(series) 0.01959
# [Stage3] L=1 ep 005 | train MSE(win) 0.01993 | test MSE(win) 0.02178 | test MSE(series) 0.01959
# [Stage3] L=1 ep 006 | train MSE(win) 0.01909 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 007 | train MSE(win) 0.01867 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 008 | train MSE(win) 0.01921 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 009 | train MSE(win) 0.02026 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 010 | train MSE(win) 0.02034 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 011 | train MSE(win) 0.01841 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 012 | train MSE(win) 0.01986 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 013 | train MSE(win) 0.01909 | test MSE(win) 0.02177 | test MSE(series) 0.01959
# [Stage3] L=1 ep 014 | train MSE(win) 0.01927 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 015 | train MSE(win) 0.01943 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 016 | train MSE(win) 0.01868 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 017 | train MSE(win) 0.02027 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 018 | train MSE(win) 0.01877 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 019 | train MSE(win) 0.01985 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 020 | train MSE(win) 0.01975 | test MSE(win) 0.02177 | test MSE(series) 0.01958
# [Stage3] L=1 ep 021 | train MSE(win) 0.01862 | test MSE(win) 0.02176 | test MSE(series) 0.01958
# [Stage3] L=1 ep 022 | train MSE(win) 0.01936 | test MSE(win) 0.02176 | test MSE(series) 0.01958
# [Stage3] L=1 ep 023 | train MSE(win) 0.01914 | test MSE(win) 0.02176 | test MSE(series) 0.01958
# [Final TEST] MSE(win) 0.021763 vs noisy 0.019387 → Δ -12.3%
# [Final TEST] MSE(series) 0.019576 vs noisy 0.018958 → Δ -3.3%
#
# ==============================
# Instance 2 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.526659 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.519994 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.514263 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.509466 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.505519 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.502258 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.499452 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.496812 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.493983 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.490583 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.486308 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.481039 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.474815 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.467751 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.459961 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.451567 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.442730 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.433636 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.424454 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.415325 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.406397 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.397838 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.389810 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.382420 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.375686 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.369550 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.363926 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.358766 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.354072 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.349866 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.346861 | LR 0.01000
# [Stage1] best train cost = 0.346861
# [Stage3] L=1 ep 000 | train MSE(win) 0.02014 | test MSE(win) 0.02198 | test MSE(series) 0.01945
# [Stage3] L=1 ep 001 | train MSE(win) 0.02008 | test MSE(win) 0.02198 | test MSE(series) 0.01945
# [Stage3] L=1 ep 002 | train MSE(win) 0.02066 | test MSE(win) 0.02198 | test MSE(series) 0.01945
# [Stage3] L=1 ep 003 | train MSE(win) 0.01952 | test MSE(win) 0.02198 | test MSE(series) 0.01945
# [Stage3] L=1 ep 004 | train MSE(win) 0.01986 | test MSE(win) 0.02198 | test MSE(series) 0.01945
# [Stage3] L=1 ep 005 | train MSE(win) 0.02099 | test MSE(win) 0.02197 | test MSE(series) 0.01945
# [Stage3] L=1 ep 006 | train MSE(win) 0.02088 | test MSE(win) 0.02197 | test MSE(series) 0.01945
# [Stage3] L=1 ep 007 | train MSE(win) 0.01963 | test MSE(win) 0.02197 | test MSE(series) 0.01945
# [Stage3] L=1 ep 008 | train MSE(win) 0.01986 | test MSE(win) 0.02197 | test MSE(series) 0.01945
# [Stage3] L=1 ep 009 | train MSE(win) 0.01964 | test MSE(win) 0.02197 | test MSE(series) 0.01945
# [Stage3] L=1 ep 010 | train MSE(win) 0.02066 | test MSE(win) 0.02197 | test MSE(series) 0.01944
# [Stage3] L=1 ep 011 | train MSE(win) 0.01972 | test MSE(win) 0.02197 | test MSE(series) 0.01944
# [Stage3] L=1 ep 012 | train MSE(win) 0.01917 | test MSE(win) 0.02196 | test MSE(series) 0.01944
# [Stage3] L=1 ep 013 | train MSE(win) 0.01973 | test MSE(win) 0.02196 | test MSE(series) 0.01944
# [Stage3] L=1 ep 014 | train MSE(win) 0.01983 | test MSE(win) 0.02196 | test MSE(series) 0.01943
# [Stage3] L=1 ep 015 | train MSE(win) 0.01989 | test MSE(win) 0.02196 | test MSE(series) 0.01943
# [Stage3] L=1 ep 016 | train MSE(win) 0.01925 | test MSE(win) 0.02196 | test MSE(series) 0.01943
# [Stage3] L=1 ep 017 | train MSE(win) 0.02006 | test MSE(win) 0.02196 | test MSE(series) 0.01943
# [Stage3] L=1 ep 018 | train MSE(win) 0.01913 | test MSE(win) 0.02195 | test MSE(series) 0.01943
# [Stage3] L=1 ep 019 | train MSE(win) 0.02069 | test MSE(win) 0.02195 | test MSE(series) 0.01943
# [Stage3] L=1 ep 020 | train MSE(win) 0.02036 | test MSE(win) 0.02195 | test MSE(series) 0.01942
# [Stage3] L=1 ep 021 | train MSE(win) 0.01980 | test MSE(win) 0.02195 | test MSE(series) 0.01942
# [Stage3] L=1 ep 022 | train MSE(win) 0.02049 | test MSE(win) 0.02194 | test MSE(series) 0.01942
# [Stage3] L=1 ep 023 | train MSE(win) 0.02086 | test MSE(win) 0.02194 | test MSE(series) 0.01941
# [Final TEST] MSE(win) 0.021939 vs noisy 0.019387 → Δ -13.2%
# [Final TEST] MSE(series) 0.019413 vs noisy 0.018958 → Δ -2.4%
#
# ==============================
# Instance 3 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.517282 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.509200 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.501333 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.493776 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.486380 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.478883 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.471283 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.463749 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.456456 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.449505 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.442894 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.436559 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.430407 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.424298 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.418023 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.411360 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.404175 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.396511 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.388591 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.380762 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.373395 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.366779 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.361058 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.356212 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.352097 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.348511 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.345263 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.342232 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.339377 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.336711 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.334738 | LR 0.01000
# [Stage1] best train cost = 0.334738
# [Stage3] L=1 ep 000 | train MSE(win) 0.02071 | test MSE(win) 0.02268 | test MSE(series) 0.02074
# [Stage3] L=1 ep 001 | train MSE(win) 0.02064 | test MSE(win) 0.02268 | test MSE(series) 0.02073
# [Stage3] L=1 ep 002 | train MSE(win) 0.02103 | test MSE(win) 0.02268 | test MSE(series) 0.02073
# [Stage3] L=1 ep 003 | train MSE(win) 0.02033 | test MSE(win) 0.02267 | test MSE(series) 0.02073
# [Stage3] L=1 ep 004 | train MSE(win) 0.02021 | test MSE(win) 0.02267 | test MSE(series) 0.02073
# [Stage3] L=1 ep 005 | train MSE(win) 0.02161 | test MSE(win) 0.02267 | test MSE(series) 0.02072
# [Stage3] L=1 ep 006 | train MSE(win) 0.02171 | test MSE(win) 0.02266 | test MSE(series) 0.02072
# [Stage3] L=1 ep 007 | train MSE(win) 0.02028 | test MSE(win) 0.02266 | test MSE(series) 0.02071
# [Stage3] L=1 ep 008 | train MSE(win) 0.02059 | test MSE(win) 0.02265 | test MSE(series) 0.02071
# [Stage3] L=1 ep 009 | train MSE(win) 0.02019 | test MSE(win) 0.02265 | test MSE(series) 0.02070
# [Stage3] L=1 ep 010 | train MSE(win) 0.02119 | test MSE(win) 0.02264 | test MSE(series) 0.02070
# [Stage3] L=1 ep 011 | train MSE(win) 0.02037 | test MSE(win) 0.02264 | test MSE(series) 0.02069
# [Stage3] L=1 ep 012 | train MSE(win) 0.02036 | test MSE(win) 0.02263 | test MSE(series) 0.02068
# [Stage3] L=1 ep 013 | train MSE(win) 0.02006 | test MSE(win) 0.02262 | test MSE(series) 0.02067
# [Stage3] L=1 ep 014 | train MSE(win) 0.02038 | test MSE(win) 0.02262 | test MSE(series) 0.02067
# [Stage3] L=1 ep 015 | train MSE(win) 0.02027 | test MSE(win) 0.02261 | test MSE(series) 0.02066
# [Stage3] L=1 ep 016 | train MSE(win) 0.02014 | test MSE(win) 0.02260 | test MSE(series) 0.02065
# [Stage3] L=1 ep 017 | train MSE(win) 0.02074 | test MSE(win) 0.02259 | test MSE(series) 0.02064
# [Stage3] L=1 ep 018 | train MSE(win) 0.01971 | test MSE(win) 0.02259 | test MSE(series) 0.02064
# [Stage3] L=1 ep 019 | train MSE(win) 0.02122 | test MSE(win) 0.02258 | test MSE(series) 0.02063
# [Stage3] L=1 ep 020 | train MSE(win) 0.02109 | test MSE(win) 0.02257 | test MSE(series) 0.02062
# [Stage3] L=1 ep 021 | train MSE(win) 0.02026 | test MSE(win) 0.02256 | test MSE(series) 0.02061
# [Stage3] L=1 ep 022 | train MSE(win) 0.02100 | test MSE(win) 0.02256 | test MSE(series) 0.02060
# [Stage3] L=1 ep 023 | train MSE(win) 0.02162 | test MSE(win) 0.02255 | test MSE(series) 0.02059
# [Final TEST] MSE(win) 0.022546 vs noisy 0.019387 → Δ -16.3%
# [Final TEST] MSE(series) 0.020592 vs noisy 0.018958 → Δ -8.6%
#
# ==============================
# Instance 4 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.523293 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.514839 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.506926 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.499850 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.493621 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.487975 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.482499 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.476698 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.470155 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.462652 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.454171 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.444851 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.434929 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.424678 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.414381 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.404319 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.394730 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.385796 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.377682 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.370540 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.364460 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.359438 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.355410 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.352298 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.350013 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.348441 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.347443 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.346865 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.346564 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.346425 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.346377 | LR 0.01000
# [Stage1] best train cost = 0.346377
# [Stage3] L=1 ep 000 | train MSE(win) 0.02194 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 001 | train MSE(win) 0.02194 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 002 | train MSE(win) 0.02204 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 003 | train MSE(win) 0.02172 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 004 | train MSE(win) 0.02135 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 005 | train MSE(win) 0.02274 | test MSE(win) 0.02280 | test MSE(series) 0.02156
# [Stage3] L=1 ep 006 | train MSE(win) 0.02263 | test MSE(win) 0.02279 | test MSE(series) 0.02156
# [Stage3] L=1 ep 007 | train MSE(win) 0.02179 | test MSE(win) 0.02279 | test MSE(series) 0.02156
# [Stage3] L=1 ep 008 | train MSE(win) 0.02173 | test MSE(win) 0.02279 | test MSE(series) 0.02156
# [Stage3] L=1 ep 009 | train MSE(win) 0.02145 | test MSE(win) 0.02279 | test MSE(series) 0.02156
# [Stage3] L=1 ep 010 | train MSE(win) 0.02224 | test MSE(win) 0.02279 | test MSE(series) 0.02156
# [Stage3] L=1 ep 011 | train MSE(win) 0.02184 | test MSE(win) 0.02279 | test MSE(series) 0.02155
# [Stage3] L=1 ep 012 | train MSE(win) 0.02173 | test MSE(win) 0.02278 | test MSE(series) 0.02155
# [Stage3] L=1 ep 013 | train MSE(win) 0.02155 | test MSE(win) 0.02278 | test MSE(series) 0.02155
# [Stage3] L=1 ep 014 | train MSE(win) 0.02145 | test MSE(win) 0.02278 | test MSE(series) 0.02154
# [Stage3] L=1 ep 015 | train MSE(win) 0.02166 | test MSE(win) 0.02277 | test MSE(series) 0.02154
# [Stage3] L=1 ep 016 | train MSE(win) 0.02157 | test MSE(win) 0.02277 | test MSE(series) 0.02154
# [Stage3] L=1 ep 017 | train MSE(win) 0.02198 | test MSE(win) 0.02277 | test MSE(series) 0.02153
# [Stage3] L=1 ep 018 | train MSE(win) 0.02128 | test MSE(win) 0.02276 | test MSE(series) 0.02153
# [Stage3] L=1 ep 019 | train MSE(win) 0.02253 | test MSE(win) 0.02276 | test MSE(series) 0.02153
# [Stage3] L=1 ep 020 | train MSE(win) 0.02221 | test MSE(win) 0.02275 | test MSE(series) 0.02152
# [Stage3] L=1 ep 021 | train MSE(win) 0.02185 | test MSE(win) 0.02275 | test MSE(series) 0.02152
# [Stage3] L=1 ep 022 | train MSE(win) 0.02259 | test MSE(win) 0.02274 | test MSE(series) 0.02151
# [Stage3] L=1 ep 023 | train MSE(win) 0.02268 | test MSE(win) 0.02274 | test MSE(series) 0.02151
# [Final TEST] MSE(win) 0.022738 vs noisy 0.019387 → Δ -17.3%
# [Final TEST] MSE(series) 0.021507 vs noisy 0.018958 → Δ -13.4%
#
# ==============================
# Instance 5 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.508570 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.504941 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.502131 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.499965 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.497917 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.495552 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.492707 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.489242 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.484945 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.479495 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.472633 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.464295 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.454623 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.443944 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.432722 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.421451 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.410546 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.400298 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.390940 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.382662 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.375547 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.369531 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.364469 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.360221 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.356688 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.353793 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.351463 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.349618 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.348176 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.347056 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.346343 | LR 0.01000
# [Stage1] best train cost = 0.346343
# [Stage3] L=1 ep 000 | train MSE(win) 0.02171 | test MSE(win) 0.02168 | test MSE(series) 0.02041
# [Stage3] L=1 ep 001 | train MSE(win) 0.02027 | test MSE(win) 0.02168 | test MSE(series) 0.02041
# [Stage3] L=1 ep 002 | train MSE(win) 0.02066 | test MSE(win) 0.02167 | test MSE(series) 0.02041
# [Stage3] L=1 ep 003 | train MSE(win) 0.01988 | test MSE(win) 0.02167 | test MSE(series) 0.02041
# [Stage3] L=1 ep 004 | train MSE(win) 0.01896 | test MSE(win) 0.02167 | test MSE(series) 0.02041
# [Stage3] L=1 ep 005 | train MSE(win) 0.02123 | test MSE(win) 0.02167 | test MSE(series) 0.02041
# [Stage3] L=1 ep 006 | train MSE(win) 0.02024 | test MSE(win) 0.02167 | test MSE(series) 0.02040
# [Stage3] L=1 ep 007 | train MSE(win) 0.02047 | test MSE(win) 0.02167 | test MSE(series) 0.02040
# [Stage3] L=1 ep 008 | train MSE(win) 0.02043 | test MSE(win) 0.02167 | test MSE(series) 0.02040
# [Stage3] L=1 ep 009 | train MSE(win) 0.02078 | test MSE(win) 0.02167 | test MSE(series) 0.02040
# [Stage3] L=1 ep 010 | train MSE(win) 0.02152 | test MSE(win) 0.02166 | test MSE(series) 0.02039
# [Stage3] L=1 ep 011 | train MSE(win) 0.01984 | test MSE(win) 0.02166 | test MSE(series) 0.02039
# [Stage3] L=1 ep 012 | train MSE(win) 0.02129 | test MSE(win) 0.02166 | test MSE(series) 0.02039
# [Stage3] L=1 ep 013 | train MSE(win) 0.02104 | test MSE(win) 0.02166 | test MSE(series) 0.02038
# [Stage3] L=1 ep 014 | train MSE(win) 0.02096 | test MSE(win) 0.02166 | test MSE(series) 0.02038
# [Stage3] L=1 ep 015 | train MSE(win) 0.02157 | test MSE(win) 0.02165 | test MSE(series) 0.02038
# [Stage3] L=1 ep 016 | train MSE(win) 0.02008 | test MSE(win) 0.02165 | test MSE(series) 0.02037
# [Stage3] L=1 ep 017 | train MSE(win) 0.02104 | test MSE(win) 0.02165 | test MSE(series) 0.02037
# [Stage3] L=1 ep 018 | train MSE(win) 0.02049 | test MSE(win) 0.02165 | test MSE(series) 0.02037
# [Stage3] L=1 ep 019 | train MSE(win) 0.02086 | test MSE(win) 0.02165 | test MSE(series) 0.02036
# [Stage3] L=1 ep 020 | train MSE(win) 0.02045 | test MSE(win) 0.02164 | test MSE(series) 0.02036
# [Stage3] L=1 ep 021 | train MSE(win) 0.02032 | test MSE(win) 0.02164 | test MSE(series) 0.02035
# [Stage3] L=1 ep 022 | train MSE(win) 0.02034 | test MSE(win) 0.02164 | test MSE(series) 0.02035
# [Stage3] L=1 ep 023 | train MSE(win) 0.01988 | test MSE(win) 0.02164 | test MSE(series) 0.02035
# [Final TEST] MSE(win) 0.021636 vs noisy 0.019387 → Δ -11.6%
# [Final TEST] MSE(series) 0.020346 vs noisy 0.018958 → Δ -7.3%
#
# ==============================
# Instance 1 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.474155 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.412353 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.365069 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.333725 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.310230 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.287135 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.263318 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.240370 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.219671 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.201685 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.186099 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.171865 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.158234 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.145178 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.133142 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.122736 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.114411 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.108233 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.103824 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.100575 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.097938 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.095590 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.093399 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.091294 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.089216 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.087127 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.085022 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.082918 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.080833 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.078778 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.077150 | LR 0.01000
# [Stage1] best train cost = 0.077150
# [Stage3] L=3 ep 000 | train MSE(win) 0.01078 | test MSE(win) 0.01259 | test MSE(series) 0.01149
# [Stage3] L=3 ep 001 | train MSE(win) 0.00982 | test MSE(win) 0.01259 | test MSE(series) 0.01149
# [Stage3] L=3 ep 002 | train MSE(win) 0.01054 | test MSE(win) 0.01259 | test MSE(series) 0.01149
# [Stage3] L=3 ep 003 | train MSE(win) 0.00856 | test MSE(win) 0.01259 | test MSE(series) 0.01149
# [Stage3] L=3 ep 004 | train MSE(win) 0.00933 | test MSE(win) 0.01260 | test MSE(series) 0.01149
# [Stage3] L=3 ep 005 | train MSE(win) 0.01057 | test MSE(win) 0.01260 | test MSE(series) 0.01149
# [Stage3] L=3 ep 006 | train MSE(win) 0.01073 | test MSE(win) 0.01260 | test MSE(series) 0.01149
# [Stage3] L=3 ep 007 | train MSE(win) 0.01004 | test MSE(win) 0.01260 | test MSE(series) 0.01149
# [Stage3] L=3 ep 008 | train MSE(win) 0.00931 | test MSE(win) 0.01261 | test MSE(series) 0.01150
# [Stage3] L=3 ep 009 | train MSE(win) 0.01068 | test MSE(win) 0.01261 | test MSE(series) 0.01150
# [Stage3] L=3 ep 010 | train MSE(win) 0.01190 | test MSE(win) 0.01262 | test MSE(series) 0.01150
# [Stage3] L=3 ep 011 | train MSE(win) 0.00988 | test MSE(win) 0.01262 | test MSE(series) 0.01150
# [Stage3] L=3 ep 012 | train MSE(win) 0.01127 | test MSE(win) 0.01263 | test MSE(series) 0.01151
# [Stage3] L=3 ep 013 | train MSE(win) 0.01010 | test MSE(win) 0.01263 | test MSE(series) 0.01151
# [Stage3] L=3 ep 014 | train MSE(win) 0.00943 | test MSE(win) 0.01264 | test MSE(series) 0.01151
# [Stage3] L=3 ep 015 | train MSE(win) 0.01017 | test MSE(win) 0.01265 | test MSE(series) 0.01151
# [Stage3] L=3 ep 016 | train MSE(win) 0.01052 | test MSE(win) 0.01266 | test MSE(series) 0.01152
# [Stage3] L=3 ep 017 | train MSE(win) 0.01134 | test MSE(win) 0.01266 | test MSE(series) 0.01152
# [Stage3] L=3 ep 018 | train MSE(win) 0.00911 | test MSE(win) 0.01267 | test MSE(series) 0.01153
# [Stage3] L=3 ep 019 | train MSE(win) 0.01020 | test MSE(win) 0.01268 | test MSE(series) 0.01153
# [Stage3] L=3 ep 020 | train MSE(win) 0.01080 | test MSE(win) 0.01268 | test MSE(series) 0.01153
# [Stage3] L=3 ep 021 | train MSE(win) 0.01068 | test MSE(win) 0.01269 | test MSE(series) 0.01154
# [Stage3] L=3 ep 022 | train MSE(win) 0.01079 | test MSE(win) 0.01270 | test MSE(series) 0.01154
# [Stage3] L=3 ep 023 | train MSE(win) 0.00965 | test MSE(win) 0.01271 | test MSE(series) 0.01155
# [Final TEST] MSE(win) 0.012709 vs noisy 0.019387 → Δ +34.4%
# [Final TEST] MSE(series) 0.011546 vs noisy 0.018958 → Δ +39.1%
#
# ==============================
# Instance 2 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.533306 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.469821 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.404187 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.343412 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.291125 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.247566 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.214237 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.190353 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.171829 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.154960 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.138095 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.122484 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.110203 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.101258 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.094175 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.088215 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.083255 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.079162 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.075739 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.072785 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.070196 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.067904 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.065839 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.063941 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.062164 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.060477 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.058849 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.057243 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.055617 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.053934 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.052521 | LR 0.01000
# [Stage1] best train cost = 0.052521
# [Stage3] L=3 ep 000 | train MSE(win) 0.00935 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 001 | train MSE(win) 0.00864 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 002 | train MSE(win) 0.00956 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 003 | train MSE(win) 0.00720 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 004 | train MSE(win) 0.00853 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 005 | train MSE(win) 0.00952 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 006 | train MSE(win) 0.00947 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 007 | train MSE(win) 0.00937 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 008 | train MSE(win) 0.00819 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 009 | train MSE(win) 0.00922 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 010 | train MSE(win) 0.01031 | test MSE(win) 0.01163 | test MSE(series) 0.01096
# [Stage3] L=3 ep 011 | train MSE(win) 0.00904 | test MSE(win) 0.01163 | test MSE(series) 0.01097
# [Stage3] L=3 ep 012 | train MSE(win) 0.01000 | test MSE(win) 0.01163 | test MSE(series) 0.01096
# [Stage3] L=3 ep 013 | train MSE(win) 0.00876 | test MSE(win) 0.01163 | test MSE(series) 0.01096
# [Stage3] L=3 ep 014 | train MSE(win) 0.00777 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 015 | train MSE(win) 0.00868 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 016 | train MSE(win) 0.00951 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 017 | train MSE(win) 0.01035 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 018 | train MSE(win) 0.00777 | test MSE(win) 0.01162 | test MSE(series) 0.01096
# [Stage3] L=3 ep 019 | train MSE(win) 0.00919 | test MSE(win) 0.01162 | test MSE(series) 0.01095
# [Stage3] L=3 ep 020 | train MSE(win) 0.00966 | test MSE(win) 0.01161 | test MSE(series) 0.01095
# [Stage3] L=3 ep 021 | train MSE(win) 0.00956 | test MSE(win) 0.01161 | test MSE(series) 0.01095
# [Stage3] L=3 ep 022 | train MSE(win) 0.00931 | test MSE(win) 0.01160 | test MSE(series) 0.01094
# [Stage3] L=3 ep 023 | train MSE(win) 0.00899 | test MSE(win) 0.01160 | test MSE(series) 0.01094
# [Final TEST] MSE(win) 0.011599 vs noisy 0.019387 → Δ +40.2%
# [Final TEST] MSE(series) 0.010939 vs noisy 0.018958 → Δ +42.3%
#
# ==============================
# Instance 3 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.488445 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.445296 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.412561 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.382372 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.354554 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.329068 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.302797 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.274125 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.243128 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.211471 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.181798 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.156679 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.137475 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.123317 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.112365 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.103443 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.096427 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.091408 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.087965 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.085417 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.083350 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.081629 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.080185 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.078953 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.077881 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.076941 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.076112 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.075380 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.074736 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.074163 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.073744 | LR 0.01000
# [Stage1] best train cost = 0.073744
# [Stage3] L=3 ep 000 | train MSE(win) 0.00962 | test MSE(win) 0.01189 | test MSE(series) 0.01143
# [Stage3] L=3 ep 001 | train MSE(win) 0.00926 | test MSE(win) 0.01189 | test MSE(series) 0.01143
# [Stage3] L=3 ep 002 | train MSE(win) 0.00955 | test MSE(win) 0.01189 | test MSE(series) 0.01143
# [Stage3] L=3 ep 003 | train MSE(win) 0.00775 | test MSE(win) 0.01189 | test MSE(series) 0.01144
# [Stage3] L=3 ep 004 | train MSE(win) 0.00884 | test MSE(win) 0.01189 | test MSE(series) 0.01144
# [Stage3] L=3 ep 005 | train MSE(win) 0.01000 | test MSE(win) 0.01189 | test MSE(series) 0.01144
# [Stage3] L=3 ep 006 | train MSE(win) 0.00972 | test MSE(win) 0.01189 | test MSE(series) 0.01144
# [Stage3] L=3 ep 007 | train MSE(win) 0.00929 | test MSE(win) 0.01190 | test MSE(series) 0.01144
# [Stage3] L=3 ep 008 | train MSE(win) 0.00869 | test MSE(win) 0.01190 | test MSE(series) 0.01144
# [Stage3] L=3 ep 009 | train MSE(win) 0.00950 | test MSE(win) 0.01190 | test MSE(series) 0.01144
# [Stage3] L=3 ep 010 | train MSE(win) 0.01078 | test MSE(win) 0.01190 | test MSE(series) 0.01144
# [Stage3] L=3 ep 011 | train MSE(win) 0.00902 | test MSE(win) 0.01191 | test MSE(series) 0.01144
# [Stage3] L=3 ep 012 | train MSE(win) 0.01013 | test MSE(win) 0.01191 | test MSE(series) 0.01145
# [Stage3] L=3 ep 013 | train MSE(win) 0.00924 | test MSE(win) 0.01191 | test MSE(series) 0.01145
# [Stage3] L=3 ep 014 | train MSE(win) 0.00838 | test MSE(win) 0.01192 | test MSE(series) 0.01145
# [Stage3] L=3 ep 015 | train MSE(win) 0.00902 | test MSE(win) 0.01192 | test MSE(series) 0.01145
# [Stage3] L=3 ep 016 | train MSE(win) 0.00936 | test MSE(win) 0.01192 | test MSE(series) 0.01145
# [Stage3] L=3 ep 017 | train MSE(win) 0.01050 | test MSE(win) 0.01192 | test MSE(series) 0.01145
# [Stage3] L=3 ep 018 | train MSE(win) 0.00826 | test MSE(win) 0.01193 | test MSE(series) 0.01145
# [Stage3] L=3 ep 019 | train MSE(win) 0.00911 | test MSE(win) 0.01193 | test MSE(series) 0.01145
# [Stage3] L=3 ep 020 | train MSE(win) 0.00965 | test MSE(win) 0.01193 | test MSE(series) 0.01146
# [Stage3] L=3 ep 021 | train MSE(win) 0.00974 | test MSE(win) 0.01193 | test MSE(series) 0.01146
# [Stage3] L=3 ep 022 | train MSE(win) 0.00996 | test MSE(win) 0.01193 | test MSE(series) 0.01146
# [Stage3] L=3 ep 023 | train MSE(win) 0.00895 | test MSE(win) 0.01193 | test MSE(series) 0.01146
# [Final TEST] MSE(win) 0.011935 vs noisy 0.019387 → Δ +38.4%
# [Final TEST] MSE(series) 0.011456 vs noisy 0.018958 → Δ +39.6%
#
# ==============================
# Instance 4 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.501104 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.456311 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.412318 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.369110 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.328647 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.291755 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.259281 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.232260 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.210367 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.192257 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.176997 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.164525 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.154493 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.146429 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.139916 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.134407 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.129485 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.125037 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.121101 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.117621 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.114405 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.111226 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.107926 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.104459 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.100884 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.097340 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.094013 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.091050 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.088479 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.086189 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.084436 | LR 0.01000
# [Stage1] best train cost = 0.084436
# [Stage3] L=3 ep 000 | train MSE(win) 0.00928 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 001 | train MSE(win) 0.00818 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 002 | train MSE(win) 0.00939 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 003 | train MSE(win) 0.00730 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 004 | train MSE(win) 0.00833 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 005 | train MSE(win) 0.00925 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 006 | train MSE(win) 0.00954 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 007 | train MSE(win) 0.00879 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 008 | train MSE(win) 0.00824 | test MSE(win) 0.01301 | test MSE(series) 0.01262
# [Stage3] L=3 ep 009 | train MSE(win) 0.00911 | test MSE(win) 0.01300 | test MSE(series) 0.01262
# [Stage3] L=3 ep 010 | train MSE(win) 0.01011 | test MSE(win) 0.01300 | test MSE(series) 0.01261
# [Stage3] L=3 ep 011 | train MSE(win) 0.00882 | test MSE(win) 0.01300 | test MSE(series) 0.01261
# [Stage3] L=3 ep 012 | train MSE(win) 0.00976 | test MSE(win) 0.01300 | test MSE(series) 0.01261
# [Stage3] L=3 ep 013 | train MSE(win) 0.00834 | test MSE(win) 0.01300 | test MSE(series) 0.01261
# [Stage3] L=3 ep 014 | train MSE(win) 0.00830 | test MSE(win) 0.01299 | test MSE(series) 0.01261
# [Stage3] L=3 ep 015 | train MSE(win) 0.00881 | test MSE(win) 0.01299 | test MSE(series) 0.01260
# [Stage3] L=3 ep 016 | train MSE(win) 0.00934 | test MSE(win) 0.01299 | test MSE(series) 0.01260
# [Stage3] L=3 ep 017 | train MSE(win) 0.01059 | test MSE(win) 0.01299 | test MSE(series) 0.01260
# [Stage3] L=3 ep 018 | train MSE(win) 0.00786 | test MSE(win) 0.01299 | test MSE(series) 0.01260
# [Stage3] L=3 ep 019 | train MSE(win) 0.00914 | test MSE(win) 0.01298 | test MSE(series) 0.01260
# [Stage3] L=3 ep 020 | train MSE(win) 0.00920 | test MSE(win) 0.01298 | test MSE(series) 0.01259
# [Stage3] L=3 ep 021 | train MSE(win) 0.00940 | test MSE(win) 0.01298 | test MSE(series) 0.01259
# [Stage3] L=3 ep 022 | train MSE(win) 0.00976 | test MSE(win) 0.01297 | test MSE(series) 0.01258
# [Stage3] L=3 ep 023 | train MSE(win) 0.00890 | test MSE(win) 0.01297 | test MSE(series) 0.01258
# [Final TEST] MSE(win) 0.012966 vs noisy 0.019387 → Δ +33.1%
# [Final TEST] MSE(series) 0.012580 vs noisy 0.018958 → Δ +33.6%
#
# ==============================
# Instance 5 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.644745 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.580967 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.512150 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.443314 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.381128 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.328841 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.284548 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.246988 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.216879 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.193218 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.173126 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.154407 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.136849 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.121187 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.108063 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.097716 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.089991 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.084493 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.080740 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.078213 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.076433 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.075070 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.073957 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.073015 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.072197 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.071465 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.070799 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.070190 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.069629 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.069108 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.068717 | LR 0.01000
# [Stage1] best train cost = 0.068717
# [Stage3] L=3 ep 000 | train MSE(win) 0.00947 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 001 | train MSE(win) 0.00879 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 002 | train MSE(win) 0.00989 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 003 | train MSE(win) 0.00750 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 004 | train MSE(win) 0.00838 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 005 | train MSE(win) 0.00954 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 006 | train MSE(win) 0.00966 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 007 | train MSE(win) 0.00938 | test MSE(win) 0.01249 | test MSE(series) 0.01202
# [Stage3] L=3 ep 008 | train MSE(win) 0.00839 | test MSE(win) 0.01250 | test MSE(series) 0.01202
# [Stage3] L=3 ep 009 | train MSE(win) 0.00974 | test MSE(win) 0.01250 | test MSE(series) 0.01203
# [Stage3] L=3 ep 010 | train MSE(win) 0.01028 | test MSE(win) 0.01250 | test MSE(series) 0.01203
# [Stage3] L=3 ep 011 | train MSE(win) 0.00909 | test MSE(win) 0.01250 | test MSE(series) 0.01203
# [Stage3] L=3 ep 012 | train MSE(win) 0.01014 | test MSE(win) 0.01250 | test MSE(series) 0.01203
# [Stage3] L=3 ep 013 | train MSE(win) 0.00850 | test MSE(win) 0.01251 | test MSE(series) 0.01203
# [Stage3] L=3 ep 014 | train MSE(win) 0.00805 | test MSE(win) 0.01251 | test MSE(series) 0.01204
# [Stage3] L=3 ep 015 | train MSE(win) 0.00881 | test MSE(win) 0.01251 | test MSE(series) 0.01204
# [Stage3] L=3 ep 016 | train MSE(win) 0.00960 | test MSE(win) 0.01252 | test MSE(series) 0.01205
# [Stage3] L=3 ep 017 | train MSE(win) 0.01069 | test MSE(win) 0.01252 | test MSE(series) 0.01205
# [Stage3] L=3 ep 018 | train MSE(win) 0.00804 | test MSE(win) 0.01253 | test MSE(series) 0.01205
# [Stage3] L=3 ep 019 | train MSE(win) 0.00932 | test MSE(win) 0.01253 | test MSE(series) 0.01206
# [Stage3] L=3 ep 020 | train MSE(win) 0.00954 | test MSE(win) 0.01253 | test MSE(series) 0.01206
# [Stage3] L=3 ep 021 | train MSE(win) 0.00932 | test MSE(win) 0.01254 | test MSE(series) 0.01207
# [Stage3] L=3 ep 022 | train MSE(win) 0.00922 | test MSE(win) 0.01254 | test MSE(series) 0.01207
# [Stage3] L=3 ep 023 | train MSE(win) 0.00881 | test MSE(win) 0.01255 | test MSE(series) 0.01208
# [Final TEST] MSE(win) 0.012548 vs noisy 0.019387 → Δ +35.3%
# [Final TEST] MSE(series) 0.012076 vs noisy 0.018958 → Δ +36.3%
#
# Completed 10 runs.

# %%
# ===============================
# Cell 9 — final plots & stats for all instances
# ===============================
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

ARCH_TAG = f"{n_qubits}q_{n_latent}l_{n_trash}t"
SAVE_PLOTS = True  # set False if you don't want PNGs on disk

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _seed_for_run(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3:
        return int(s3["TEST_SEED_FIXED"])
    hist = s3.get("hist_train", [])
    return 88_000 + 100*instance_id + (len(hist) - 1 if len(hist) else 0)

def plot_one(run, save_dir=None, title_note=""):
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    seed = _seed_for_run(run, inst)

    denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed)
    tr_rec = denoise_windows(psi, denoise, tr_n)
    te_rec = denoise_windows(psi, denoise, te_n)

    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_rec);te_hat  = _flatten_avg(te_rec)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    x_tr = np.arange(len(tr_pure)); x_te = np.arange(len(tr_pure), len(tr_pure)+len(te_pure))
    x_split = len(tr_pure)

    plt.figure(figsize=(12, 6))
    plt.scatter(x_tr, tr_noi, s=10, alpha=0.55, label=f"Train Noise (MSE={mse_tr_noise:0.5f})")
    plt.scatter(x_te, te_noi, s=10, alpha=0.55, label=f"Test  Noise (MSE={mse_te_noise:0.5f})")
    plt.plot(x_tr, tr_pure, linewidth=1.8, label="Train Pure")
    plt.plot(x_te, te_pure, linewidth=1.8, label="Test Pure")
    plt.plot(x_tr, tr_hat, linestyle="--", linewidth=2.0, label=f"Train Recovered (MSE={mse_tr_hat:0.5f})")
    plt.plot(x_te, te_hat, linestyle="--", linewidth=2.0, label=f"Test  Recovered (MSE={mse_te_hat:0.5f})")
    plt.axvline(x_split, color="grey", linestyle="--", alpha=0.7)
    plt.ylim(scale_low - 0.05*(scale_high - scale_low), scale_high + 0.05*(scale_high - scale_low))
    plt.xlabel(f'Range (samples={len(y)}, window size={wind_size}, step={wind_step})')
    plt.title(f'Pure vs Recovered (data=\"{DATA_ID}\", σ={EVAL_SIGMA:.3f}, '
              f'W={wind_size}, step={wind_step}, L={L}, inst={inst}) {title_note}')
    plt.legend(loc="upper center", ncol=3, frameon=False)
    plt.tight_layout()

    if SAVE_PLOTS and save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        out_png = Path(save_dir) / f"plot_{ARCH_TAG}_L{L}_inst{inst:02d}.png"
        plt.savefig(out_png, dpi=200, bbox_inches="tight", pad_inches=0.08)
        print(f"Saved plot → {out_png}")
    plt.show()

    dtr = 100*(1 - mse_tr_hat/max(mse_tr_noise,1e-12))
    dte = 100*(1 - mse_te_hat/max(mse_te_noise,1e-12))
    print(f"[Series-avg] TRAIN: noise={mse_tr_noise:0.8f}  recovered={mse_tr_hat:0.8f}  Δ={dtr:+.1f}%")
    print(f"[Series-avg] TEST : noise={mse_te_noise:0.8f}  recovered={mse_te_hat:0.8f}  Δ={dte:+.1f}%")

# -- Run plots for every trained (instance, L)
for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        if any(r["n_layers"] == L and r["instance_id"] == inst for r in ALL_RUNS):
            run = next(r for r in ALL_RUNS if r["n_layers"] == L and r["instance_id"] == inst)
            print(f"\n=== Final plot for L={L}, inst={inst} ===")
            plot_one(run, save_dir=f"{FIGURES_PATH}/final/{ARCH_TAG}/L{L}")
# Out:
# === Final plot for L=1, inst=1 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01896122  Δ=+1.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01957572  Δ=-3.3%
#
# === Final plot for L=1, inst=2 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01846705  Δ=+4.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01941300  Δ=-2.4%
#
# === Final plot for L=1, inst=3 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01965775  Δ=-2.0%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02059160  Δ=-8.6%
#
# === Final plot for L=1, inst=4 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02135918  Δ=-10.9%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02150658  Δ=-13.4%
#
# === Final plot for L=1, inst=5 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L1/plot_4q_3l_1t_L1_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02050914  Δ=-6.4%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02034642  Δ=-7.3%
#
# === Final plot for L=3, inst=1 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01059030  Δ=+45.0%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01154647  Δ=+39.1%
#
# === Final plot for L=3, inst=2 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.00960631  Δ=+50.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01093870  Δ=+42.3%
#
# === Final plot for L=3, inst=3 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01049409  Δ=+45.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01145625  Δ=+39.6%
#
# === Final plot for L=3, inst=4 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01015172  Δ=+47.3%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01257996  Δ=+33.6%
#
# === Final plot for L=3, inst=5 ===
# Saved plot → aintern/figures/final/4q_3l_1t/L3/plot_4q_3l_1t_L3_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01022815  Δ=+46.9%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01207624  Δ=+36.3%

# %%
# ===============================
# Cell A — Circuit renderer (ψ + SWAP-reset + adjoint(φ))
# ===============================
from pathlib import Path
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as pnp

def render_and_save_circuit(
    L, phi_vec, psi_vec, save_dir, inst,
    style="pennylane", level="device", fname_prefix="circuit"
):
    """
    Draw the denoiser circuit exactly as used in Stage-3:
      1) embed_input(x)
      2) encoder with ψ
      3) SWAP-reset of the trash qubits using |0> ancillas
      4) adjoint(encoder) with fixed φ
      5) Z measurements (on the main data wires only)

    Notes:
    - Device wires: [0, 1, ..., n_qubits-1, 'anc0', 'anc1', ...]
    - SWAPs occur between trash wires (n_latent ... n_qubits-1) and the ancillas.
    """
    # --- wires: main data wires + ancillas for reset ---
    main_wires = list(range(n_qubits))
    anc_wires  = [f"anc{k}" for k in range(n_trash)]  # pretty labels
    dev_wires  = main_wires + anc_wires

    dev = qml.device("default.qubit", wires=dev_wires, shots=None)

    # freeze φ & ψ for drawing
    theta_fixed = pnp.array(phi_vec, requires_grad=False).reshape((L, n_qubits, 3))
    psi_flat    = pnp.array(psi_vec, requires_grad=False)

    # ----- Encoder body used in Stage-1/3 (matches your training template) -----
    def encoder_body(theta):
        # theta shape: (L, n_qubits, 3) for RX/RY/RZ on each qubit per layer
        for l in range(L):
            # single-qubit rotations
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=main_wires[q])
                qml.RY(theta[l, q, 1], wires=main_wires[q])
                qml.RZ(theta[l, q, 2], wires=main_wires[q])
            # ring CNOT entanglers across data wires
            for q in range(n_qubits - 1):
                qml.CNOT(wires=[main_wires[q], main_wires[q + 1]])
            qml.CNOT(wires=[main_wires[-1], main_wires[0]])

    # fixed decoder = adjoint(φ)
    def decoder_fixed():
        qml.adjoint(encoder_body)(theta_fixed)

    # --- explicit SWAP-reset (trash -> ancilla, main trash becomes |0>)
    def swap_reset_trash_to_ancilla():
        for k in range(n_trash):
            t_wire = main_wires[n_latent + k]  # trash wire in main register
            a_wire = anc_wires[k]              # corresponding ancilla at |0>
            qml.SWAP(wires=[t_wire, a_wire])

    # --- QNode for drawing (deterministic dummy input) ---
    @qml.qnode(dev)
    def denoiser_for_draw(x_in):
        # 1) input embedding on main wires (same function you use in training)
        embed_input(x_in)

        # 2) encoder with learned ψ (reuse your training helper if you prefer)
        #    If your 'encoder_template' writes to the current device wires,
        #    it will act on main_wires because those are numbered 0..n_qubits-1.
        encoder_template(psi_flat, L)

        # 3) SWAP-reset of trash qubits into ancillas
        if n_trash > 0:
            swap_reset_trash_to_ancilla()

        # 4) fixed decoder = adjoint(φ)
        decoder_fixed()

        # 5) measure main data wires (not the ancillas)
        return [qml.expval(qml.PauliZ(w)) for w in main_wires]

    # ---- render & save ----
    x_dummy = pnp.zeros(wind_size, dtype=float)  # just to build the tape
    qml.drawer.use_style(style)
    fig, ax = qml.draw_mpl(denoiser_for_draw, decimals=2, level=level)(x_dummy)

    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    out_png = save_dir / f"{fname_prefix}_L{L}_inst{int(inst):02d}.png"
    fig.savefig(out_png, dpi=220, bbox_inches="tight", pad_inches=0.1)
    plt.close(fig)
    return out_png

# %%
# ===============================
# Cell B — Save φ/ψ + circuit PNGs + CSVs
# ===============================
import json, csv, time, os
from pathlib import Path
import numpy as np
import pandas as pd

# --- helpers (local, robust) ---
def ensure_dir(p: str | Path) -> Path:
    p = Path(p); p.mkdir(parents=True, exist_ok=True); return p

def arch_tag():
    # e.g. "4q_3l_1t"
    return f"{n_qubits}q_{n_latent}l_{n_trash}t"

def inst_fname(L, inst):
    return f"inst{int(inst):02d}_L{int(L)}"

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _choose_eval_seed(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3 and s3["TEST_SEED_FIXED"] is not None:
        return int(s3["TEST_SEED_FIXED"])
    # fallback to "last-epoch" convention
    eplen = len(s3.get("hist_train", []))
    return 88_000 + 100*instance_id + max(eplen - 1, 0)

# Respect global choices if set elsewhere
DEV_NAME   = globals().get("DEV_NAME", "default.qubit")
RESET_MODE = globals().get("RESET_MODE", "swap")   # "swap" (unitary) or "measure"

# --- roots ---
ROOT = ensure_dir("qae_runs")
DATA_ROOT = ensure_dir(ROOT / DATA_ID)
ARCH_ROOT = ensure_dir(DATA_ROOT / arch_tag())

# per-layer dirs
dir_L = {L: ensure_dir(ARCH_ROOT / f"L{int(L)}") for L in set(LAYER_OPTIONS)}

# CSV paths (within arch folder)
CSV_RUNS   = ARCH_ROOT / "metrics_by_run.csv"
CSV_SUMMARY= ARCH_ROOT / "summary_by_layer.csv"

# create/ensure CSV headers
RUNS_HEADER = [
    "dataset","arch","instance_id","layer",
    "window_size","step","sigma_eval",
    "mse_train_noise","mse_train_recovered","delta_train_pct",
    "mse_test_noise","mse_test_recovered","delta_test_pct",
    "s1_best_train_cost","timestamp","bundle_json"
]
if not CSV_RUNS.exists():
    with open(CSV_RUNS, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow(RUNS_HEADER)

# ---- iterate runs and save artifacts ----
rows = []
for run in ALL_RUNS:
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    # --- params to .npy ---
    np.save(dir_L[L] / f"phi_{inst_fname(L, inst)}.npy", phi)
    np.save(dir_L[L] / f"psi_{inst_fname(L, inst)}.npy", psi)

    # --- evaluate metrics on the run's fixed test seed (or fallback) ---
    seed_eval = _choose_eval_seed(run, inst)
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed_eval)

    # Use the same reset mode as training (ensures denoiser matches what was trained)
    handles  = stage3_qnodes(L, phi, reset_mode=RESET_MODE)
    denoiser = handles["denoiser_qnode_all"]

    tr_hat_w = denoise_windows(psi, denoiser, tr_n)
    te_hat_w = denoise_windows(psi, denoiser, te_n)

    # series-level (flattened) MSEs
    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_hat_w); te_hat = _flatten_avg(te_hat_w)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    d_tr = 100.0 * (1.0 - mse_tr_hat / max(mse_tr_noise, 1e-12))
    d_te = 100.0 * (1.0 - mse_te_hat / max(mse_te_noise, 1e-12))

    # --- save circuit PNG (in arch folder, NOT inside Lx) ---
    png_path = render_and_save_circuit(L, phi, psi, save_dir=ARCH_ROOT, inst=inst,
                                       style="pennylane", level="device",
                                       fname_prefix="circuit")

    # --- compact JSON bundle (path saved in CSV for traceability) ---
    bundle = {
        "schema": {"name": "half_qae_bundle", "version": "1.0"},
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "dataset": {
            "id": DATA_ID,
            "scale_low":  float(scale_low),
            "scale_high": float(scale_high),
            "window_size": int(wind_size),
            "window_step": int(wind_step),
            "split": float(split),
        },
        "run": {
            "instance_id": inst,
            "layer": L,
            "sigma_eval": float(EVAL_SIGMA),
            "test_seed_fixed": int(run["stage3"].get("TEST_SEED_FIXED", seed_eval)),
        },
        "environment": {
            "device": DEV_NAME,
            "reset_mode": RESET_MODE,
        },
        "architecture": {
            "n_qubits": int(n_qubits),
            "n_latent": int(n_latent),
            "n_trash":  int(n_trash),
        },
        "parameters": {
            "phi": phi.tolist(),
            "psi": psi.tolist(),
        },
        "metrics_series": {
            "mse_train_noise": mse_tr_noise,
            "mse_train_recovered": mse_tr_hat,
            "delta_train_pct": d_tr,
            "mse_test_noise": mse_te_noise,
            "mse_test_recovered": mse_te_hat,
            "delta_test_pct": d_te,
        }
    }
    bundle_path = dir_L[L] / f"bundle_{inst_fname(L, inst)}.json"
    with open(bundle_path, "w", encoding="utf-8") as f:
        json.dump(bundle, f, indent=2)

    # --- row for runs CSV ---
    rows.append([
        DATA_ID, arch_tag(), inst, L,
        int(wind_size), int(wind_step), float(EVAL_SIGMA),
        mse_tr_noise, mse_tr_hat, d_tr,
        mse_te_noise, mse_te_hat, d_te,
        float(run["stage1"].get("best_train", np.nan)),
        bundle["timestamp"],
        str(bundle_path)
    ])

# upsert rows into metrics_by_run.csv (deduplicate by instance_id+layer)
if rows:
    df_new = pd.DataFrame(rows, columns=RUNS_HEADER)
    if CSV_RUNS.exists():
        df_old = pd.read_csv(CSV_RUNS)
        key_cols = ["dataset","arch","instance_id","layer"]
        df_old = df_old.drop_duplicates(subset=key_cols, keep="last")
        df_new = pd.concat([df_old, df_new], ignore_index=True)
        df_new = df_new.drop_duplicates(subset=key_cols, keep="last")
    df_new.to_csv(CSV_RUNS, index=False)
    print(f"Updated per-run metrics → {CSV_RUNS}")

# # build a tiny per-layer summary
if Path(CSV_RUNS).exists():
    df = pd.read_csv(CSV_RUNS)
    summary = (df
        .groupby("layer", as_index=True)
        .agg(
            runs=("instance_id","count"),
            mse_test_noise_mean=("mse_test_noise","mean"),
            mse_test_recovered_mean=("mse_test_recovered","mean"),
            delta_test_pct_mean=("delta_test_pct","mean"),
        )
    )
    summary.to_csv(CSV_SUMMARY)
    print(f"Saved per-layer summary → {CSV_SUMMARY}")

print(f"Artifacts saved under → {ARCH_ROOT}")

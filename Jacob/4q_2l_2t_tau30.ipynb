# %%
# ===========================
# Cell 0 — Config
# ===========================
DATA_ID = 'mackey_glass_tau30_n200'   # your dataset folder name

# Noise used in training & scoring
EVAL_SIGMA   = 0.20

# Windowing (must match qubit count for our QAE)
wind_size    = 4      # == n_qubits
wind_step    = 2

# Train/Test split on windows produced from the full series
split        = 0.75   # first 75% windows → train, last 25% → test

# Runs
INSTANCE_IDS = [1, 2, 3, 4, 5]
LAYER_OPTIONS = [1, 3]  # Stage-1/3 depth options

# Reset implementation for Stage-3:
#   'Jacob' → qml.measure(w, reset=True)  (keeps same wire count)
#   'swap'    → unitary SWAP to ancillas in |0>            (adds n_trash ancillas; enables adjoint on lightning)
RESET_MODE = 'swap'   # ← default approach

# Backends to use (you can keep both lightning; 'measure' may fall back from adjoint automatically)
STAGE1_BACKEND = 'lightning.qubit'
STAGE3_BACKEND = 'lightning.qubit'

# Logging
LOG_NAME = 'aintern'
CASE_NAME = 'half_qae'
DATA_PATH = f'{LOG_NAME}/data'
FIGURES_PATH = f'{LOG_NAME}/figures'
TRAIN_PATH = f'{LOG_NAME}/training'
PARAMS_PATH = f'{LOG_NAME}/params'
ANALYSIS_PATH = f'{LOG_NAME}/analysis'

# %%
# ===========================
# Cell 1 — Imports & utils
# ===========================
import os, sys, time, math, random, json
from pathlib import Path
import numpy as np
import pennylane as qml
from pennylane import numpy as pnp
import matplotlib.pyplot as plt

# repo utils
sys.path.append('.'); sys.path.append('..')
from qae_utils.Files import create_folder_if_needed, read_json_file, read_ts_file
from qae_utils.Window import ts_wind_make, ts_wind_split, ts_wind_flatten_avg
from qae_utils.Window import ts_add_noise
from qae_utils.Charts import multi_plot_flat_ts

# folders
for p in [FIGURES_PATH, TRAIN_PATH, PARAMS_PATH, ANALYSIS_PATH]:
    create_folder_if_needed(p)

# plotting
np.set_printoptions(suppress=True, precision=6)
plt.rcParams["figure.figsize"] = (6.5, 4)

def set_global_seed(instance_id: int):
    base = 10_000 + int(instance_id)
    random.seed(base + 11)
    np.random.seed(base + 22)
    try:
        pnp.random.seed(base + 33)
    except Exception:
        pass
    return dict(global_seed=base, numpy_seed=base+22, pnp_seed=base+33)

# %%
# ===========================
# Cell 2 — Load data & embed (robust paths)
# ===========================
import os

# keep your DATA_ID, LOG_NAME, DATA_PATH from Cell 0
# this resolver tries several roots so relative paths won't break
def _find_data_folder(data_id, log_name='aintern', preferred_root=None):
    candidates = []
    if preferred_root:
        candidates.append(preferred_root)
    # common locations
    candidates += [
        f'./{log_name}/data',
        f'../{log_name}/data',
        f'../../{log_name}/data',
        './jacobs_examples/aintern/data',
        '../jacobs_examples/aintern/data',
        '../../jacobs_examples/aintern/data',
    ]
    tried = []
    for root in candidates:
        folder = os.path.join(root, data_id)
        info_p = os.path.join(folder, 'info.json')
        x_p    = os.path.join(folder, 'x_org.arr')
        y_p    = os.path.join(folder, 'y_org.arr')
        tried.append(folder)
        if os.path.isdir(folder) and all(os.path.exists(p) for p in (info_p, x_p, y_p)):
            return folder
    raise FileNotFoundError(
        "Could not find dataset folder with required files.\n"
        f"DATA_ID='{data_id}'. Tried:\n - " + "\n - ".join(tried)
    )

# resolve the folder (uses your DATA_PATH from Cell 0 as a preference)
try:
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=DATA_PATH)
except Exception as e:
    # last resort: try without preferred_root
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=None)

data_info_path = f'{DATA_FOLDER}/info.json'
x_org_path     = f'{DATA_FOLDER}/x_org.arr'
y_org_path     = f'{DATA_FOLDER}/y_org.arr'

info = read_json_file(data_info_path)
X = read_ts_file(x_org_path).astype(int)  # indices (for plotting only)
y = read_ts_file(y_org_path)              # values (original domain)

scale_low  = float(info['scale_low'])
scale_high = float(info['scale_high'])
print(f'Using data folder: {DATA_FOLDER}')
print(f'Loaded {len(y)} samples; scale = [{scale_low:.3f}, {scale_high:.3f}]')

# quick plot (optional)
multi_plot_flat_ts([y], X_list=[0], colors=['blue'], labels=['Original'],
                   lines=['solid'], legend_cols=1, rcParams=(8, 3),
                   xlabel=f'Range (samples={len(y)})',
                   title=f'Data for model training (data=\"{DATA_ID}\")')

def embed_input(x, info_=None):
    """Map window values to RY(π·v01) with v01 from [scale_low, scale_high] → [0,1]."""
    if info_ is None: info_ = info
    lo, hi = float(info_['scale_low']), float(info_['scale_high'])
    xn = (pnp.array(x) - lo) / max(hi - lo, 1e-12)
    for i, v in enumerate(xn):
        qml.RY(v * pnp.pi, wires=i)
# Out:
# Using data folder: ../jacobs_examples/aintern/data/mackey_glass_tau30_n200
# Loaded 200 samples; scale = [0.200, 0.800]

# %%
# ===========================
# Cell 3 — Architecture (4q, 3 latent, 1 trash)
# ===========================
n_qubits = wind_size      # must equal window size
n_latent = 2
n_trash  = n_qubits - n_latent
trash_wires  = list(range(n_latent, n_qubits))  # [3] for 4q
signal_wires = list(range(n_qubits))            # diagnostics / full outputs

def make_device(nwires, backend='lightning.qubit'):
    return qml.device(backend, wires=nwires, shots=None)

def encoder_template(params, n_layers):
    """RX/RY/RZ per qubit + ring CNOT per layer."""
    assert len(params) == n_layers * n_qubits * 3
    for l in range(n_layers):
        for q in range(n_qubits):
            idx = l * n_qubits * 3 + q * 3
            qml.RX(params[idx + 0], wires=q)
            qml.RY(params[idx + 1], wires=q)
            qml.RZ(params[idx + 2], wires=q)
        for q in range(n_qubits - 1):
            qml.CNOT(wires=[q, q + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])

print(f"Architecture set: {n_qubits}q ({n_latent} latent, {n_trash} trash).")
# Out:
# Architecture set: 4q (2 latent, 2 trash).

# %%
# ===========================
# Cell 4 — Stage-1 training
# ===========================
def stage1_qnodes(n_layers):
    dev = make_device(n_qubits, backend=STAGE1_BACKEND)

    @qml.qnode(dev, interface="autograd", diff_method="adjoint")
    def trash_expectations(phi, x_clean):
        embed_input(x_clean)
        encoder_template(phi, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in trash_wires]

    return trash_expectations

def stage1_loss_on_windows(trash_expect, phi, windows_clean):
    # P(|1>) = (1 - Z)/2 on trash wires
    total = pnp.array(0.0)
    for w in windows_clean:
        z = pnp.array(trash_expect(phi, w))
        total = total + pnp.mean((1.0 - z) * 0.5)
    return total / max(len(windows_clean), 1)

def train_stage1_clean(windows_train_clean, n_layers, instance_id,
                       n_epochs=120, lr_init=0.010, patience=10, lr_patience=8):
    set_global_seed(instance_id)
    enc_shape = n_layers * n_qubits * 3
    phi = pnp.array(np.random.normal(0, 0.5, enc_shape), requires_grad=True)
    opt = qml.AdamOptimizer(stepsize=lr_init)
    lr = lr_init

    trash_expect = stage1_qnodes(n_layers)
    best_phi, best_cost = None, float("inf")
    no_improve = 0

    for ep in range(n_epochs):
        loss_fn = lambda p: stage1_loss_on_windows(trash_expect, p, windows_train_clean)
        phi, cost = opt.step_and_cost(loss_fn, phi)

        if cost < best_cost - 1e-9:
            best_cost, best_phi, no_improve = float(cost), pnp.array(phi, requires_grad=False), 0
        else:
            no_improve += 1
            if (no_improve % lr_patience) == 0:
                lr = max(lr * 0.5, 1e-4)
                opt = qml.AdamOptimizer(stepsize=lr)
                print(f"[Stage1] ↓ LR → {lr:.5f}")
            if no_improve >= patience:
                print("[Stage1] Early stopping."); break

        if ep % 5 == 0 or ep == n_epochs-1:
            print(f"[Stage1] L={n_layers} ep {ep:03d} | train {float(cost):.6f} | LR {lr:.5f}")

    return dict(phi=(best_phi if best_phi is not None else phi),
                best_train=float(best_cost))

# %%
# ===========================
# Cell 5 — Stage-3 QNodes
# ===========================
def stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET_MODE):

    need_anc = n_trash if (reset_mode == "swap" and n_trash > 0) else 0
    dev3 = make_device(n_qubits + need_anc)
    ancilla_wires = list(range(n_qubits, n_qubits + need_anc))

    theta_fixed = pnp.array(phi_stage1, requires_grad=False).reshape((n_layers, n_qubits, 3))

    def encoder_fixed_body(theta):
        for l in range(n_layers):
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=q)
                qml.RY(theta[l, q, 1], wires=q)
                qml.RZ(theta[l, q, 2], wires=q)
            for q in range(n_qubits-1):
                qml.CNOT(wires=[q, q+1])
            qml.CNOT(wires=[n_qubits-1, 0])

    def decoder_fixed():
        qml.adjoint(encoder_fixed_body)(theta_fixed)

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def encoder_only_expZ_all(flat_params, x_in):
        embed_input(x_in)
        encoder_template(flat_params, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def teacher_code_latents(x_clean):
        embed_input(x_clean)
        encoder_fixed_body(theta_fixed)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_latent)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def denoiser_qnode_all(flat_params, x_noisy):
        embed_input(x_noisy)
        encoder_template(flat_params, n_layers)

        # --- reset trash ---
        if n_trash > 0:
            if reset_mode == "Jacob":
                for w in trash_wires:
                    qml.measure(w, reset=True)
            elif reset_mode == "swap":
                # one clean ancilla per trash wire
                for t, a in zip(trash_wires, ancilla_wires):
                    # ancillas start in |0>, so SWAP puts |0> into trash, old trash into ancilla
                    qml.SWAP(wires=[t, a])

        decoder_fixed()
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    return dict(
        theta_fixed=theta_fixed,
        ancilla_wires=ancilla_wires,
        encoder_only_expZ_all=encoder_only_expZ_all,
        teacher_code_latents=teacher_code_latents,
        denoiser_qnode_all=denoiser_qnode_all
    )

def Z_to_values_autograd(z_all):
    z_all = pnp.clip(pnp.asarray(z_all), -0.999999, 0.999999)
    v01   = pnp.arccos(z_all) / pnp.pi
    return v01 * (scale_high - scale_low) + scale_low

def first_diff(x):
    x = pnp.array(x); return x[1:] - x[:-1]

def p1_from_expZ(z):
    return (1 - pnp.asarray(z)) * 0.5

def huber(residual, delta):
    r = pnp.abs(residual)
    return pnp.where(r <= delta, 0.5*r**2, delta*(r - 0.5*delta))

# %%
# ===========================
# Cell 6 — Noise & scoring helpers
# ===========================
def make_windows_from_series(y_vec, noise_sigma, seed, wind_size, wind_step):
    """
    Inject one noise vector into the whole series,
    then windowize both clean and noisy series the same way.
    """
    y_noisy = ts_add_noise(y_vec, noise=noise_sigma, noise_type='normal', clip=False,
                           range_low=scale_low, range_high=scale_high, seed=seed)

    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)

    # windows index array (not used by model, only for split helper)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])

    # split consistently
    X_tr, y_tr_clean, X_te, y_te_clean = ts_wind_split(X_ts, win_clean, split)
    X_tr, y_tr_noisy, X_te, y_te_noisy = ts_wind_split(X_ts, win_noisy, split)

    return (y_tr_clean, y_tr_noisy, y_te_clean, y_te_noisy)

def denoise_windows(params, denoise_qnode, windows_noisy):
    outs = []
    for w in windows_noisy:
        zD = pnp.array(denoise_qnode(params, w))
        outs.append(pnp.array(Z_to_values_autograd(zD)))
    return pnp.stack(outs)

def mse_on_windows(w_true, w_pred):
    w_true = np.asarray(w_true); w_pred = np.asarray(w_pred)
    return float(np.mean((w_true - w_pred)**2))

def mse_on_series_avg(w_true, w_pred, step):
    flat_true = ts_wind_flatten_avg(np.asarray(w_true), step)
    flat_pred = ts_wind_flatten_avg(np.asarray(w_pred), step)
    return float(np.mean((flat_true - flat_pred)**2))

# %%
# ===========================
# Cell 7 — Stage-3 (simple, fixed test seed, mini-batch)
# ===========================
def _series_to_train_test_windows(y_vec, sigma, seed):
    """Noise once → windowize → train/test split."""
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return np.asarray(tr_clean), np.asarray(tr_noisy), np.asarray(te_clean), np.asarray(te_noisy)

def _win_mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b)**2))

def _ser_mse(a, b):
    a = ts_wind_flatten_avg(np.asarray(a), wind_step)
    b = ts_wind_flatten_avg(np.asarray(b), wind_step)
    return float(np.mean((a - b)**2))

def train_stage3_series_noise_simple(
    y_full, phi_stage1, n_layers, instance_id,
    EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001, CLIP_NORM=1.0,
    USE_EMA=True, EMA_DECAY=0.995,
    TRAIN_SEED_BASE=88000, TEST_SEED_FIXED=99123,
    RESET=RESET_MODE,        # ← pass through
    BETA_TF=0.05,            # latent tug weight (teacher forcing)
    L_TV=0.02                # temporal smoothness weight
):
    set_global_seed(instance_id)
    handles = stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET)
    enc_all   = handles["encoder_only_expZ_all"]
    teacher_l = handles["teacher_code_latents"]
    denoise   = handles["denoiser_qnode_all"]

    # init ψ near φ
    phi_flat = pnp.array(phi_stage1, requires_grad=False)
    psi = pnp.array(np.array(phi_flat) + 0.05*np.random.randn(len(phi_flat)), requires_grad=True)

    opt = qml.AdamOptimizer(stepsize=LR)
    ema = pnp.array(psi, requires_grad=False) if USE_EMA else None

    hist_train_win_mse, hist_test_win_mse = [], []
    hist_train_ser_mse, hist_test_ser_mse = [], []

    def loss_on_batch(params, batch_clean, batch_noisy):
        total = pnp.array(0.0)
        for c, n in zip(batch_clean, batch_noisy):
            z_all = pnp.array(enc_all(params, n))
            z_sig, z_tr = z_all[:n_latent], z_all[n_latent:]
            zD   = pnp.array(denoise(params, n))
            vhat = Z_to_values_autograd(zD)

            L_rec = pnp.mean((pnp.array(c) - vhat)**2)
            L_tf  = pnp.mean(huber(pnp.array(teacher_l(c)) - z_sig, 0.25))
            L_tr  = pnp.mean(p1_from_expZ(z_tr))
            L_tv  = pnp.mean(huber(first_diff(c) - first_diff(vhat), 0.02))

            total = total + (L_rec + BETA_TF*L_tf + 0.5*L_tr + L_TV*L_tv)
        return total / max(len(batch_clean), 1)

    for ep in range(EPOCHS):
        # epoch-specific train noise
        tr_clean, tr_noisy, _, _ = make_windows_from_series(
            y_full, EVAL_SIGMA, TRAIN_SEED_BASE + ep, wind_size, wind_step
        )
        # fixed test noise
        _, _, te_clean, te_noisy = make_windows_from_series(
            y_full, EVAL_SIGMA, TEST_SEED_FIXED, wind_size, wind_step
        )

        # inner SGD steps with mini-batches
        for _ in range(INNER_STEPS):
            idx = np.random.randint(0, len(tr_clean), size=min(BATCH_SIZE, len(tr_clean)))
            batch_c = [tr_clean[i] for i in idx]
            batch_n = [tr_noisy[i] for i in idx]
            psi, _ = opt.step_and_cost(lambda p: loss_on_batch(p, batch_c, batch_n), psi)
            if USE_EMA:
                ema = EMA_DECAY * ema + (1 - EMA_DECAY) * psi

        eval_params = ema if USE_EMA else psi

        # ---- metrics
        tr_pred = denoise_windows(eval_params, denoise, tr_noisy)
        te_pred = denoise_windows(eval_params, denoise, te_noisy)

        train_mse_win = mse_on_windows(tr_clean, tr_pred)
        test_mse_win  = mse_on_windows(te_clean, te_pred)
        train_mse_ser = mse_on_series_avg(tr_clean, tr_pred, wind_step)
        test_mse_ser  = mse_on_series_avg(te_clean, te_pred, wind_step)

        hist_train_win_mse.append(float(train_mse_win))
        hist_test_win_mse.append(float(test_mse_win))
        hist_train_ser_mse.append(float(train_mse_ser))
        hist_test_ser_mse.append(float(test_mse_ser))

        print(f"[Stage3] L={n_layers} ep {ep:03d} | "
              f"train MSE(win) {train_mse_win:.5f} | "
              f"test MSE(win) {test_mse_win:.5f} | "
              f"test MSE(series) {test_mse_ser:.5f}")

    return dict(
        psi=(ema if USE_EMA else psi),
        hist_train_win_mse=hist_train_win_mse,
        hist_test_win_mse=hist_test_win_mse,
        hist_train_ser_mse=hist_train_ser_mse,
        hist_test_ser_mse=hist_test_ser_mse,
        TEST_SEED_FIXED=int(TEST_SEED_FIXED),
        RESET_MODE=str(RESET),
    )

# %%
# ===========================
# Cell 8 — Runs (instances × layers)
# ===========================
ALL_RUNS = []

for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        print("\n" + "="*30)
        print(f"Instance {inst} | Layers {L}")
        print("="*30)
        set_global_seed(inst)

        # ---- CLEAN windows once (for Stage-1 only)
        clean_windows = ts_wind_make(y, wind_size, wind_step)
        X_ts = np.array([i*wind_step for i in range(len(clean_windows))])
        _, win_tr_clean, _, win_te_clean = ts_wind_split(X_ts, clean_windows, split)
        print(f"[Windows] train={len(win_tr_clean)}, test={len(win_te_clean)} (W={wind_size}, step={wind_step})")

        # ---- Stage 1
        s1 = train_stage1_clean(
            win_tr_clean, n_layers=L, instance_id=inst,
            n_epochs=150, lr_init=0.010, patience=10, lr_patience=8
        )
        phi = s1["phi"]
        print(f"[Stage1] best train cost = {s1['best_train']:.6f}")

        # ---- Stage 3 (mentor-style reset by default)
        s3 = train_stage3_series_noise_simple(
                y_full=y, phi_stage1=phi, n_layers=L, instance_id=inst,
                EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001,
                RESET=RESET_MODE, BETA_TF=0.05, L_TV=0.02
        )

        # Final fixed-seed scoring (aligns with logs)
        seed_fix = s3.get("TEST_SEED_FIXED", 99123)
        trC, trN, teC, teN = _series_to_train_test_windows(y, EVAL_SIGMA, seed_fix)
        denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
        te_pred = denoise_windows(s3["psi"], denoise, teN)

        final_win = _win_mse(teC, te_pred)
        base_win  = _win_mse(teC, teN)
        final_ser = _ser_mse(teC, te_pred)
        base_ser  = _ser_mse(teC, teN)
        print(f"[Final TEST] MSE(win) {final_win:.6f} vs noisy {base_win:.6f} → Δ {100*(1-final_win/max(base_win,1e-12)):+.1f}%")
        print(f"[Final TEST] MSE(series) {final_ser:.6f} vs noisy {base_ser:.6f} → Δ {100*(1-final_ser/max(base_ser,1e-12)):+.1f}%")

        ALL_RUNS.append(dict(
            instance_id=inst, n_layers=L,
            stage1=dict(best_train=s1["best_train"], phi=np.array(phi)),
            stage3=dict(**s3)
        ))

print("\nCompleted", len(ALL_RUNS), "runs.")
# Out:
# ==============================
# Instance 1 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.478298 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.473727 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.468930 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.463930 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.458812 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.453635 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.448464 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.443333 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.438258 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.433237 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.428269 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.423354 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.418492 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.413676 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.408895 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.404130 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.399357 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.394552 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.389689 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.384741 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.379686 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.374506 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.369194 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.363749 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.358188 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.352539 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.346850 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.341180 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.335604 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.330207 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.326075 | LR 0.01000
# [Stage1] best train cost = 0.326075
# [Stage3] L=1 ep 000 | train MSE(win) 0.02631 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 001 | train MSE(win) 0.02617 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 002 | train MSE(win) 0.02626 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 003 | train MSE(win) 0.02635 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 004 | train MSE(win) 0.02622 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 005 | train MSE(win) 0.02618 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 006 | train MSE(win) 0.02638 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 007 | train MSE(win) 0.02605 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 008 | train MSE(win) 0.02657 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 009 | train MSE(win) 0.02642 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 010 | train MSE(win) 0.02637 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 011 | train MSE(win) 0.02621 | test MSE(win) 0.02594 | test MSE(series) 0.02474
# [Stage3] L=1 ep 012 | train MSE(win) 0.02620 | test MSE(win) 0.02594 | test MSE(series) 0.02473
# [Stage3] L=1 ep 013 | train MSE(win) 0.02625 | test MSE(win) 0.02594 | test MSE(series) 0.02473
# [Stage3] L=1 ep 014 | train MSE(win) 0.02639 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 015 | train MSE(win) 0.02630 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 016 | train MSE(win) 0.02629 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 017 | train MSE(win) 0.02634 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 018 | train MSE(win) 0.02618 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 019 | train MSE(win) 0.02620 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 020 | train MSE(win) 0.02612 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 021 | train MSE(win) 0.02650 | test MSE(win) 0.02593 | test MSE(series) 0.02473
# [Stage3] L=1 ep 022 | train MSE(win) 0.02636 | test MSE(win) 0.02593 | test MSE(series) 0.02472
# [Stage3] L=1 ep 023 | train MSE(win) 0.02624 | test MSE(win) 0.02593 | test MSE(series) 0.02472
# [Final TEST] MSE(win) 0.025926 vs noisy 0.019387 → Δ -33.7%
# [Final TEST] MSE(series) 0.024723 vs noisy 0.018958 → Δ -30.4%
#
# ==============================
# Instance 2 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.513392 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.506092 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.499782 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.494155 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.488893 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.483546 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.477857 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.471815 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.465503 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.459020 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.452461 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.445903 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.439404 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.433012 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.426772 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.420726 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.414899 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.409297 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.403899 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.398660 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.393526 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.388436 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.383336 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.378176 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.372921 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.367546 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.362040 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.356411 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.350683 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.344899 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.340273 | LR 0.01000
# [Stage1] best train cost = 0.340273
# [Stage3] L=1 ep 000 | train MSE(win) 0.02543 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 001 | train MSE(win) 0.02504 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 002 | train MSE(win) 0.02518 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 003 | train MSE(win) 0.02503 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 004 | train MSE(win) 0.02521 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 005 | train MSE(win) 0.02527 | test MSE(win) 0.02440 | test MSE(series) 0.02381
# [Stage3] L=1 ep 006 | train MSE(win) 0.02512 | test MSE(win) 0.02440 | test MSE(series) 0.02382
# [Stage3] L=1 ep 007 | train MSE(win) 0.02543 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 008 | train MSE(win) 0.02507 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 009 | train MSE(win) 0.02544 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 010 | train MSE(win) 0.02518 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 011 | train MSE(win) 0.02514 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 012 | train MSE(win) 0.02520 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 013 | train MSE(win) 0.02491 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 014 | train MSE(win) 0.02525 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 015 | train MSE(win) 0.02516 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 016 | train MSE(win) 0.02528 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 017 | train MSE(win) 0.02517 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 018 | train MSE(win) 0.02539 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 019 | train MSE(win) 0.02520 | test MSE(win) 0.02441 | test MSE(series) 0.02382
# [Stage3] L=1 ep 020 | train MSE(win) 0.02524 | test MSE(win) 0.02442 | test MSE(series) 0.02383
# [Stage3] L=1 ep 021 | train MSE(win) 0.02505 | test MSE(win) 0.02442 | test MSE(series) 0.02383
# [Stage3] L=1 ep 022 | train MSE(win) 0.02504 | test MSE(win) 0.02442 | test MSE(series) 0.02383
# [Stage3] L=1 ep 023 | train MSE(win) 0.02505 | test MSE(win) 0.02442 | test MSE(series) 0.02383
# [Final TEST] MSE(win) 0.024419 vs noisy 0.019387 → Δ -26.0%
# [Final TEST] MSE(series) 0.023828 vs noisy 0.018958 → Δ -25.7%
#
# ==============================
# Instance 3 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.496759 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.489303 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.480997 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.471755 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.461178 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.449141 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.435896 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.421866 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.407529 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.393416 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.380072 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.367939 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.357256 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.348027 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.340057 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.333070 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.326825 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.321200 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.316178 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.311802 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.308092 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.305007 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.302453 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.300337 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.298603 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.297221 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.296165 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.295400 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.294881 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.294545 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.294364 | LR 0.01000
# [Stage1] best train cost = 0.294364
# [Stage3] L=1 ep 000 | train MSE(win) 0.02271 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 001 | train MSE(win) 0.02328 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 002 | train MSE(win) 0.02282 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 003 | train MSE(win) 0.02367 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 004 | train MSE(win) 0.02297 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 005 | train MSE(win) 0.02279 | test MSE(win) 0.02115 | test MSE(series) 0.02012
# [Stage3] L=1 ep 006 | train MSE(win) 0.02358 | test MSE(win) 0.02115 | test MSE(series) 0.02011
# [Stage3] L=1 ep 007 | train MSE(win) 0.02222 | test MSE(win) 0.02114 | test MSE(series) 0.02011
# [Stage3] L=1 ep 008 | train MSE(win) 0.02373 | test MSE(win) 0.02114 | test MSE(series) 0.02011
# [Stage3] L=1 ep 009 | train MSE(win) 0.02268 | test MSE(win) 0.02114 | test MSE(series) 0.02011
# [Stage3] L=1 ep 010 | train MSE(win) 0.02303 | test MSE(win) 0.02114 | test MSE(series) 0.02011
# [Stage3] L=1 ep 011 | train MSE(win) 0.02296 | test MSE(win) 0.02114 | test MSE(series) 0.02011
# [Stage3] L=1 ep 012 | train MSE(win) 0.02267 | test MSE(win) 0.02114 | test MSE(series) 0.02010
# [Stage3] L=1 ep 013 | train MSE(win) 0.02290 | test MSE(win) 0.02113 | test MSE(series) 0.02010
# [Stage3] L=1 ep 014 | train MSE(win) 0.02296 | test MSE(win) 0.02113 | test MSE(series) 0.02010
# [Stage3] L=1 ep 015 | train MSE(win) 0.02278 | test MSE(win) 0.02113 | test MSE(series) 0.02010
# [Stage3] L=1 ep 016 | train MSE(win) 0.02257 | test MSE(win) 0.02113 | test MSE(series) 0.02010
# [Stage3] L=1 ep 017 | train MSE(win) 0.02358 | test MSE(win) 0.02112 | test MSE(series) 0.02010
# [Stage3] L=1 ep 018 | train MSE(win) 0.02239 | test MSE(win) 0.02112 | test MSE(series) 0.02009
# [Stage3] L=1 ep 019 | train MSE(win) 0.02334 | test MSE(win) 0.02112 | test MSE(series) 0.02009
# [Stage3] L=1 ep 020 | train MSE(win) 0.02214 | test MSE(win) 0.02112 | test MSE(series) 0.02009
# [Stage3] L=1 ep 021 | train MSE(win) 0.02378 | test MSE(win) 0.02111 | test MSE(series) 0.02009
# [Stage3] L=1 ep 022 | train MSE(win) 0.02338 | test MSE(win) 0.02111 | test MSE(series) 0.02008
# [Stage3] L=1 ep 023 | train MSE(win) 0.02279 | test MSE(win) 0.02111 | test MSE(series) 0.02008
# [Final TEST] MSE(win) 0.021109 vs noisy 0.019387 → Δ -8.9%
# [Final TEST] MSE(series) 0.020082 vs noisy 0.018958 → Δ -5.9%
#
# ==============================
# Instance 4 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.477596 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.473028 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.468096 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.462882 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.457489 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.452032 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.446614 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.441313 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.436174 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.431220 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.426445 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.421811 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.417270 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.412780 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.408304 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.403815 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.399291 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.394714 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.390067 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.385334 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.380504 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.375571 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.370531 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.365385 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.360137 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.354796 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.349384 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.343944 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.338546 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.333285 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.329243 | LR 0.01000
# [Stage1] best train cost = 0.329243
# [Stage3] L=1 ep 000 | train MSE(win) 0.02718 | test MSE(win) 0.02705 | test MSE(series) 0.02550
# [Stage3] L=1 ep 001 | train MSE(win) 0.02704 | test MSE(win) 0.02705 | test MSE(series) 0.02550
# [Stage3] L=1 ep 002 | train MSE(win) 0.02718 | test MSE(win) 0.02705 | test MSE(series) 0.02550
# [Stage3] L=1 ep 003 | train MSE(win) 0.02723 | test MSE(win) 0.02705 | test MSE(series) 0.02550
# [Stage3] L=1 ep 004 | train MSE(win) 0.02715 | test MSE(win) 0.02705 | test MSE(series) 0.02550
# [Stage3] L=1 ep 005 | train MSE(win) 0.02707 | test MSE(win) 0.02705 | test MSE(series) 0.02549
# [Stage3] L=1 ep 006 | train MSE(win) 0.02723 | test MSE(win) 0.02705 | test MSE(series) 0.02549
# [Stage3] L=1 ep 007 | train MSE(win) 0.02699 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 008 | train MSE(win) 0.02748 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 009 | train MSE(win) 0.02733 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 010 | train MSE(win) 0.02730 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 011 | train MSE(win) 0.02710 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 012 | train MSE(win) 0.02712 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 013 | train MSE(win) 0.02717 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 014 | train MSE(win) 0.02726 | test MSE(win) 0.02704 | test MSE(series) 0.02549
# [Stage3] L=1 ep 015 | train MSE(win) 0.02722 | test MSE(win) 0.02704 | test MSE(series) 0.02548
# [Stage3] L=1 ep 016 | train MSE(win) 0.02722 | test MSE(win) 0.02704 | test MSE(series) 0.02548
# [Stage3] L=1 ep 017 | train MSE(win) 0.02717 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 018 | train MSE(win) 0.02707 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 019 | train MSE(win) 0.02707 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 020 | train MSE(win) 0.02706 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 021 | train MSE(win) 0.02737 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 022 | train MSE(win) 0.02729 | test MSE(win) 0.02703 | test MSE(series) 0.02548
# [Stage3] L=1 ep 023 | train MSE(win) 0.02712 | test MSE(win) 0.02703 | test MSE(series) 0.02547
# [Final TEST] MSE(win) 0.027028 vs noisy 0.019387 → Δ -39.4%
# [Final TEST] MSE(series) 0.025474 vs noisy 0.018958 → Δ -34.4%
#
# ==============================
# Instance 5 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.480010 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.474397 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.468607 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.462894 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.457458 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.452267 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.447077 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.441732 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.436216 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.430538 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.424698 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.418708 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.412601 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.406420 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.400204 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.393992 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.387811 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.381673 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.375568 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.369474 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.363364 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.357224 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.351054 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.344882 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.338759 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.332761 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.326979 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.321515 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.316467 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.311919 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.308681 | LR 0.01000
# [Stage1] best train cost = 0.308681
# [Stage3] L=1 ep 000 | train MSE(win) 0.02350 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 001 | train MSE(win) 0.02371 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 002 | train MSE(win) 0.02358 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 003 | train MSE(win) 0.02390 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 004 | train MSE(win) 0.02358 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 005 | train MSE(win) 0.02351 | test MSE(win) 0.02238 | test MSE(series) 0.02181
# [Stage3] L=1 ep 006 | train MSE(win) 0.02391 | test MSE(win) 0.02237 | test MSE(series) 0.02181
# [Stage3] L=1 ep 007 | train MSE(win) 0.02324 | test MSE(win) 0.02237 | test MSE(series) 0.02181
# [Stage3] L=1 ep 008 | train MSE(win) 0.02403 | test MSE(win) 0.02237 | test MSE(series) 0.02181
# [Stage3] L=1 ep 009 | train MSE(win) 0.02349 | test MSE(win) 0.02237 | test MSE(series) 0.02181
# [Stage3] L=1 ep 010 | train MSE(win) 0.02369 | test MSE(win) 0.02237 | test MSE(series) 0.02180
# [Stage3] L=1 ep 011 | train MSE(win) 0.02359 | test MSE(win) 0.02237 | test MSE(series) 0.02180
# [Stage3] L=1 ep 012 | train MSE(win) 0.02352 | test MSE(win) 0.02237 | test MSE(series) 0.02180
# [Stage3] L=1 ep 013 | train MSE(win) 0.02369 | test MSE(win) 0.02236 | test MSE(series) 0.02180
# [Stage3] L=1 ep 014 | train MSE(win) 0.02373 | test MSE(win) 0.02236 | test MSE(series) 0.02180
# [Stage3] L=1 ep 015 | train MSE(win) 0.02361 | test MSE(win) 0.02236 | test MSE(series) 0.02180
# [Stage3] L=1 ep 016 | train MSE(win) 0.02357 | test MSE(win) 0.02236 | test MSE(series) 0.02179
# [Stage3] L=1 ep 017 | train MSE(win) 0.02383 | test MSE(win) 0.02236 | test MSE(series) 0.02179
# [Stage3] L=1 ep 018 | train MSE(win) 0.02340 | test MSE(win) 0.02236 | test MSE(series) 0.02179
# [Stage3] L=1 ep 019 | train MSE(win) 0.02376 | test MSE(win) 0.02235 | test MSE(series) 0.02179
# [Stage3] L=1 ep 020 | train MSE(win) 0.02332 | test MSE(win) 0.02235 | test MSE(series) 0.02179
# [Stage3] L=1 ep 021 | train MSE(win) 0.02400 | test MSE(win) 0.02235 | test MSE(series) 0.02179
# [Stage3] L=1 ep 022 | train MSE(win) 0.02380 | test MSE(win) 0.02235 | test MSE(series) 0.02178
# [Stage3] L=1 ep 023 | train MSE(win) 0.02365 | test MSE(win) 0.02235 | test MSE(series) 0.02178
# [Final TEST] MSE(win) 0.022346 vs noisy 0.019387 → Δ -15.3%
# [Final TEST] MSE(series) 0.021782 vs noisy 0.018958 → Δ -14.9%
#
# ==============================
# Instance 1 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.435332 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.388343 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.349799 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.321470 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.300528 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.283570 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.268867 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.256059 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.244992 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.235180 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.226183 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.217745 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.209619 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.201518 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.193265 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.184794 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.176073 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.167181 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.158349 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.149882 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.142059 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.135064 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.128968 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.123752 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.119341 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.115632 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.112513 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.109877 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.107626 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.105681 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.104306 | LR 0.01000
# [Stage1] best train cost = 0.104306
# [Stage3] L=3 ep 000 | train MSE(win) 0.01320 | test MSE(win) 0.01302 | test MSE(series) 0.01238
# [Stage3] L=3 ep 001 | train MSE(win) 0.01416 | test MSE(win) 0.01302 | test MSE(series) 0.01238
# [Stage3] L=3 ep 002 | train MSE(win) 0.01345 | test MSE(win) 0.01302 | test MSE(series) 0.01238
# [Stage3] L=3 ep 003 | train MSE(win) 0.01275 | test MSE(win) 0.01302 | test MSE(series) 0.01238
# [Stage3] L=3 ep 004 | train MSE(win) 0.01223 | test MSE(win) 0.01301 | test MSE(series) 0.01237
# [Stage3] L=3 ep 005 | train MSE(win) 0.01381 | test MSE(win) 0.01301 | test MSE(series) 0.01237
# [Stage3] L=3 ep 006 | train MSE(win) 0.01382 | test MSE(win) 0.01301 | test MSE(series) 0.01237
# [Stage3] L=3 ep 007 | train MSE(win) 0.01333 | test MSE(win) 0.01301 | test MSE(series) 0.01236
# [Stage3] L=3 ep 008 | train MSE(win) 0.01302 | test MSE(win) 0.01300 | test MSE(series) 0.01236
# [Stage3] L=3 ep 009 | train MSE(win) 0.01319 | test MSE(win) 0.01300 | test MSE(series) 0.01235
# [Stage3] L=3 ep 010 | train MSE(win) 0.01421 | test MSE(win) 0.01299 | test MSE(series) 0.01235
# [Stage3] L=3 ep 011 | train MSE(win) 0.01273 | test MSE(win) 0.01299 | test MSE(series) 0.01234
# [Stage3] L=3 ep 012 | train MSE(win) 0.01408 | test MSE(win) 0.01298 | test MSE(series) 0.01234
# [Stage3] L=3 ep 013 | train MSE(win) 0.01302 | test MSE(win) 0.01298 | test MSE(series) 0.01233
# [Stage3] L=3 ep 014 | train MSE(win) 0.01265 | test MSE(win) 0.01298 | test MSE(series) 0.01233
# [Stage3] L=3 ep 015 | train MSE(win) 0.01338 | test MSE(win) 0.01297 | test MSE(series) 0.01232
# [Stage3] L=3 ep 016 | train MSE(win) 0.01308 | test MSE(win) 0.01297 | test MSE(series) 0.01232
# [Stage3] L=3 ep 017 | train MSE(win) 0.01379 | test MSE(win) 0.01296 | test MSE(series) 0.01231
# [Stage3] L=3 ep 018 | train MSE(win) 0.01325 | test MSE(win) 0.01295 | test MSE(series) 0.01230
# [Stage3] L=3 ep 019 | train MSE(win) 0.01438 | test MSE(win) 0.01295 | test MSE(series) 0.01230
# [Stage3] L=3 ep 020 | train MSE(win) 0.01236 | test MSE(win) 0.01294 | test MSE(series) 0.01229
# [Stage3] L=3 ep 021 | train MSE(win) 0.01270 | test MSE(win) 0.01293 | test MSE(series) 0.01228
# [Stage3] L=3 ep 022 | train MSE(win) 0.01449 | test MSE(win) 0.01293 | test MSE(series) 0.01227
# [Stage3] L=3 ep 023 | train MSE(win) 0.01288 | test MSE(win) 0.01292 | test MSE(series) 0.01226
# [Final TEST] MSE(win) 0.012920 vs noisy 0.019387 → Δ +33.4%
# [Final TEST] MSE(series) 0.012265 vs noisy 0.018958 → Δ +35.3%
#
# ==============================
# Instance 2 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.528820 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.481959 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.439362 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.402846 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.368497 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.336008 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.308280 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.285613 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.266031 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.248067 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.230932 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.214387 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.199144 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.185947 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.174908 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.165704 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.157930 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.151345 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.145766 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.140875 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.136381 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.132174 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.128324 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.124947 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.122085 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.119712 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.117758 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.116137 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.114772 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.113601 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.112764 | LR 0.01000
# [Stage1] best train cost = 0.112764
# [Stage3] L=3 ep 000 | train MSE(win) 0.01430 | test MSE(win) 0.01230 | test MSE(series) 0.01098
# [Stage3] L=3 ep 001 | train MSE(win) 0.01515 | test MSE(win) 0.01230 | test MSE(series) 0.01098
# [Stage3] L=3 ep 002 | train MSE(win) 0.01488 | test MSE(win) 0.01230 | test MSE(series) 0.01098
# [Stage3] L=3 ep 003 | train MSE(win) 0.01368 | test MSE(win) 0.01229 | test MSE(series) 0.01098
# [Stage3] L=3 ep 004 | train MSE(win) 0.01343 | test MSE(win) 0.01229 | test MSE(series) 0.01097
# [Stage3] L=3 ep 005 | train MSE(win) 0.01395 | test MSE(win) 0.01228 | test MSE(series) 0.01097
# [Stage3] L=3 ep 006 | train MSE(win) 0.01430 | test MSE(win) 0.01228 | test MSE(series) 0.01096
# [Stage3] L=3 ep 007 | train MSE(win) 0.01436 | test MSE(win) 0.01227 | test MSE(series) 0.01096
# [Stage3] L=3 ep 008 | train MSE(win) 0.01322 | test MSE(win) 0.01226 | test MSE(series) 0.01095
# [Stage3] L=3 ep 009 | train MSE(win) 0.01453 | test MSE(win) 0.01226 | test MSE(series) 0.01094
# [Stage3] L=3 ep 010 | train MSE(win) 0.01586 | test MSE(win) 0.01225 | test MSE(series) 0.01094
# [Stage3] L=3 ep 011 | train MSE(win) 0.01363 | test MSE(win) 0.01224 | test MSE(series) 0.01093
# [Stage3] L=3 ep 012 | train MSE(win) 0.01466 | test MSE(win) 0.01223 | test MSE(series) 0.01092
# [Stage3] L=3 ep 013 | train MSE(win) 0.01369 | test MSE(win) 0.01222 | test MSE(series) 0.01091
# [Stage3] L=3 ep 014 | train MSE(win) 0.01401 | test MSE(win) 0.01221 | test MSE(series) 0.01090
# [Stage3] L=3 ep 015 | train MSE(win) 0.01485 | test MSE(win) 0.01220 | test MSE(series) 0.01090
# [Stage3] L=3 ep 016 | train MSE(win) 0.01386 | test MSE(win) 0.01219 | test MSE(series) 0.01089
# [Stage3] L=3 ep 017 | train MSE(win) 0.01426 | test MSE(win) 0.01218 | test MSE(series) 0.01088
# [Stage3] L=3 ep 018 | train MSE(win) 0.01367 | test MSE(win) 0.01217 | test MSE(series) 0.01087
# [Stage3] L=3 ep 019 | train MSE(win) 0.01580 | test MSE(win) 0.01216 | test MSE(series) 0.01086
# [Stage3] L=3 ep 020 | train MSE(win) 0.01374 | test MSE(win) 0.01215 | test MSE(series) 0.01085
# [Stage3] L=3 ep 021 | train MSE(win) 0.01310 | test MSE(win) 0.01215 | test MSE(series) 0.01085
# [Stage3] L=3 ep 022 | train MSE(win) 0.01563 | test MSE(win) 0.01214 | test MSE(series) 0.01084
# [Stage3] L=3 ep 023 | train MSE(win) 0.01325 | test MSE(win) 0.01213 | test MSE(series) 0.01083
# [Final TEST] MSE(win) 0.012128 vs noisy 0.019387 → Δ +37.4%
# [Final TEST] MSE(series) 0.010831 vs noisy 0.018958 → Δ +42.9%
#
# ==============================
# Instance 3 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.475680 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.432335 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.404446 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.377666 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.351247 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.328420 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.308165 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.289152 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.270145 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.250425 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.230954 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.214088 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.201620 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.193162 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.187097 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.182284 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.178472 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.175682 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.173654 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.172017 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.170560 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.169196 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.167842 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.166432 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.164969 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.163487 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.162010 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.160556 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.159144 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.157784 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.156735 | LR 0.01000
# [Stage1] best train cost = 0.156735
# [Stage3] L=3 ep 000 | train MSE(win) 0.01706 | test MSE(win) 0.01639 | test MSE(series) 0.01600
# [Stage3] L=3 ep 001 | train MSE(win) 0.01742 | test MSE(win) 0.01639 | test MSE(series) 0.01600
# [Stage3] L=3 ep 002 | train MSE(win) 0.01676 | test MSE(win) 0.01639 | test MSE(series) 0.01600
# [Stage3] L=3 ep 003 | train MSE(win) 0.01578 | test MSE(win) 0.01639 | test MSE(series) 0.01600
# [Stage3] L=3 ep 004 | train MSE(win) 0.01584 | test MSE(win) 0.01638 | test MSE(series) 0.01600
# [Stage3] L=3 ep 005 | train MSE(win) 0.01701 | test MSE(win) 0.01638 | test MSE(series) 0.01599
# [Stage3] L=3 ep 006 | train MSE(win) 0.01728 | test MSE(win) 0.01638 | test MSE(series) 0.01599
# [Stage3] L=3 ep 007 | train MSE(win) 0.01678 | test MSE(win) 0.01637 | test MSE(series) 0.01598
# [Stage3] L=3 ep 008 | train MSE(win) 0.01677 | test MSE(win) 0.01637 | test MSE(series) 0.01598
# [Stage3] L=3 ep 009 | train MSE(win) 0.01745 | test MSE(win) 0.01637 | test MSE(series) 0.01598
# [Stage3] L=3 ep 010 | train MSE(win) 0.01717 | test MSE(win) 0.01636 | test MSE(series) 0.01597
# [Stage3] L=3 ep 011 | train MSE(win) 0.01651 | test MSE(win) 0.01636 | test MSE(series) 0.01597
# [Stage3] L=3 ep 012 | train MSE(win) 0.01737 | test MSE(win) 0.01636 | test MSE(series) 0.01597
# [Stage3] L=3 ep 013 | train MSE(win) 0.01668 | test MSE(win) 0.01636 | test MSE(series) 0.01597
# [Stage3] L=3 ep 014 | train MSE(win) 0.01586 | test MSE(win) 0.01635 | test MSE(series) 0.01596
# [Stage3] L=3 ep 015 | train MSE(win) 0.01670 | test MSE(win) 0.01635 | test MSE(series) 0.01596
# [Stage3] L=3 ep 016 | train MSE(win) 0.01649 | test MSE(win) 0.01635 | test MSE(series) 0.01596
# [Stage3] L=3 ep 017 | train MSE(win) 0.01720 | test MSE(win) 0.01635 | test MSE(series) 0.01596
# [Stage3] L=3 ep 018 | train MSE(win) 0.01683 | test MSE(win) 0.01634 | test MSE(series) 0.01595
# [Stage3] L=3 ep 019 | train MSE(win) 0.01776 | test MSE(win) 0.01634 | test MSE(series) 0.01595
# [Stage3] L=3 ep 020 | train MSE(win) 0.01645 | test MSE(win) 0.01633 | test MSE(series) 0.01594
# [Stage3] L=3 ep 021 | train MSE(win) 0.01673 | test MSE(win) 0.01633 | test MSE(series) 0.01594
# [Stage3] L=3 ep 022 | train MSE(win) 0.01741 | test MSE(win) 0.01632 | test MSE(series) 0.01593
# [Stage3] L=3 ep 023 | train MSE(win) 0.01677 | test MSE(win) 0.01632 | test MSE(series) 0.01593
# [Final TEST] MSE(win) 0.016317 vs noisy 0.019387 → Δ +15.8%
# [Final TEST] MSE(series) 0.015926 vs noisy 0.018958 → Δ +16.0%
#
# ==============================
# Instance 4 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.468042 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.430250 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.395788 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.364926 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.339793 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.321137 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.306050 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.292098 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.278836 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.266408 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.254725 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.243484 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.232903 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.223101 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.213923 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.205229 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.197078 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.189607 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.182814 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.176591 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.170888 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.165756 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.161212 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.157185 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.153586 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.150347 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.147389 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.144633 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.142019 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.139520 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.137609 | LR 0.01000
# [Stage1] best train cost = 0.137609
# [Stage3] L=3 ep 000 | train MSE(win) 0.01700 | test MSE(win) 0.01589 | test MSE(series) 0.01540
# [Stage3] L=3 ep 001 | train MSE(win) 0.01790 | test MSE(win) 0.01588 | test MSE(series) 0.01540
# [Stage3] L=3 ep 002 | train MSE(win) 0.01729 | test MSE(win) 0.01588 | test MSE(series) 0.01540
# [Stage3] L=3 ep 003 | train MSE(win) 0.01631 | test MSE(win) 0.01588 | test MSE(series) 0.01539
# [Stage3] L=3 ep 004 | train MSE(win) 0.01549 | test MSE(win) 0.01587 | test MSE(series) 0.01539
# [Stage3] L=3 ep 005 | train MSE(win) 0.01749 | test MSE(win) 0.01586 | test MSE(series) 0.01538
# [Stage3] L=3 ep 006 | train MSE(win) 0.01806 | test MSE(win) 0.01585 | test MSE(series) 0.01537
# [Stage3] L=3 ep 007 | train MSE(win) 0.01702 | test MSE(win) 0.01584 | test MSE(series) 0.01536
# [Stage3] L=3 ep 008 | train MSE(win) 0.01734 | test MSE(win) 0.01583 | test MSE(series) 0.01535
# [Stage3] L=3 ep 009 | train MSE(win) 0.01608 | test MSE(win) 0.01582 | test MSE(series) 0.01534
# [Stage3] L=3 ep 010 | train MSE(win) 0.01783 | test MSE(win) 0.01581 | test MSE(series) 0.01533
# [Stage3] L=3 ep 011 | train MSE(win) 0.01615 | test MSE(win) 0.01580 | test MSE(series) 0.01532
# [Stage3] L=3 ep 012 | train MSE(win) 0.01702 | test MSE(win) 0.01579 | test MSE(series) 0.01531
# [Stage3] L=3 ep 013 | train MSE(win) 0.01754 | test MSE(win) 0.01578 | test MSE(series) 0.01530
# [Stage3] L=3 ep 014 | train MSE(win) 0.01677 | test MSE(win) 0.01577 | test MSE(series) 0.01529
# [Stage3] L=3 ep 015 | train MSE(win) 0.01650 | test MSE(win) 0.01576 | test MSE(series) 0.01528
# [Stage3] L=3 ep 016 | train MSE(win) 0.01595 | test MSE(win) 0.01575 | test MSE(series) 0.01527
# [Stage3] L=3 ep 017 | train MSE(win) 0.01697 | test MSE(win) 0.01574 | test MSE(series) 0.01526
# [Stage3] L=3 ep 018 | train MSE(win) 0.01711 | test MSE(win) 0.01573 | test MSE(series) 0.01525
# [Stage3] L=3 ep 019 | train MSE(win) 0.01842 | test MSE(win) 0.01572 | test MSE(series) 0.01524
# [Stage3] L=3 ep 020 | train MSE(win) 0.01564 | test MSE(win) 0.01570 | test MSE(series) 0.01522
# [Stage3] L=3 ep 021 | train MSE(win) 0.01791 | test MSE(win) 0.01569 | test MSE(series) 0.01521
# [Stage3] L=3 ep 022 | train MSE(win) 0.01760 | test MSE(win) 0.01568 | test MSE(series) 0.01520
# [Stage3] L=3 ep 023 | train MSE(win) 0.01660 | test MSE(win) 0.01567 | test MSE(series) 0.01519
# [Final TEST] MSE(win) 0.015668 vs noisy 0.019387 → Δ +19.2%
# [Final TEST] MSE(series) 0.015187 vs noisy 0.018958 → Δ +19.9%
#
# ==============================
# Instance 5 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.556909 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.524201 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.489552 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.452701 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.416092 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.384369 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.359661 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.340076 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.324030 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.310788 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.298734 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.286384 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.274037 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.262501 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.251707 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.241364 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.231529 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.222124 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.212983 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.203994 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.195070 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.186229 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.177591 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.169327 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.161587 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.154401 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.147684 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.141326 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.135290 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.129624 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.125406 | LR 0.01000
# [Stage1] best train cost = 0.125406
# [Stage3] L=3 ep 000 | train MSE(win) 0.01267 | test MSE(win) 0.01287 | test MSE(series) 0.01202
# [Stage3] L=3 ep 001 | train MSE(win) 0.01382 | test MSE(win) 0.01287 | test MSE(series) 0.01202
# [Stage3] L=3 ep 002 | train MSE(win) 0.01333 | test MSE(win) 0.01286 | test MSE(series) 0.01202
# [Stage3] L=3 ep 003 | train MSE(win) 0.01216 | test MSE(win) 0.01286 | test MSE(series) 0.01201
# [Stage3] L=3 ep 004 | train MSE(win) 0.01162 | test MSE(win) 0.01285 | test MSE(series) 0.01201
# [Stage3] L=3 ep 005 | train MSE(win) 0.01374 | test MSE(win) 0.01284 | test MSE(series) 0.01200
# [Stage3] L=3 ep 006 | train MSE(win) 0.01370 | test MSE(win) 0.01283 | test MSE(series) 0.01199
# [Stage3] L=3 ep 007 | train MSE(win) 0.01310 | test MSE(win) 0.01282 | test MSE(series) 0.01198
# [Stage3] L=3 ep 008 | train MSE(win) 0.01338 | test MSE(win) 0.01281 | test MSE(series) 0.01197
# [Stage3] L=3 ep 009 | train MSE(win) 0.01308 | test MSE(win) 0.01280 | test MSE(series) 0.01196
# [Stage3] L=3 ep 010 | train MSE(win) 0.01386 | test MSE(win) 0.01279 | test MSE(series) 0.01195
# [Stage3] L=3 ep 011 | train MSE(win) 0.01280 | test MSE(win) 0.01278 | test MSE(series) 0.01194
# [Stage3] L=3 ep 012 | train MSE(win) 0.01343 | test MSE(win) 0.01277 | test MSE(series) 0.01193
# [Stage3] L=3 ep 013 | train MSE(win) 0.01223 | test MSE(win) 0.01275 | test MSE(series) 0.01191
# [Stage3] L=3 ep 014 | train MSE(win) 0.01231 | test MSE(win) 0.01274 | test MSE(series) 0.01190
# [Stage3] L=3 ep 015 | train MSE(win) 0.01294 | test MSE(win) 0.01272 | test MSE(series) 0.01189
# [Stage3] L=3 ep 016 | train MSE(win) 0.01257 | test MSE(win) 0.01271 | test MSE(series) 0.01187
# [Stage3] L=3 ep 017 | train MSE(win) 0.01420 | test MSE(win) 0.01269 | test MSE(series) 0.01186
# [Stage3] L=3 ep 018 | train MSE(win) 0.01280 | test MSE(win) 0.01268 | test MSE(series) 0.01184
# [Stage3] L=3 ep 019 | train MSE(win) 0.01446 | test MSE(win) 0.01266 | test MSE(series) 0.01183
# [Stage3] L=3 ep 020 | train MSE(win) 0.01210 | test MSE(win) 0.01264 | test MSE(series) 0.01181
# [Stage3] L=3 ep 021 | train MSE(win) 0.01341 | test MSE(win) 0.01262 | test MSE(series) 0.01179
# [Stage3] L=3 ep 022 | train MSE(win) 0.01378 | test MSE(win) 0.01260 | test MSE(series) 0.01177
# [Stage3] L=3 ep 023 | train MSE(win) 0.01303 | test MSE(win) 0.01258 | test MSE(series) 0.01175
# [Final TEST] MSE(win) 0.012577 vs noisy 0.019387 → Δ +35.1%
# [Final TEST] MSE(series) 0.011753 vs noisy 0.018958 → Δ +38.0%
#
# Completed 10 runs.

# %%
# ===============================
# Cell 9 — final plots & stats for all instances
# ===============================
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

ARCH_TAG = f"{n_qubits}q_{n_latent}l_{n_trash}t"
SAVE_PLOTS = True  # set False if you don't want PNGs on disk

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _seed_for_run(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3:
        return int(s3["TEST_SEED_FIXED"])
    hist = s3.get("hist_train", [])
    return 88_000 + 100*instance_id + (len(hist) - 1 if len(hist) else 0)

def plot_one(run, save_dir=None, title_note=""):
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    seed = _seed_for_run(run, inst)

    denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed)
    tr_rec = denoise_windows(psi, denoise, tr_n)
    te_rec = denoise_windows(psi, denoise, te_n)

    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_rec);te_hat  = _flatten_avg(te_rec)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    x_tr = np.arange(len(tr_pure)); x_te = np.arange(len(tr_pure), len(tr_pure)+len(te_pure))
    x_split = len(tr_pure)

    plt.figure(figsize=(12, 6))
    plt.scatter(x_tr, tr_noi, s=10, alpha=0.55, label=f"Train Noise (MSE={mse_tr_noise:0.5f})")
    plt.scatter(x_te, te_noi, s=10, alpha=0.55, label=f"Test  Noise (MSE={mse_te_noise:0.5f})")
    plt.plot(x_tr, tr_pure, linewidth=1.8, label="Train Pure")
    plt.plot(x_te, te_pure, linewidth=1.8, label="Test Pure")
    plt.plot(x_tr, tr_hat, linestyle="--", linewidth=2.0, label=f"Train Recovered (MSE={mse_tr_hat:0.5f})")
    plt.plot(x_te, te_hat, linestyle="--", linewidth=2.0, label=f"Test  Recovered (MSE={mse_te_hat:0.5f})")
    plt.axvline(x_split, color="grey", linestyle="--", alpha=0.7)
    plt.ylim(scale_low - 0.05*(scale_high - scale_low), scale_high + 0.05*(scale_high - scale_low))
    plt.xlabel(f'Range (samples={len(y)}, window size={wind_size}, step={wind_step})')
    plt.title(f'Pure vs Recovered (data=\"{DATA_ID}\", σ={EVAL_SIGMA:.3f}, '
              f'W={wind_size}, step={wind_step}, L={L}, inst={inst}) {title_note}')
    plt.legend(loc="upper center", ncol=3, frameon=False)
    plt.tight_layout()

    if SAVE_PLOTS and save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        out_png = Path(save_dir) / f"plot_{ARCH_TAG}_L{L}_inst{inst:02d}.png"
        plt.savefig(out_png, dpi=200, bbox_inches="tight", pad_inches=0.08)
        print(f"Saved plot → {out_png}")
    plt.show()

    dtr = 100*(1 - mse_tr_hat/max(mse_tr_noise,1e-12))
    dte = 100*(1 - mse_te_hat/max(mse_te_noise,1e-12))
    print(f"[Series-avg] TRAIN: noise={mse_tr_noise:0.8f}  recovered={mse_tr_hat:0.8f}  Δ={dtr:+.1f}%")
    print(f"[Series-avg] TEST : noise={mse_te_noise:0.8f}  recovered={mse_te_hat:0.8f}  Δ={dte:+.1f}%")

# -- Run plots for every trained (instance, L)
for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        if any(r["n_layers"] == L and r["instance_id"] == inst for r in ALL_RUNS):
            run = next(r for r in ALL_RUNS if r["n_layers"] == L and r["instance_id"] == inst)
            print(f"\n=== Final plot for L={L}, inst={inst} ===")
            plot_one(run, save_dir=f"{FIGURES_PATH}/final2/{ARCH_TAG}/L{L}")
# Out:
# === Final plot for L=1, inst=1 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02578072  Δ=-33.8%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02472291  Δ=-30.4%
#
# === Final plot for L=1, inst=2 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02499141  Δ=-29.7%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02382839  Δ=-25.7%
#
# === Final plot for L=1, inst=3 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02225796  Δ=-15.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02008154  Δ=-5.9%
#
# === Final plot for L=1, inst=4 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02640201  Δ=-37.0%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02547384  Δ=-34.4%
#
# === Final plot for L=1, inst=5 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02341480  Δ=-21.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02178234  Δ=-14.9%
#
# === Final plot for L=3, inst=1 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01366851  Δ=+29.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01226459  Δ=+35.3%
#
# === Final plot for L=3, inst=2 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01382306  Δ=+28.3%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01083053  Δ=+42.9%
#
# === Final plot for L=3, inst=3 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01750506  Δ=+9.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01592567  Δ=+16.0%
#
# === Final plot for L=3, inst=4 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01773671  Δ=+7.9%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01518742  Δ=+19.9%
#
# === Final plot for L=3, inst=5 ===
# Saved plot → aintern/figures/final2/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01378572  Δ=+28.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01175286  Δ=+38.0%

# %%
# ===============================
# Cell A — Circuit renderer (ψ + SWAP-reset + adjoint(φ))
# ===============================
from pathlib import Path
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as pnp

def render_and_save_circuit(
    L, phi_vec, psi_vec, save_dir, inst,
    style="pennylane", level="device", fname_prefix="circuit"
):
    """
    Draw the denoiser circuit exactly as used in Stage-3:
      1) embed_input(x)
      2) encoder with ψ
      3) SWAP-reset of the trash qubits using |0> ancillas
      4) adjoint(encoder) with fixed φ
      5) Z measurements (on the main data wires only)

    Notes:
    - Device wires: [0, 1, ..., n_qubits-1, 'anc0', 'anc1', ...]
    - SWAPs occur between trash wires (n_latent ... n_qubits-1) and the ancillas.
    """
    # --- wires: main data wires + ancillas for reset ---
    main_wires = list(range(n_qubits))
    anc_wires  = [f"anc{k}" for k in range(n_trash)]  # pretty labels
    dev_wires  = main_wires + anc_wires

    dev = qml.device("default.qubit", wires=dev_wires, shots=None)

    # freeze φ & ψ for drawing
    theta_fixed = pnp.array(phi_vec, requires_grad=False).reshape((L, n_qubits, 3))
    psi_flat    = pnp.array(psi_vec, requires_grad=False)

    # ----- Encoder body used in Stage-1/3 (matches your training template) -----
    def encoder_body(theta):
        # theta shape: (L, n_qubits, 3) for RX/RY/RZ on each qubit per layer
        for l in range(L):
            # single-qubit rotations
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=main_wires[q])
                qml.RY(theta[l, q, 1], wires=main_wires[q])
                qml.RZ(theta[l, q, 2], wires=main_wires[q])
            # ring CNOT entanglers across data wires
            for q in range(n_qubits - 1):
                qml.CNOT(wires=[main_wires[q], main_wires[q + 1]])
            qml.CNOT(wires=[main_wires[-1], main_wires[0]])

    # fixed decoder = adjoint(φ)
    def decoder_fixed():
        qml.adjoint(encoder_body)(theta_fixed)

    # --- explicit SWAP-reset (trash -> ancilla, main trash becomes |0>)
    def swap_reset_trash_to_ancilla():
        for k in range(n_trash):
            t_wire = main_wires[n_latent + k]  # trash wire in main register
            a_wire = anc_wires[k]              # corresponding ancilla at |0>
            qml.SWAP(wires=[t_wire, a_wire])

    # --- QNode for drawing (deterministic dummy input) ---
    @qml.qnode(dev)
    def denoiser_for_draw(x_in):
        # 1) input embedding on main wires (same function you use in training)
        embed_input(x_in)

        # 2) encoder with learned ψ (reuse your training helper if you prefer)
        #    If your 'encoder_template' writes to the current device wires,
        #    it will act on main_wires because those are numbered 0..n_qubits-1.
        encoder_template(psi_flat, L)

        # 3) SWAP-reset of trash qubits into ancillas
        if n_trash > 0:
            swap_reset_trash_to_ancilla()

        # 4) fixed decoder = adjoint(φ)
        decoder_fixed()

        # 5) measure main data wires (not the ancillas)
        return [qml.expval(qml.PauliZ(w)) for w in main_wires]

    # ---- render & save ----
    x_dummy = pnp.zeros(wind_size, dtype=float)  # just to build the tape
    qml.drawer.use_style(style)
    fig, ax = qml.draw_mpl(denoiser_for_draw, decimals=2, level=level)(x_dummy)

    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    out_png = save_dir / f"{fname_prefix}_L{L}_inst{int(inst):02d}.png"
    fig.savefig(out_png, dpi=220, bbox_inches="tight", pad_inches=0.1)
    plt.close(fig)
    return out_png

# %%
# ===============================
# Cell B — Save φ/ψ + circuit PNGs + CSVs
# ===============================
import json, csv, time, os
from pathlib import Path
import numpy as np
import pandas as pd

# --- helpers (local, robust) ---
def ensure_dir(p: str | Path) -> Path:
    p = Path(p); p.mkdir(parents=True, exist_ok=True); return p

def arch_tag():
    # e.g. "4q_3l_1t"
    return f"{n_qubits}q_{n_latent}l_{n_trash}t"

def inst_fname(L, inst):
    return f"inst{int(inst):02d}_L{int(L)}"

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _choose_eval_seed(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3 and s3["TEST_SEED_FIXED"] is not None:
        return int(s3["TEST_SEED_FIXED"])
    # fallback to "last-epoch" convention
    eplen = len(s3.get("hist_train", []))
    return 88_000 + 100*instance_id + max(eplen - 1, 0)

# Respect global choices if set elsewhere
DEV_NAME   = globals().get("DEV_NAME", "default.qubit")
RESET_MODE = globals().get("RESET_MODE", "swap")   # "swap" (unitary) or "measure"

# --- roots ---
ROOT = ensure_dir("qae_runs")
DATA_ROOT = ensure_dir(ROOT / DATA_ID)
ARCH_ROOT = ensure_dir(DATA_ROOT / arch_tag())

# per-layer dirs
dir_L = {L: ensure_dir(ARCH_ROOT / f"L{int(L)}") for L in set(LAYER_OPTIONS)}

# CSV paths (within arch folder)
CSV_RUNS   = ARCH_ROOT / "metrics_by_run.csv"
CSV_SUMMARY= ARCH_ROOT / "summary_by_layer.csv"

# create/ensure CSV headers
RUNS_HEADER = [
    "dataset","arch","instance_id","layer",
    "window_size","step","sigma_eval",
    "mse_train_noise","mse_train_recovered","delta_train_pct",
    "mse_test_noise","mse_test_recovered","delta_test_pct",
    "s1_best_train_cost","timestamp","bundle_json"
]
if not CSV_RUNS.exists():
    with open(CSV_RUNS, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow(RUNS_HEADER)

# ---- iterate runs and save artifacts ----
rows = []
for run in ALL_RUNS:
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    # --- params to .npy ---
    np.save(dir_L[L] / f"phi_{inst_fname(L, inst)}.npy", phi)
    np.save(dir_L[L] / f"psi_{inst_fname(L, inst)}.npy", psi)

    # --- evaluate metrics on the run's fixed test seed (or fallback) ---
    seed_eval = _choose_eval_seed(run, inst)
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed_eval)

    # Use the same reset mode as training (ensures denoiser matches what was trained)
    handles  = stage3_qnodes(L, phi, reset_mode=RESET_MODE)
    denoiser = handles["denoiser_qnode_all"]

    tr_hat_w = denoise_windows(psi, denoiser, tr_n)
    te_hat_w = denoise_windows(psi, denoiser, te_n)

    # series-level (flattened) MSEs
    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_hat_w); te_hat = _flatten_avg(te_hat_w)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    d_tr = 100.0 * (1.0 - mse_tr_hat / max(mse_tr_noise, 1e-12))
    d_te = 100.0 * (1.0 - mse_te_hat / max(mse_te_noise, 1e-12))

    # --- save circuit PNG (in arch folder, NOT inside Lx) ---
    png_path = render_and_save_circuit(L, phi, psi, save_dir=ARCH_ROOT, inst=inst,
                                       style="pennylane", level="device",
                                       fname_prefix="circuit")

    # --- compact JSON bundle (path saved in CSV for traceability) ---
    bundle = {
        "schema": {"name": "half_qae_bundle", "version": "1.0"},
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "dataset": {
            "id": DATA_ID,
            "scale_low":  float(scale_low),
            "scale_high": float(scale_high),
            "window_size": int(wind_size),
            "window_step": int(wind_step),
            "split": float(split),
        },
        "run": {
            "instance_id": inst,
            "layer": L,
            "sigma_eval": float(EVAL_SIGMA),
            "test_seed_fixed": int(run["stage3"].get("TEST_SEED_FIXED", seed_eval)),
        },
        "environment": {
            "device": DEV_NAME,
            "reset_mode": RESET_MODE,
        },
        "architecture": {
            "n_qubits": int(n_qubits),
            "n_latent": int(n_latent),
            "n_trash":  int(n_trash),
        },
        "parameters": {
            "phi": phi.tolist(),
            "psi": psi.tolist(),
        },
        "metrics_series": {
            "mse_train_noise": mse_tr_noise,
            "mse_train_recovered": mse_tr_hat,
            "delta_train_pct": d_tr,
            "mse_test_noise": mse_te_noise,
            "mse_test_recovered": mse_te_hat,
            "delta_test_pct": d_te,
        }
    }
    bundle_path = dir_L[L] / f"bundle_{inst_fname(L, inst)}.json"
    with open(bundle_path, "w", encoding="utf-8") as f:
        json.dump(bundle, f, indent=2)

    # --- row for runs CSV ---
    rows.append([
        DATA_ID, arch_tag(), inst, L,
        int(wind_size), int(wind_step), float(EVAL_SIGMA),
        mse_tr_noise, mse_tr_hat, d_tr,
        mse_te_noise, mse_te_hat, d_te,
        float(run["stage1"].get("best_train", np.nan)),
        bundle["timestamp"],
        str(bundle_path)
    ])

# upsert rows into metrics_by_run.csv (deduplicate by instance_id+layer)
if rows:
    df_new = pd.DataFrame(rows, columns=RUNS_HEADER)
    if CSV_RUNS.exists():
        df_old = pd.read_csv(CSV_RUNS)
        key_cols = ["dataset","arch","instance_id","layer"]
        df_old = df_old.drop_duplicates(subset=key_cols, keep="last")
        df_new = pd.concat([df_old, df_new], ignore_index=True)
        df_new = df_new.drop_duplicates(subset=key_cols, keep="last")
    df_new.to_csv(CSV_RUNS, index=False)
    print(f"Updated per-run metrics → {CSV_RUNS}")

# # build a tiny per-layer summary
if Path(CSV_RUNS).exists():
    df = pd.read_csv(CSV_RUNS)
    summary = (df
        .groupby("layer", as_index=True)
        .agg(
            runs=("instance_id","count"),
            mse_test_noise_mean=("mse_test_noise","mean"),
            mse_test_recovered_mean=("mse_test_recovered","mean"),
            delta_test_pct_mean=("delta_test_pct","mean"),
        )
    )
    summary.to_csv(CSV_SUMMARY)
    print(f"Saved per-layer summary → {CSV_SUMMARY}")

print(f"Artifacts saved under → {ARCH_ROOT}")
# Out:
# Updated per-run metrics → qae_runs/mackey_glass_tau30_n200/4q_2l_2t/metrics_by_run.csv
# Saved per-layer summary → qae_runs/mackey_glass_tau30_n200/4q_2l_2t/summary_by_layer.csv
# Artifacts saved under → qae_runs/mackey_glass_tau30_n200/4q_2l_2t

# %%
# ===========================
# Cell 0 — Config
# ===========================
DATA_ID = 'mackey_glass_tau17_n200'   # your dataset folder name

# Noise used in training & scoring
EVAL_SIGMA   = 0.20

# Windowing (must match qubit count for our QAE)
wind_size    = 4      # == n_qubits
wind_step    = 2

# Train/Test split on windows produced from the full series
split        = 0.75   # first 75% windows → train, last 25% → test

# Runs
INSTANCE_IDS = [1, 2, 3, 4, 5]
LAYER_OPTIONS = [1, 3]  # Stage-1/3 depth options

# Reset implementation for Stage-3:
#   'Jacob' → qml.measure(w, reset=True)  (keeps same wire count)
#   'swap'    → unitary SWAP to ancillas in |0>            (adds n_trash ancillas; enables adjoint on lightning)
RESET_MODE = 'swap'   # ← default approach

# Backends to use (you can keep both lightning; 'measure' may fall back from adjoint automatically)
STAGE1_BACKEND = 'lightning.qubit'
STAGE3_BACKEND = 'lightning.qubit'

# Logging
LOG_NAME = 'aintern'
CASE_NAME = 'half_qae'
DATA_PATH = f'{LOG_NAME}/data'
FIGURES_PATH = f'{LOG_NAME}/figures'
TRAIN_PATH = f'{LOG_NAME}/training'
PARAMS_PATH = f'{LOG_NAME}/params'
ANALYSIS_PATH = f'{LOG_NAME}/analysis'

# %%
# ===========================
# Cell 1 — Imports & utils
# ===========================
import os, sys, time, math, random, json
from pathlib import Path
import numpy as np
import pennylane as qml
from pennylane import numpy as pnp
import matplotlib.pyplot as plt

# repo utils
sys.path.append('.'); sys.path.append('..')
from qae_utils.Files import create_folder_if_needed, read_json_file, read_ts_file
from qae_utils.Window import ts_wind_make, ts_wind_split, ts_wind_flatten_avg
from qae_utils.Window import ts_add_noise
from qae_utils.Charts import multi_plot_flat_ts

# folders
for p in [FIGURES_PATH, TRAIN_PATH, PARAMS_PATH, ANALYSIS_PATH]:
    create_folder_if_needed(p)

# plotting
np.set_printoptions(suppress=True, precision=6)
plt.rcParams["figure.figsize"] = (6.5, 4)

def set_global_seed(instance_id: int):
    base = 10_000 + int(instance_id)
    random.seed(base + 11)
    np.random.seed(base + 22)
    try:
        pnp.random.seed(base + 33)
    except Exception:
        pass
    return dict(global_seed=base, numpy_seed=base+22, pnp_seed=base+33)

# %%
# ===========================
# Cell 2 — Load data & embed (robust paths)
# ===========================
import os

# keep your DATA_ID, LOG_NAME, DATA_PATH from Cell 0
# this resolver tries several roots so relative paths won't break
def _find_data_folder(data_id, log_name='aintern', preferred_root=None):
    candidates = []
    if preferred_root:
        candidates.append(preferred_root)
    # common locations
    candidates += [
        f'./{log_name}/data',
        f'../{log_name}/data',
        f'../../{log_name}/data',
        './jacobs_examples/aintern/data',
        '../jacobs_examples/aintern/data',
        '../../jacobs_examples/aintern/data',
    ]
    tried = []
    for root in candidates:
        folder = os.path.join(root, data_id)
        info_p = os.path.join(folder, 'info.json')
        x_p    = os.path.join(folder, 'x_org.arr')
        y_p    = os.path.join(folder, 'y_org.arr')
        tried.append(folder)
        if os.path.isdir(folder) and all(os.path.exists(p) for p in (info_p, x_p, y_p)):
            return folder
    raise FileNotFoundError(
        "Could not find dataset folder with required files.\n"
        f"DATA_ID='{data_id}'. Tried:\n - " + "\n - ".join(tried)
    )

# resolve the folder (uses your DATA_PATH from Cell 0 as a preference)
try:
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=DATA_PATH)
except Exception as e:
    # last resort: try without preferred_root
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=None)

data_info_path = f'{DATA_FOLDER}/info.json'
x_org_path     = f'{DATA_FOLDER}/x_org.arr'
y_org_path     = f'{DATA_FOLDER}/y_org.arr'

info = read_json_file(data_info_path)
X = read_ts_file(x_org_path).astype(int)  # indices (for plotting only)
y = read_ts_file(y_org_path)              # values (original domain)

scale_low  = float(info['scale_low'])
scale_high = float(info['scale_high'])
print(f'Using data folder: {DATA_FOLDER}')
print(f'Loaded {len(y)} samples; scale = [{scale_low:.3f}, {scale_high:.3f}]')

# quick plot (optional)
multi_plot_flat_ts([y], X_list=[0], colors=['blue'], labels=['Original'],
                   lines=['solid'], legend_cols=1, rcParams=(8, 3),
                   xlabel=f'Range (samples={len(y)})',
                   title=f'Data for model training (data=\"{DATA_ID}\")')

def embed_input(x, info_=None):
    """Map window values to RY(π·v01) with v01 from [scale_low, scale_high] → [0,1]."""
    if info_ is None: info_ = info
    lo, hi = float(info_['scale_low']), float(info_['scale_high'])
    xn = (pnp.array(x) - lo) / max(hi - lo, 1e-12)
    for i, v in enumerate(xn):
        qml.RY(v * pnp.pi, wires=i)
# Out:
# Using data folder: ../jacobs_examples/aintern/data/mackey_glass_tau17_n200
# Loaded 200 samples; scale = [0.200, 0.800]

# %%
# ===========================
# Cell 3 — Architecture (4q, 3 latent, 1 trash)
# ===========================
n_qubits = wind_size      # must equal window size
n_latent = 2
n_trash  = n_qubits - n_latent
trash_wires  = list(range(n_latent, n_qubits))  # [3] for 4q
signal_wires = list(range(n_qubits))            # diagnostics / full outputs

def make_device(nwires, backend='lightning.qubit'):
    return qml.device(backend, wires=nwires, shots=None)

def encoder_template(params, n_layers):
    """RX/RY/RZ per qubit + ring CNOT per layer."""
    assert len(params) == n_layers * n_qubits * 3
    for l in range(n_layers):
        for q in range(n_qubits):
            idx = l * n_qubits * 3 + q * 3
            qml.RX(params[idx + 0], wires=q)
            qml.RY(params[idx + 1], wires=q)
            qml.RZ(params[idx + 2], wires=q)
        for q in range(n_qubits - 1):
            qml.CNOT(wires=[q, q + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])

print(f"Architecture set: {n_qubits}q ({n_latent} latent, {n_trash} trash).")
# Out:
# Architecture set: 4q (2 latent, 2 trash).

# %%
# ===========================
# Cell 4 — Stage-1 training
# ===========================
def stage1_qnodes(n_layers):
    dev = make_device(n_qubits, backend=STAGE1_BACKEND)

    @qml.qnode(dev, interface="autograd", diff_method="adjoint")
    def trash_expectations(phi, x_clean):
        embed_input(x_clean)
        encoder_template(phi, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in trash_wires]

    return trash_expectations

def stage1_loss_on_windows(trash_expect, phi, windows_clean):
    # P(|1>) = (1 - Z)/2 on trash wires
    total = pnp.array(0.0)
    for w in windows_clean:
        z = pnp.array(trash_expect(phi, w))
        total = total + pnp.mean((1.0 - z) * 0.5)
    return total / max(len(windows_clean), 1)

def train_stage1_clean(windows_train_clean, n_layers, instance_id,
                       n_epochs=120, lr_init=0.010, patience=10, lr_patience=8):
    set_global_seed(instance_id)
    enc_shape = n_layers * n_qubits * 3
    phi = pnp.array(np.random.normal(0, 0.5, enc_shape), requires_grad=True)
    opt = qml.AdamOptimizer(stepsize=lr_init)
    lr = lr_init

    trash_expect = stage1_qnodes(n_layers)
    best_phi, best_cost = None, float("inf")
    no_improve = 0

    for ep in range(n_epochs):
        loss_fn = lambda p: stage1_loss_on_windows(trash_expect, p, windows_train_clean)
        phi, cost = opt.step_and_cost(loss_fn, phi)

        if cost < best_cost - 1e-9:
            best_cost, best_phi, no_improve = float(cost), pnp.array(phi, requires_grad=False), 0
        else:
            no_improve += 1
            if (no_improve % lr_patience) == 0:
                lr = max(lr * 0.5, 1e-4)
                opt = qml.AdamOptimizer(stepsize=lr)
                print(f"[Stage1] ↓ LR → {lr:.5f}")
            if no_improve >= patience:
                print("[Stage1] Early stopping."); break

        if ep % 5 == 0 or ep == n_epochs-1:
            print(f"[Stage1] L={n_layers} ep {ep:03d} | train {float(cost):.6f} | LR {lr:.5f}")

    return dict(phi=(best_phi if best_phi is not None else phi),
                best_train=float(best_cost))

# %%
# ===========================
# Cell 5 — Stage-3 QNodes
# ===========================
def stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET_MODE):

    need_anc = n_trash if (reset_mode == "swap" and n_trash > 0) else 0
    dev3 = make_device(n_qubits + need_anc)
    ancilla_wires = list(range(n_qubits, n_qubits + need_anc))

    theta_fixed = pnp.array(phi_stage1, requires_grad=False).reshape((n_layers, n_qubits, 3))

    def encoder_fixed_body(theta):
        for l in range(n_layers):
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=q)
                qml.RY(theta[l, q, 1], wires=q)
                qml.RZ(theta[l, q, 2], wires=q)
            for q in range(n_qubits-1):
                qml.CNOT(wires=[q, q+1])
            qml.CNOT(wires=[n_qubits-1, 0])

    def decoder_fixed():
        qml.adjoint(encoder_fixed_body)(theta_fixed)

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def encoder_only_expZ_all(flat_params, x_in):
        embed_input(x_in)
        encoder_template(flat_params, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def teacher_code_latents(x_clean):
        embed_input(x_clean)
        encoder_fixed_body(theta_fixed)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_latent)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def denoiser_qnode_all(flat_params, x_noisy):
        embed_input(x_noisy)
        encoder_template(flat_params, n_layers)

        # --- reset trash ---
        if n_trash > 0:
            if reset_mode == "Jacob":
                for w in trash_wires:
                    qml.measure(w, reset=True)
            elif reset_mode == "swap":
                # one clean ancilla per trash wire
                for t, a in zip(trash_wires, ancilla_wires):
                    # ancillas start in |0>, so SWAP puts |0> into trash, old trash into ancilla
                    qml.SWAP(wires=[t, a])

        decoder_fixed()
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    return dict(
        theta_fixed=theta_fixed,
        ancilla_wires=ancilla_wires,
        encoder_only_expZ_all=encoder_only_expZ_all,
        teacher_code_latents=teacher_code_latents,
        denoiser_qnode_all=denoiser_qnode_all
    )

def Z_to_values_autograd(z_all):
    z_all = pnp.clip(pnp.asarray(z_all), -0.999999, 0.999999)
    v01   = pnp.arccos(z_all) / pnp.pi
    return v01 * (scale_high - scale_low) + scale_low

def first_diff(x):
    x = pnp.array(x); return x[1:] - x[:-1]

def p1_from_expZ(z):
    return (1 - pnp.asarray(z)) * 0.5

def huber(residual, delta):
    r = pnp.abs(residual)
    return pnp.where(r <= delta, 0.5*r**2, delta*(r - 0.5*delta))

# %%
# ===========================
# Cell 6 — Noise & scoring helpers
# ===========================
def make_windows_from_series(y_vec, noise_sigma, seed, wind_size, wind_step):
    """
    Inject one noise vector into the whole series,
    then windowize both clean and noisy series the same way.
    """
    y_noisy = ts_add_noise(y_vec, noise=noise_sigma, noise_type='normal', clip=False,
                           range_low=scale_low, range_high=scale_high, seed=seed)

    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)

    # windows index array (not used by model, only for split helper)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])

    # split consistently
    X_tr, y_tr_clean, X_te, y_te_clean = ts_wind_split(X_ts, win_clean, split)
    X_tr, y_tr_noisy, X_te, y_te_noisy = ts_wind_split(X_ts, win_noisy, split)

    return (y_tr_clean, y_tr_noisy, y_te_clean, y_te_noisy)

def denoise_windows(params, denoise_qnode, windows_noisy):
    outs = []
    for w in windows_noisy:
        zD = pnp.array(denoise_qnode(params, w))
        outs.append(pnp.array(Z_to_values_autograd(zD)))
    return pnp.stack(outs)

def mse_on_windows(w_true, w_pred):
    w_true = np.asarray(w_true); w_pred = np.asarray(w_pred)
    return float(np.mean((w_true - w_pred)**2))

def mse_on_series_avg(w_true, w_pred, step):
    flat_true = ts_wind_flatten_avg(np.asarray(w_true), step)
    flat_pred = ts_wind_flatten_avg(np.asarray(w_pred), step)
    return float(np.mean((flat_true - flat_pred)**2))

# %%
# ===========================
# Cell 7 — Stage-3 (simple, fixed test seed, mini-batch)
# ===========================
def _series_to_train_test_windows(y_vec, sigma, seed):
    """Noise once → windowize → train/test split."""
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return np.asarray(tr_clean), np.asarray(tr_noisy), np.asarray(te_clean), np.asarray(te_noisy)

def _win_mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b)**2))

def _ser_mse(a, b):
    a = ts_wind_flatten_avg(np.asarray(a), wind_step)
    b = ts_wind_flatten_avg(np.asarray(b), wind_step)
    return float(np.mean((a - b)**2))

def train_stage3_series_noise_simple(
    y_full, phi_stage1, n_layers, instance_id,
    EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001, CLIP_NORM=1.0,
    USE_EMA=True, EMA_DECAY=0.995,
    TRAIN_SEED_BASE=88000, TEST_SEED_FIXED=99123,
    RESET=RESET_MODE,        # ← pass through
    BETA_TF=0.05,            # latent tug weight (teacher forcing)
    L_TV=0.02                # temporal smoothness weight
):
    set_global_seed(instance_id)
    handles = stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET)
    enc_all   = handles["encoder_only_expZ_all"]
    teacher_l = handles["teacher_code_latents"]
    denoise   = handles["denoiser_qnode_all"]

    # init ψ near φ
    phi_flat = pnp.array(phi_stage1, requires_grad=False)
    psi = pnp.array(np.array(phi_flat) + 0.05*np.random.randn(len(phi_flat)), requires_grad=True)

    opt = qml.AdamOptimizer(stepsize=LR)
    ema = pnp.array(psi, requires_grad=False) if USE_EMA else None

    hist_train_win_mse, hist_test_win_mse = [], []
    hist_train_ser_mse, hist_test_ser_mse = [], []

    def loss_on_batch(params, batch_clean, batch_noisy):
        total = pnp.array(0.0)
        for c, n in zip(batch_clean, batch_noisy):
            z_all = pnp.array(enc_all(params, n))
            z_sig, z_tr = z_all[:n_latent], z_all[n_latent:]
            zD   = pnp.array(denoise(params, n))
            vhat = Z_to_values_autograd(zD)

            L_rec = pnp.mean((pnp.array(c) - vhat)**2)
            L_tf  = pnp.mean(huber(pnp.array(teacher_l(c)) - z_sig, 0.25))
            L_tr  = pnp.mean(p1_from_expZ(z_tr))
            L_tv  = pnp.mean(huber(first_diff(c) - first_diff(vhat), 0.02))

            total = total + (L_rec + BETA_TF*L_tf + 0.5*L_tr + L_TV*L_tv)
        return total / max(len(batch_clean), 1)

    for ep in range(EPOCHS):
        # epoch-specific train noise
        tr_clean, tr_noisy, _, _ = make_windows_from_series(
            y_full, EVAL_SIGMA, TRAIN_SEED_BASE + ep, wind_size, wind_step
        )
        # fixed test noise
        _, _, te_clean, te_noisy = make_windows_from_series(
            y_full, EVAL_SIGMA, TEST_SEED_FIXED, wind_size, wind_step
        )

        # inner SGD steps with mini-batches
        for _ in range(INNER_STEPS):
            idx = np.random.randint(0, len(tr_clean), size=min(BATCH_SIZE, len(tr_clean)))
            batch_c = [tr_clean[i] for i in idx]
            batch_n = [tr_noisy[i] for i in idx]
            psi, _ = opt.step_and_cost(lambda p: loss_on_batch(p, batch_c, batch_n), psi)
            if USE_EMA:
                ema = EMA_DECAY * ema + (1 - EMA_DECAY) * psi

        eval_params = ema if USE_EMA else psi

        # ---- metrics
        tr_pred = denoise_windows(eval_params, denoise, tr_noisy)
        te_pred = denoise_windows(eval_params, denoise, te_noisy)

        train_mse_win = mse_on_windows(tr_clean, tr_pred)
        test_mse_win  = mse_on_windows(te_clean, te_pred)
        train_mse_ser = mse_on_series_avg(tr_clean, tr_pred, wind_step)
        test_mse_ser  = mse_on_series_avg(te_clean, te_pred, wind_step)

        hist_train_win_mse.append(float(train_mse_win))
        hist_test_win_mse.append(float(test_mse_win))
        hist_train_ser_mse.append(float(train_mse_ser))
        hist_test_ser_mse.append(float(test_mse_ser))

        print(f"[Stage3] L={n_layers} ep {ep:03d} | "
              f"train MSE(win) {train_mse_win:.5f} | "
              f"test MSE(win) {test_mse_win:.5f} | "
              f"test MSE(series) {test_mse_ser:.5f}")

    return dict(
        psi=(ema if USE_EMA else psi),
        hist_train_win_mse=hist_train_win_mse,
        hist_test_win_mse=hist_test_win_mse,
        hist_train_ser_mse=hist_train_ser_mse,
        hist_test_ser_mse=hist_test_ser_mse,
        TEST_SEED_FIXED=int(TEST_SEED_FIXED),
        RESET_MODE=str(RESET),
    )

# %%
# ===========================
# Cell 8 — Runs (instances × layers)
# ===========================
ALL_RUNS = []

for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        print("\n" + "="*30)
        print(f"Instance {inst} | Layers {L}")
        print("="*30)
        set_global_seed(inst)

        # ---- CLEAN windows once (for Stage-1 only)
        clean_windows = ts_wind_make(y, wind_size, wind_step)
        X_ts = np.array([i*wind_step for i in range(len(clean_windows))])
        _, win_tr_clean, _, win_te_clean = ts_wind_split(X_ts, clean_windows, split)
        print(f"[Windows] train={len(win_tr_clean)}, test={len(win_te_clean)} (W={wind_size}, step={wind_step})")

        # ---- Stage 1
        s1 = train_stage1_clean(
            win_tr_clean, n_layers=L, instance_id=inst,
            n_epochs=150, lr_init=0.010, patience=10, lr_patience=8
        )
        phi = s1["phi"]
        print(f"[Stage1] best train cost = {s1['best_train']:.6f}")

        # ---- Stage 3 (mentor-style reset by default)
        s3 = train_stage3_series_noise_simple(
                y_full=y, phi_stage1=phi, n_layers=L, instance_id=inst,
                EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001,
                RESET=RESET_MODE, BETA_TF=0.05, L_TV=0.02
        )

        # Final fixed-seed scoring (aligns with logs)
        seed_fix = s3.get("TEST_SEED_FIXED", 99123)
        trC, trN, teC, teN = _series_to_train_test_windows(y, EVAL_SIGMA, seed_fix)
        denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
        te_pred = denoise_windows(s3["psi"], denoise, teN)

        final_win = _win_mse(teC, te_pred)
        base_win  = _win_mse(teC, teN)
        final_ser = _ser_mse(teC, te_pred)
        base_ser  = _ser_mse(teC, teN)
        print(f"[Final TEST] MSE(win) {final_win:.6f} vs noisy {base_win:.6f} → Δ {100*(1-final_win/max(base_win,1e-12)):+.1f}%")
        print(f"[Final TEST] MSE(series) {final_ser:.6f} vs noisy {base_ser:.6f} → Δ {100*(1-final_ser/max(base_ser,1e-12)):+.1f}%")

        ALL_RUNS.append(dict(
            instance_id=inst, n_layers=L,
            stage1=dict(best_train=s1["best_train"], phi=np.array(phi)),
            stage3=dict(**s3)
        ))

print("\nCompleted", len(ALL_RUNS), "runs.")
# Out:
# ==============================
# Instance 1 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.495513 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.492231 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.488573 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.484488 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.480010 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.475199 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.470134 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.464891 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.459522 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.454044 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.448449 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.442706 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.436795 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.430741 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.424613 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.418506 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.412501 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.406659 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.401000 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.395513 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.390160 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.384890 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.379649 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.374397 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.369113 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.363807 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.358528 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.353369 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.348460 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.343948 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.340717 | LR 0.01000
# [Stage1] best train cost = 0.340717
# [Stage3] L=1 ep 000 | train MSE(win) 0.02457 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 001 | train MSE(win) 0.02467 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 002 | train MSE(win) 0.02458 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 003 | train MSE(win) 0.02461 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 004 | train MSE(win) 0.02434 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 005 | train MSE(win) 0.02460 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 006 | train MSE(win) 0.02453 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 007 | train MSE(win) 0.02460 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 008 | train MSE(win) 0.02456 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 009 | train MSE(win) 0.02434 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 010 | train MSE(win) 0.02466 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 011 | train MSE(win) 0.02450 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 012 | train MSE(win) 0.02458 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 013 | train MSE(win) 0.02430 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 014 | train MSE(win) 0.02473 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 015 | train MSE(win) 0.02462 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 016 | train MSE(win) 0.02451 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 017 | train MSE(win) 0.02431 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 018 | train MSE(win) 0.02443 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 019 | train MSE(win) 0.02466 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 020 | train MSE(win) 0.02440 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 021 | train MSE(win) 0.02455 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 022 | train MSE(win) 0.02437 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Stage3] L=1 ep 023 | train MSE(win) 0.02454 | test MSE(win) 0.02340 | test MSE(series) 0.02311
# [Final TEST] MSE(win) 0.023396 vs noisy 0.019387 → Δ -20.7%
# [Final TEST] MSE(series) 0.023105 vs noisy 0.018958 → Δ -21.9%
#
# ==============================
# Instance 2 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.537604 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.528231 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.519685 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.512310 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.506320 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.501751 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.498461 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.496173 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.494552 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.493257 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.491978 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.490451 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.488469 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.485872 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.482521 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.478289 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.473071 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.466834 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.459670 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.451815 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.443617 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.435455 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.427652 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.420410 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.413785 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.407717 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.402078 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.396724 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.391537 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.386432 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.382378 | LR 0.01000
# [Stage1] best train cost = 0.382378
# [Stage3] L=1 ep 000 | train MSE(win) 0.02402 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 001 | train MSE(win) 0.02303 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 002 | train MSE(win) 0.02333 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 003 | train MSE(win) 0.02347 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 004 | train MSE(win) 0.02439 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 005 | train MSE(win) 0.02387 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 006 | train MSE(win) 0.02419 | test MSE(win) 0.02347 | test MSE(series) 0.02284
# [Stage3] L=1 ep 007 | train MSE(win) 0.02409 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 008 | train MSE(win) 0.02349 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 009 | train MSE(win) 0.02415 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 010 | train MSE(win) 0.02442 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 011 | train MSE(win) 0.02410 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 012 | train MSE(win) 0.02418 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 013 | train MSE(win) 0.02439 | test MSE(win) 0.02348 | test MSE(series) 0.02285
# [Stage3] L=1 ep 014 | train MSE(win) 0.02339 | test MSE(win) 0.02349 | test MSE(series) 0.02285
# [Stage3] L=1 ep 015 | train MSE(win) 0.02356 | test MSE(win) 0.02349 | test MSE(series) 0.02286
# [Stage3] L=1 ep 016 | train MSE(win) 0.02482 | test MSE(win) 0.02349 | test MSE(series) 0.02286
# [Stage3] L=1 ep 017 | train MSE(win) 0.02465 | test MSE(win) 0.02349 | test MSE(series) 0.02286
# [Stage3] L=1 ep 018 | train MSE(win) 0.02393 | test MSE(win) 0.02350 | test MSE(series) 0.02286
# [Stage3] L=1 ep 019 | train MSE(win) 0.02367 | test MSE(win) 0.02350 | test MSE(series) 0.02287
# [Stage3] L=1 ep 020 | train MSE(win) 0.02408 | test MSE(win) 0.02350 | test MSE(series) 0.02287
# [Stage3] L=1 ep 021 | train MSE(win) 0.02431 | test MSE(win) 0.02350 | test MSE(series) 0.02287
# [Stage3] L=1 ep 022 | train MSE(win) 0.02421 | test MSE(win) 0.02351 | test MSE(series) 0.02287
# [Stage3] L=1 ep 023 | train MSE(win) 0.02396 | test MSE(win) 0.02351 | test MSE(series) 0.02288
# [Final TEST] MSE(win) 0.023509 vs noisy 0.019387 → Δ -21.3%
# [Final TEST] MSE(series) 0.022875 vs noisy 0.018958 → Δ -20.7%
#
# ==============================
# Instance 3 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.532474 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.522627 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.512107 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.501217 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.490175 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.478977 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.467335 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.454925 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.441689 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.427877 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.413952 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.400438 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.387789 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.376301 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.366105 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.357226 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.349631 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.343252 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.337983 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.333695 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.330249 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.327510 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.325349 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.323633 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.322227 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.320999 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.319839 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.318664 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.317425 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.316099 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.314970 | LR 0.01000
# [Stage1] best train cost = 0.314970
# [Stage3] L=1 ep 000 | train MSE(win) 0.02282 | test MSE(win) 0.02216 | test MSE(series) 0.02188
# [Stage3] L=1 ep 001 | train MSE(win) 0.02278 | test MSE(win) 0.02216 | test MSE(series) 0.02188
# [Stage3] L=1 ep 002 | train MSE(win) 0.02251 | test MSE(win) 0.02216 | test MSE(series) 0.02188
# [Stage3] L=1 ep 003 | train MSE(win) 0.02248 | test MSE(win) 0.02216 | test MSE(series) 0.02188
# [Stage3] L=1 ep 004 | train MSE(win) 0.02173 | test MSE(win) 0.02216 | test MSE(series) 0.02187
# [Stage3] L=1 ep 005 | train MSE(win) 0.02262 | test MSE(win) 0.02216 | test MSE(series) 0.02187
# [Stage3] L=1 ep 006 | train MSE(win) 0.02232 | test MSE(win) 0.02216 | test MSE(series) 0.02187
# [Stage3] L=1 ep 007 | train MSE(win) 0.02252 | test MSE(win) 0.02216 | test MSE(series) 0.02187
# [Stage3] L=1 ep 008 | train MSE(win) 0.02256 | test MSE(win) 0.02216 | test MSE(series) 0.02187
# [Stage3] L=1 ep 009 | train MSE(win) 0.02252 | test MSE(win) 0.02215 | test MSE(series) 0.02187
# [Stage3] L=1 ep 010 | train MSE(win) 0.02291 | test MSE(win) 0.02215 | test MSE(series) 0.02186
# [Stage3] L=1 ep 011 | train MSE(win) 0.02207 | test MSE(win) 0.02215 | test MSE(series) 0.02186
# [Stage3] L=1 ep 012 | train MSE(win) 0.02300 | test MSE(win) 0.02215 | test MSE(series) 0.02186
# [Stage3] L=1 ep 013 | train MSE(win) 0.02253 | test MSE(win) 0.02215 | test MSE(series) 0.02186
# [Stage3] L=1 ep 014 | train MSE(win) 0.02274 | test MSE(win) 0.02215 | test MSE(series) 0.02185
# [Stage3] L=1 ep 015 | train MSE(win) 0.02296 | test MSE(win) 0.02214 | test MSE(series) 0.02185
# [Stage3] L=1 ep 016 | train MSE(win) 0.02226 | test MSE(win) 0.02214 | test MSE(series) 0.02185
# [Stage3] L=1 ep 017 | train MSE(win) 0.02234 | test MSE(win) 0.02214 | test MSE(series) 0.02184
# [Stage3] L=1 ep 018 | train MSE(win) 0.02232 | test MSE(win) 0.02214 | test MSE(series) 0.02184
# [Stage3] L=1 ep 019 | train MSE(win) 0.02261 | test MSE(win) 0.02214 | test MSE(series) 0.02184
# [Stage3] L=1 ep 020 | train MSE(win) 0.02226 | test MSE(win) 0.02213 | test MSE(series) 0.02184
# [Stage3] L=1 ep 021 | train MSE(win) 0.02220 | test MSE(win) 0.02213 | test MSE(series) 0.02183
# [Stage3] L=1 ep 022 | train MSE(win) 0.02214 | test MSE(win) 0.02213 | test MSE(series) 0.02183
# [Stage3] L=1 ep 023 | train MSE(win) 0.02206 | test MSE(win) 0.02213 | test MSE(series) 0.02183
# [Final TEST] MSE(win) 0.022128 vs noisy 0.019387 → Δ -14.1%
# [Final TEST] MSE(series) 0.021826 vs noisy 0.018958 → Δ -15.1%
#
# ==============================
# Instance 4 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.486951 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.483233 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.479086 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.474559 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.469731 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.464700 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.459540 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.454286 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.449002 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.443786 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.438735 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.433911 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.429333 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.424974 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.420774 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.416659 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.412563 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.408434 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.404238 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.399955 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.395575 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.391095 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.386515 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.381843 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.377092 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.372283 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.367443 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.362597 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.357769 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.352981 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.349200 | LR 0.01000
# [Stage1] best train cost = 0.349200
# [Stage3] L=1 ep 000 | train MSE(win) 0.02619 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 001 | train MSE(win) 0.02627 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 002 | train MSE(win) 0.02621 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 003 | train MSE(win) 0.02623 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 004 | train MSE(win) 0.02599 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 005 | train MSE(win) 0.02622 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 006 | train MSE(win) 0.02613 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 007 | train MSE(win) 0.02626 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 008 | train MSE(win) 0.02617 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 009 | train MSE(win) 0.02598 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 010 | train MSE(win) 0.02630 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 011 | train MSE(win) 0.02609 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 012 | train MSE(win) 0.02616 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 013 | train MSE(win) 0.02598 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 014 | train MSE(win) 0.02637 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 015 | train MSE(win) 0.02631 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 016 | train MSE(win) 0.02612 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 017 | train MSE(win) 0.02594 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 018 | train MSE(win) 0.02610 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 019 | train MSE(win) 0.02628 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 020 | train MSE(win) 0.02603 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 021 | train MSE(win) 0.02617 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 022 | train MSE(win) 0.02602 | test MSE(win) 0.02494 | test MSE(series) 0.02429
# [Stage3] L=1 ep 023 | train MSE(win) 0.02614 | test MSE(win) 0.02494 | test MSE(series) 0.02428
# [Final TEST] MSE(win) 0.024944 vs noisy 0.019387 → Δ -28.7%
# [Final TEST] MSE(series) 0.024285 vs noisy 0.018958 → Δ -28.1%
#
# ==============================
# Instance 5 | Layers 1
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=1 ep 000 | train 0.493855 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.487552 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.481268 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.475218 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.469633 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.464580 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.459834 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.454973 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.449672 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.443831 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.437469 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.430640 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.423371 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.415640 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.407462 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.398936 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.390242 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.381580 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.373130 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.365047 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.357438 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.350368 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.343879 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.338005 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.332781 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.328228 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.324348 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.321116 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.318477 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.316359 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.314984 | LR 0.01000
# [Stage1] best train cost = 0.314984
# [Stage3] L=1 ep 000 | train MSE(win) 0.02225 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 001 | train MSE(win) 0.02169 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 002 | train MSE(win) 0.02119 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 003 | train MSE(win) 0.02101 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 004 | train MSE(win) 0.02028 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 005 | train MSE(win) 0.02165 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 006 | train MSE(win) 0.02097 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 007 | train MSE(win) 0.02135 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 008 | train MSE(win) 0.02140 | test MSE(win) 0.02197 | test MSE(series) 0.02115
# [Stage3] L=1 ep 009 | train MSE(win) 0.02166 | test MSE(win) 0.02197 | test MSE(series) 0.02114
# [Stage3] L=1 ep 010 | train MSE(win) 0.02211 | test MSE(win) 0.02197 | test MSE(series) 0.02114
# [Stage3] L=1 ep 011 | train MSE(win) 0.02067 | test MSE(win) 0.02197 | test MSE(series) 0.02114
# [Stage3] L=1 ep 012 | train MSE(win) 0.02212 | test MSE(win) 0.02197 | test MSE(series) 0.02114
# [Stage3] L=1 ep 013 | train MSE(win) 0.02189 | test MSE(win) 0.02196 | test MSE(series) 0.02114
# [Stage3] L=1 ep 014 | train MSE(win) 0.02160 | test MSE(win) 0.02196 | test MSE(series) 0.02114
# [Stage3] L=1 ep 015 | train MSE(win) 0.02227 | test MSE(win) 0.02196 | test MSE(series) 0.02114
# [Stage3] L=1 ep 016 | train MSE(win) 0.02099 | test MSE(win) 0.02196 | test MSE(series) 0.02114
# [Stage3] L=1 ep 017 | train MSE(win) 0.02155 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 018 | train MSE(win) 0.02119 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 019 | train MSE(win) 0.02158 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 020 | train MSE(win) 0.02110 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 021 | train MSE(win) 0.02103 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 022 | train MSE(win) 0.02122 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Stage3] L=1 ep 023 | train MSE(win) 0.02048 | test MSE(win) 0.02196 | test MSE(series) 0.02113
# [Final TEST] MSE(win) 0.021963 vs noisy 0.019387 → Δ -13.3%
# [Final TEST] MSE(series) 0.021126 vs noisy 0.018958 → Δ -11.4%
#
# ==============================
# Instance 1 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.453649 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.406148 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.367714 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.340173 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.319858 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.302743 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.287668 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.273774 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.260219 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.246854 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.233855 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.221323 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.209344 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.197969 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.187287 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.177373 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.168247 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.159931 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.152471 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.145890 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.140194 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.135359 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.131310 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.127926 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.125065 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.122595 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.120407 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.118415 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.116560 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.114814 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.113490 | LR 0.01000
# [Stage1] best train cost = 0.113490
# [Stage3] L=3 ep 000 | train MSE(win) 0.01539 | test MSE(win) 0.01560 | test MSE(series) 0.01473
# [Stage3] L=3 ep 001 | train MSE(win) 0.01410 | test MSE(win) 0.01560 | test MSE(series) 0.01472
# [Stage3] L=3 ep 002 | train MSE(win) 0.01469 | test MSE(win) 0.01560 | test MSE(series) 0.01472
# [Stage3] L=3 ep 003 | train MSE(win) 0.01253 | test MSE(win) 0.01559 | test MSE(series) 0.01472
# [Stage3] L=3 ep 004 | train MSE(win) 0.01379 | test MSE(win) 0.01559 | test MSE(series) 0.01472
# [Stage3] L=3 ep 005 | train MSE(win) 0.01441 | test MSE(win) 0.01559 | test MSE(series) 0.01471
# [Stage3] L=3 ep 006 | train MSE(win) 0.01480 | test MSE(win) 0.01559 | test MSE(series) 0.01471
# [Stage3] L=3 ep 007 | train MSE(win) 0.01418 | test MSE(win) 0.01559 | test MSE(series) 0.01471
# [Stage3] L=3 ep 008 | train MSE(win) 0.01373 | test MSE(win) 0.01558 | test MSE(series) 0.01470
# [Stage3] L=3 ep 009 | train MSE(win) 0.01553 | test MSE(win) 0.01558 | test MSE(series) 0.01470
# [Stage3] L=3 ep 010 | train MSE(win) 0.01614 | test MSE(win) 0.01558 | test MSE(series) 0.01470
# [Stage3] L=3 ep 011 | train MSE(win) 0.01383 | test MSE(win) 0.01558 | test MSE(series) 0.01469
# [Stage3] L=3 ep 012 | train MSE(win) 0.01518 | test MSE(win) 0.01558 | test MSE(series) 0.01469
# [Stage3] L=3 ep 013 | train MSE(win) 0.01421 | test MSE(win) 0.01557 | test MSE(series) 0.01468
# [Stage3] L=3 ep 014 | train MSE(win) 0.01333 | test MSE(win) 0.01557 | test MSE(series) 0.01468
# [Stage3] L=3 ep 015 | train MSE(win) 0.01411 | test MSE(win) 0.01557 | test MSE(series) 0.01467
# [Stage3] L=3 ep 016 | train MSE(win) 0.01337 | test MSE(win) 0.01556 | test MSE(series) 0.01467
# [Stage3] L=3 ep 017 | train MSE(win) 0.01493 | test MSE(win) 0.01556 | test MSE(series) 0.01466
# [Stage3] L=3 ep 018 | train MSE(win) 0.01331 | test MSE(win) 0.01556 | test MSE(series) 0.01465
# [Stage3] L=3 ep 019 | train MSE(win) 0.01406 | test MSE(win) 0.01555 | test MSE(series) 0.01465
# [Stage3] L=3 ep 020 | train MSE(win) 0.01400 | test MSE(win) 0.01555 | test MSE(series) 0.01464
# [Stage3] L=3 ep 021 | train MSE(win) 0.01353 | test MSE(win) 0.01555 | test MSE(series) 0.01464
# [Stage3] L=3 ep 022 | train MSE(win) 0.01399 | test MSE(win) 0.01554 | test MSE(series) 0.01463
# [Stage3] L=3 ep 023 | train MSE(win) 0.01324 | test MSE(win) 0.01554 | test MSE(series) 0.01463
# [Final TEST] MSE(win) 0.015542 vs noisy 0.019387 → Δ +19.8%
# [Final TEST] MSE(series) 0.014626 vs noisy 0.018958 → Δ +22.9%
#
# ==============================
# Instance 2 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.547119 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.499720 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.457192 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.422497 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.389484 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.356569 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.327079 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.302801 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.281539 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.260804 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.240228 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.220438 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.202477 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.187292 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.175182 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.165922 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.159211 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.154721 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.151761 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.149460 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.147346 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.145397 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.143712 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.142310 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.141115 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.140050 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.139072 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.138163 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.137304 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.136466 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.135790 | LR 0.01000
# [Stage1] best train cost = 0.135790
# [Stage3] L=3 ep 000 | train MSE(win) 0.01594 | test MSE(win) 0.01416 | test MSE(series) 0.01364
# [Stage3] L=3 ep 001 | train MSE(win) 0.01514 | test MSE(win) 0.01416 | test MSE(series) 0.01364
# [Stage3] L=3 ep 002 | train MSE(win) 0.01595 | test MSE(win) 0.01416 | test MSE(series) 0.01364
# [Stage3] L=3 ep 003 | train MSE(win) 0.01372 | test MSE(win) 0.01416 | test MSE(series) 0.01363
# [Stage3] L=3 ep 004 | train MSE(win) 0.01486 | test MSE(win) 0.01416 | test MSE(series) 0.01363
# [Stage3] L=3 ep 005 | train MSE(win) 0.01486 | test MSE(win) 0.01415 | test MSE(series) 0.01363
# [Stage3] L=3 ep 006 | train MSE(win) 0.01535 | test MSE(win) 0.01415 | test MSE(series) 0.01362
# [Stage3] L=3 ep 007 | train MSE(win) 0.01516 | test MSE(win) 0.01415 | test MSE(series) 0.01362
# [Stage3] L=3 ep 008 | train MSE(win) 0.01451 | test MSE(win) 0.01414 | test MSE(series) 0.01362
# [Stage3] L=3 ep 009 | train MSE(win) 0.01556 | test MSE(win) 0.01414 | test MSE(series) 0.01361
# [Stage3] L=3 ep 010 | train MSE(win) 0.01628 | test MSE(win) 0.01413 | test MSE(series) 0.01360
# [Stage3] L=3 ep 011 | train MSE(win) 0.01483 | test MSE(win) 0.01413 | test MSE(series) 0.01360
# [Stage3] L=3 ep 012 | train MSE(win) 0.01529 | test MSE(win) 0.01412 | test MSE(series) 0.01359
# [Stage3] L=3 ep 013 | train MSE(win) 0.01473 | test MSE(win) 0.01411 | test MSE(series) 0.01359
# [Stage3] L=3 ep 014 | train MSE(win) 0.01440 | test MSE(win) 0.01411 | test MSE(series) 0.01358
# [Stage3] L=3 ep 015 | train MSE(win) 0.01485 | test MSE(win) 0.01410 | test MSE(series) 0.01357
# [Stage3] L=3 ep 016 | train MSE(win) 0.01471 | test MSE(win) 0.01410 | test MSE(series) 0.01357
# [Stage3] L=3 ep 017 | train MSE(win) 0.01512 | test MSE(win) 0.01409 | test MSE(series) 0.01356
# [Stage3] L=3 ep 018 | train MSE(win) 0.01436 | test MSE(win) 0.01408 | test MSE(series) 0.01355
# [Stage3] L=3 ep 019 | train MSE(win) 0.01464 | test MSE(win) 0.01408 | test MSE(series) 0.01354
# [Stage3] L=3 ep 020 | train MSE(win) 0.01466 | test MSE(win) 0.01407 | test MSE(series) 0.01354
# [Stage3] L=3 ep 021 | train MSE(win) 0.01499 | test MSE(win) 0.01406 | test MSE(series) 0.01353
# [Stage3] L=3 ep 022 | train MSE(win) 0.01537 | test MSE(win) 0.01406 | test MSE(series) 0.01352
# [Stage3] L=3 ep 023 | train MSE(win) 0.01413 | test MSE(win) 0.01405 | test MSE(series) 0.01351
# [Final TEST] MSE(win) 0.014051 vs noisy 0.019387 → Δ +27.5%
# [Final TEST] MSE(series) 0.013514 vs noisy 0.018958 → Δ +28.7%
#
# ==============================
# Instance 3 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.462583 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.421152 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.391879 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.364623 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.338766 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.317096 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.298418 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.280786 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.263726 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.246965 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.231158 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.217575 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.207154 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.199810 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.194486 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.190335 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.187206 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.185089 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.183612 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.182305 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.180902 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.179357 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.177717 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.176043 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.174387 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.172785 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.171260 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.169815 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.168435 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.167097 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.166039 | LR 0.01000
# [Stage1] best train cost = 0.166039
# [Stage3] L=3 ep 000 | train MSE(win) 0.01850 | test MSE(win) 0.01910 | test MSE(series) 0.01800
# [Stage3] L=3 ep 001 | train MSE(win) 0.01851 | test MSE(win) 0.01910 | test MSE(series) 0.01800
# [Stage3] L=3 ep 002 | train MSE(win) 0.01821 | test MSE(win) 0.01910 | test MSE(series) 0.01800
# [Stage3] L=3 ep 003 | train MSE(win) 0.01751 | test MSE(win) 0.01909 | test MSE(series) 0.01800
# [Stage3] L=3 ep 004 | train MSE(win) 0.01796 | test MSE(win) 0.01909 | test MSE(series) 0.01799
# [Stage3] L=3 ep 005 | train MSE(win) 0.01805 | test MSE(win) 0.01909 | test MSE(series) 0.01799
# [Stage3] L=3 ep 006 | train MSE(win) 0.01906 | test MSE(win) 0.01908 | test MSE(series) 0.01799
# [Stage3] L=3 ep 007 | train MSE(win) 0.01780 | test MSE(win) 0.01908 | test MSE(series) 0.01798
# [Stage3] L=3 ep 008 | train MSE(win) 0.01787 | test MSE(win) 0.01907 | test MSE(series) 0.01798
# [Stage3] L=3 ep 009 | train MSE(win) 0.01858 | test MSE(win) 0.01907 | test MSE(series) 0.01797
# [Stage3] L=3 ep 010 | train MSE(win) 0.01890 | test MSE(win) 0.01907 | test MSE(series) 0.01797
# [Stage3] L=3 ep 011 | train MSE(win) 0.01790 | test MSE(win) 0.01906 | test MSE(series) 0.01796
# [Stage3] L=3 ep 012 | train MSE(win) 0.01843 | test MSE(win) 0.01906 | test MSE(series) 0.01796
# [Stage3] L=3 ep 013 | train MSE(win) 0.01844 | test MSE(win) 0.01905 | test MSE(series) 0.01795
# [Stage3] L=3 ep 014 | train MSE(win) 0.01776 | test MSE(win) 0.01905 | test MSE(series) 0.01795
# [Stage3] L=3 ep 015 | train MSE(win) 0.01830 | test MSE(win) 0.01905 | test MSE(series) 0.01795
# [Stage3] L=3 ep 016 | train MSE(win) 0.01767 | test MSE(win) 0.01904 | test MSE(series) 0.01794
# [Stage3] L=3 ep 017 | train MSE(win) 0.01874 | test MSE(win) 0.01904 | test MSE(series) 0.01794
# [Stage3] L=3 ep 018 | train MSE(win) 0.01768 | test MSE(win) 0.01903 | test MSE(series) 0.01793
# [Stage3] L=3 ep 019 | train MSE(win) 0.01856 | test MSE(win) 0.01903 | test MSE(series) 0.01793
# [Stage3] L=3 ep 020 | train MSE(win) 0.01822 | test MSE(win) 0.01903 | test MSE(series) 0.01793
# [Stage3] L=3 ep 021 | train MSE(win) 0.01794 | test MSE(win) 0.01902 | test MSE(series) 0.01792
# [Stage3] L=3 ep 022 | train MSE(win) 0.01873 | test MSE(win) 0.01902 | test MSE(series) 0.01792
# [Stage3] L=3 ep 023 | train MSE(win) 0.01817 | test MSE(win) 0.01902 | test MSE(series) 0.01792
# [Final TEST] MSE(win) 0.019016 vs noisy 0.019387 → Δ +1.9%
# [Final TEST] MSE(series) 0.017916 vs noisy 0.018958 → Δ +5.5%
#
# ==============================
# Instance 4 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.477038 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.441413 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.409163 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.380273 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.353731 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.330309 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.310794 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.293875 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.278314 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.264504 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.252497 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.241720 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.231778 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.222547 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.213968 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.205928 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.198452 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.191746 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.186018 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.181382 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.177790 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.175077 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.173031 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.171427 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.170078 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.168848 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.167636 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.166370 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.164988 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.163429 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.162012 | LR 0.01000
# [Stage1] best train cost = 0.162012
# [Stage3] L=3 ep 000 | train MSE(win) 0.01668 | test MSE(win) 0.01836 | test MSE(series) 0.01730
# [Stage3] L=3 ep 001 | train MSE(win) 0.01551 | test MSE(win) 0.01836 | test MSE(series) 0.01730
# [Stage3] L=3 ep 002 | train MSE(win) 0.01682 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 003 | train MSE(win) 0.01501 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 004 | train MSE(win) 0.01547 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 005 | train MSE(win) 0.01640 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 006 | train MSE(win) 0.01624 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 007 | train MSE(win) 0.01615 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 008 | train MSE(win) 0.01577 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 009 | train MSE(win) 0.01682 | test MSE(win) 0.01836 | test MSE(series) 0.01729
# [Stage3] L=3 ep 010 | train MSE(win) 0.01712 | test MSE(win) 0.01835 | test MSE(series) 0.01729
# [Stage3] L=3 ep 011 | train MSE(win) 0.01588 | test MSE(win) 0.01835 | test MSE(series) 0.01729
# [Stage3] L=3 ep 012 | train MSE(win) 0.01603 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 013 | train MSE(win) 0.01570 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 014 | train MSE(win) 0.01584 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 015 | train MSE(win) 0.01601 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 016 | train MSE(win) 0.01607 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 017 | train MSE(win) 0.01679 | test MSE(win) 0.01835 | test MSE(series) 0.01728
# [Stage3] L=3 ep 018 | train MSE(win) 0.01557 | test MSE(win) 0.01834 | test MSE(series) 0.01728
# [Stage3] L=3 ep 019 | train MSE(win) 0.01639 | test MSE(win) 0.01834 | test MSE(series) 0.01727
# [Stage3] L=3 ep 020 | train MSE(win) 0.01661 | test MSE(win) 0.01834 | test MSE(series) 0.01727
# [Stage3] L=3 ep 021 | train MSE(win) 0.01565 | test MSE(win) 0.01834 | test MSE(series) 0.01727
# [Stage3] L=3 ep 022 | train MSE(win) 0.01624 | test MSE(win) 0.01833 | test MSE(series) 0.01727
# [Stage3] L=3 ep 023 | train MSE(win) 0.01620 | test MSE(win) 0.01833 | test MSE(series) 0.01727
# [Final TEST] MSE(win) 0.018331 vs noisy 0.019387 → Δ +5.4%
# [Final TEST] MSE(series) 0.017265 vs noisy 0.018958 → Δ +8.9%
#
# ==============================
# Instance 5 | Layers 3
# ==============================
# [Windows] train=74, test=25 (W=4, step=2)
# [Stage1] L=3 ep 000 | train 0.586798 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.552703 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.513526 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.471030 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.429179 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.391347 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.360814 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.339156 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.324298 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.313167 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.304393 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.297510 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.291793 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.286481 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.281038 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.275080 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.268294 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.260388 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.251157 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.240635 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.229187 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.217501 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.206458 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.196795 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.188732 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.181939 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.175841 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.169964 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.164052 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.158038 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.153182 | LR 0.01000
# [Stage1] best train cost = 0.153182
# [Stage3] L=3 ep 000 | train MSE(win) 0.01774 | test MSE(win) 0.01880 | test MSE(series) 0.01789
# [Stage3] L=3 ep 001 | train MSE(win) 0.01770 | test MSE(win) 0.01879 | test MSE(series) 0.01789
# [Stage3] L=3 ep 002 | train MSE(win) 0.01768 | test MSE(win) 0.01879 | test MSE(series) 0.01788
# [Stage3] L=3 ep 003 | train MSE(win) 0.01605 | test MSE(win) 0.01879 | test MSE(series) 0.01788
# [Stage3] L=3 ep 004 | train MSE(win) 0.01682 | test MSE(win) 0.01879 | test MSE(series) 0.01788
# [Stage3] L=3 ep 005 | train MSE(win) 0.01733 | test MSE(win) 0.01879 | test MSE(series) 0.01788
# [Stage3] L=3 ep 006 | train MSE(win) 0.01788 | test MSE(win) 0.01878 | test MSE(series) 0.01787
# [Stage3] L=3 ep 007 | train MSE(win) 0.01684 | test MSE(win) 0.01878 | test MSE(series) 0.01787
# [Stage3] L=3 ep 008 | train MSE(win) 0.01715 | test MSE(win) 0.01877 | test MSE(series) 0.01786
# [Stage3] L=3 ep 009 | train MSE(win) 0.01715 | test MSE(win) 0.01877 | test MSE(series) 0.01786
# [Stage3] L=3 ep 010 | train MSE(win) 0.01734 | test MSE(win) 0.01876 | test MSE(series) 0.01786
# [Stage3] L=3 ep 011 | train MSE(win) 0.01767 | test MSE(win) 0.01876 | test MSE(series) 0.01785
# [Stage3] L=3 ep 012 | train MSE(win) 0.01780 | test MSE(win) 0.01875 | test MSE(series) 0.01784
# [Stage3] L=3 ep 013 | train MSE(win) 0.01650 | test MSE(win) 0.01875 | test MSE(series) 0.01784
# [Stage3] L=3 ep 014 | train MSE(win) 0.01697 | test MSE(win) 0.01874 | test MSE(series) 0.01783
# [Stage3] L=3 ep 015 | train MSE(win) 0.01703 | test MSE(win) 0.01874 | test MSE(series) 0.01783
# [Stage3] L=3 ep 016 | train MSE(win) 0.01709 | test MSE(win) 0.01873 | test MSE(series) 0.01782
# [Stage3] L=3 ep 017 | train MSE(win) 0.01848 | test MSE(win) 0.01872 | test MSE(series) 0.01782
# [Stage3] L=3 ep 018 | train MSE(win) 0.01692 | test MSE(win) 0.01872 | test MSE(series) 0.01781
# [Stage3] L=3 ep 019 | train MSE(win) 0.01777 | test MSE(win) 0.01871 | test MSE(series) 0.01780
# [Stage3] L=3 ep 020 | train MSE(win) 0.01722 | test MSE(win) 0.01870 | test MSE(series) 0.01780
# [Stage3] L=3 ep 021 | train MSE(win) 0.01722 | test MSE(win) 0.01870 | test MSE(series) 0.01779
# [Stage3] L=3 ep 022 | train MSE(win) 0.01764 | test MSE(win) 0.01869 | test MSE(series) 0.01778
# [Stage3] L=3 ep 023 | train MSE(win) 0.01698 | test MSE(win) 0.01868 | test MSE(series) 0.01777
# [Final TEST] MSE(win) 0.018679 vs noisy 0.019387 → Δ +3.7%
# [Final TEST] MSE(series) 0.017772 vs noisy 0.018958 → Δ +6.3%
#
# Completed 10 runs.

# %%
# ===============================
# Cell 9 — final plots & stats for all instances
# ===============================
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

ARCH_TAG = f"{n_qubits}q_{n_latent}l_{n_trash}t"
SAVE_PLOTS = True  # set False if you don't want PNGs on disk

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _seed_for_run(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3:
        return int(s3["TEST_SEED_FIXED"])
    hist = s3.get("hist_train", [])
    return 88_000 + 100*instance_id + (len(hist) - 1 if len(hist) else 0)

def plot_one(run, save_dir=None, title_note=""):
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    seed = _seed_for_run(run, inst)

    denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed)
    tr_rec = denoise_windows(psi, denoise, tr_n)
    te_rec = denoise_windows(psi, denoise, te_n)

    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_rec);te_hat  = _flatten_avg(te_rec)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    x_tr = np.arange(len(tr_pure)); x_te = np.arange(len(tr_pure), len(tr_pure)+len(te_pure))
    x_split = len(tr_pure)

    plt.figure(figsize=(12, 6))
    plt.scatter(x_tr, tr_noi, s=10, alpha=0.55, label=f"Train Noise (MSE={mse_tr_noise:0.5f})")
    plt.scatter(x_te, te_noi, s=10, alpha=0.55, label=f"Test  Noise (MSE={mse_te_noise:0.5f})")
    plt.plot(x_tr, tr_pure, linewidth=1.8, label="Train Pure")
    plt.plot(x_te, te_pure, linewidth=1.8, label="Test Pure")
    plt.plot(x_tr, tr_hat, linestyle="--", linewidth=2.0, label=f"Train Recovered (MSE={mse_tr_hat:0.5f})")
    plt.plot(x_te, te_hat, linestyle="--", linewidth=2.0, label=f"Test  Recovered (MSE={mse_te_hat:0.5f})")
    plt.axvline(x_split, color="grey", linestyle="--", alpha=0.7)
    plt.ylim(scale_low - 0.05*(scale_high - scale_low), scale_high + 0.05*(scale_high - scale_low))
    plt.xlabel(f'Range (samples={len(y)}, window size={wind_size}, step={wind_step})')
    plt.title(f'Pure vs Recovered (data=\"{DATA_ID}\", σ={EVAL_SIGMA:.3f}, '
              f'W={wind_size}, step={wind_step}, L={L}, inst={inst}) {title_note}')
    plt.legend(loc="upper center", ncol=3, frameon=False)
    plt.tight_layout()

    if SAVE_PLOTS and save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        out_png = Path(save_dir) / f"plot_{ARCH_TAG}_L{L}_inst{inst:02d}.png"
        plt.savefig(out_png, dpi=200, bbox_inches="tight", pad_inches=0.08)
        print(f"Saved plot → {out_png}")
    plt.show()

    dtr = 100*(1 - mse_tr_hat/max(mse_tr_noise,1e-12))
    dte = 100*(1 - mse_te_hat/max(mse_te_noise,1e-12))
    print(f"[Series-avg] TRAIN: noise={mse_tr_noise:0.8f}  recovered={mse_tr_hat:0.8f}  Δ={dtr:+.1f}%")
    print(f"[Series-avg] TEST : noise={mse_te_noise:0.8f}  recovered={mse_te_hat:0.8f}  Δ={dte:+.1f}%")

# -- Run plots for every trained (instance, L)
for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        if any(r["n_layers"] == L and r["instance_id"] == inst for r in ALL_RUNS):
            run = next(r for r in ALL_RUNS if r["n_layers"] == L and r["instance_id"] == inst)
            print(f"\n=== Final plot for L={L}, inst={inst} ===")
            plot_one(run, save_dir=f"{FIGURES_PATH}/final/{ARCH_TAG}/L{L}")
# Out:
# === Final plot for L=1, inst=1 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02432081  Δ=-26.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02310542  Δ=-21.9%
#
# === Final plot for L=1, inst=2 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02345536  Δ=-21.7%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02287546  Δ=-20.7%
#
# === Final plot for L=1, inst=3 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02242997  Δ=-16.4%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02182603  Δ=-15.1%
#
# === Final plot for L=1, inst=4 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02554260  Δ=-32.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02428491  Δ=-28.1%
#
# === Final plot for L=1, inst=5 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L1/plot_4q_2l_2t_L1_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.02123118  Δ=-10.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02112605  Δ=-11.4%
#
# === Final plot for L=3, inst=1 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst01.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01468315  Δ=+23.8%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01462571  Δ=+22.9%
#
# === Final plot for L=3, inst=2 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst02.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01517530  Δ=+21.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01351379  Δ=+28.7%
#
# === Final plot for L=3, inst=3 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst03.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01848510  Δ=+4.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01791569  Δ=+5.5%
#
# === Final plot for L=3, inst=4 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst04.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01649965  Δ=+14.4%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01726528  Δ=+8.9%
#
# === Final plot for L=3, inst=5 ===
# Saved plot → aintern/figures/final/4q_2l_2t/L3/plot_4q_2l_2t_L3_inst05.png
# [Series-avg] TRAIN: noise=0.01926807  recovered=0.01687682  Δ=+12.4%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01777237  Δ=+6.3%

# %%
# ===============================
# Cell A — Circuit renderer (ψ + SWAP-reset + adjoint(φ))
# ===============================
from pathlib import Path
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as pnp

def render_and_save_circuit(
    L, phi_vec, psi_vec, save_dir, inst,
    style="pennylane", level="device", fname_prefix="circuit"
):
    """
    Draw the denoiser circuit exactly as used in Stage-3:
      1) embed_input(x)
      2) encoder with ψ
      3) SWAP-reset of the trash qubits using |0> ancillas
      4) adjoint(encoder) with fixed φ
      5) Z measurements (on the main data wires only)

    Notes:
    - Device wires: [0, 1, ..., n_qubits-1, 'anc0', 'anc1', ...]
    - SWAPs occur between trash wires (n_latent ... n_qubits-1) and the ancillas.
    """
    # --- wires: main data wires + ancillas for reset ---
    main_wires = list(range(n_qubits))
    anc_wires  = [f"anc{k}" for k in range(n_trash)]  # pretty labels
    dev_wires  = main_wires + anc_wires

    dev = qml.device("default.qubit", wires=dev_wires, shots=None)

    # freeze φ & ψ for drawing
    theta_fixed = pnp.array(phi_vec, requires_grad=False).reshape((L, n_qubits, 3))
    psi_flat    = pnp.array(psi_vec, requires_grad=False)

    # ----- Encoder body used in Stage-1/3 (matches your training template) -----
    def encoder_body(theta):
        # theta shape: (L, n_qubits, 3) for RX/RY/RZ on each qubit per layer
        for l in range(L):
            # single-qubit rotations
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=main_wires[q])
                qml.RY(theta[l, q, 1], wires=main_wires[q])
                qml.RZ(theta[l, q, 2], wires=main_wires[q])
            # ring CNOT entanglers across data wires
            for q in range(n_qubits - 1):
                qml.CNOT(wires=[main_wires[q], main_wires[q + 1]])
            qml.CNOT(wires=[main_wires[-1], main_wires[0]])

    # fixed decoder = adjoint(φ)
    def decoder_fixed():
        qml.adjoint(encoder_body)(theta_fixed)

    # --- explicit SWAP-reset (trash -> ancilla, main trash becomes |0>)
    def swap_reset_trash_to_ancilla():
        for k in range(n_trash):
            t_wire = main_wires[n_latent + k]  # trash wire in main register
            a_wire = anc_wires[k]              # corresponding ancilla at |0>
            qml.SWAP(wires=[t_wire, a_wire])

    # --- QNode for drawing (deterministic dummy input) ---
    @qml.qnode(dev)
    def denoiser_for_draw(x_in):
        # 1) input embedding on main wires (same function you use in training)
        embed_input(x_in)

        # 2) encoder with learned ψ (reuse your training helper if you prefer)
        #    If your 'encoder_template' writes to the current device wires,
        #    it will act on main_wires because those are numbered 0..n_qubits-1.
        encoder_template(psi_flat, L)

        # 3) SWAP-reset of trash qubits into ancillas
        if n_trash > 0:
            swap_reset_trash_to_ancilla()

        # 4) fixed decoder = adjoint(φ)
        decoder_fixed()

        # 5) measure main data wires (not the ancillas)
        return [qml.expval(qml.PauliZ(w)) for w in main_wires]

    # ---- render & save ----
    x_dummy = pnp.zeros(wind_size, dtype=float)  # just to build the tape
    qml.drawer.use_style(style)
    fig, ax = qml.draw_mpl(denoiser_for_draw, decimals=2, level=level)(x_dummy)

    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    out_png = save_dir / f"{fname_prefix}_L{L}_inst{int(inst):02d}.png"
    fig.savefig(out_png, dpi=220, bbox_inches="tight", pad_inches=0.1)
    plt.close(fig)
    return out_png

# %%
# ===============================
# Cell B — Save φ/ψ + circuit PNGs + CSVs
# ===============================
import json, csv, time, os
from pathlib import Path
import numpy as np
import pandas as pd

# --- helpers (local, robust) ---
def ensure_dir(p: str | Path) -> Path:
    p = Path(p); p.mkdir(parents=True, exist_ok=True); return p

def arch_tag():
    # e.g. "4q_3l_1t"
    return f"{n_qubits}q_{n_latent}l_{n_trash}t"

def inst_fname(L, inst):
    return f"inst{int(inst):02d}_L{int(L)}"

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _choose_eval_seed(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3 and s3["TEST_SEED_FIXED"] is not None:
        return int(s3["TEST_SEED_FIXED"])
    # fallback to "last-epoch" convention
    eplen = len(s3.get("hist_train", []))
    return 88_000 + 100*instance_id + max(eplen - 1, 0)

# Respect global choices if set elsewhere
DEV_NAME   = globals().get("DEV_NAME", "default.qubit")
RESET_MODE = globals().get("RESET_MODE", "swap")   # "swap" (unitary) or "measure"

# --- roots ---
ROOT = ensure_dir("qae_runs")
DATA_ROOT = ensure_dir(ROOT / DATA_ID)
ARCH_ROOT = ensure_dir(DATA_ROOT / arch_tag())

# per-layer dirs
dir_L = {L: ensure_dir(ARCH_ROOT / f"L{int(L)}") for L in set(LAYER_OPTIONS)}

# CSV paths (within arch folder)
CSV_RUNS   = ARCH_ROOT / "metrics_by_run.csv"
CSV_SUMMARY= ARCH_ROOT / "summary_by_layer.csv"

# create/ensure CSV headers
RUNS_HEADER = [
    "dataset","arch","instance_id","layer",
    "window_size","step","sigma_eval",
    "mse_train_noise","mse_train_recovered","delta_train_pct",
    "mse_test_noise","mse_test_recovered","delta_test_pct",
    "s1_best_train_cost","timestamp","bundle_json"
]
if not CSV_RUNS.exists():
    with open(CSV_RUNS, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow(RUNS_HEADER)

# ---- iterate runs and save artifacts ----
rows = []
for run in ALL_RUNS:
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    # --- params to .npy ---
    np.save(dir_L[L] / f"phi_{inst_fname(L, inst)}.npy", phi)
    np.save(dir_L[L] / f"psi_{inst_fname(L, inst)}.npy", psi)

    # --- evaluate metrics on the run's fixed test seed (or fallback) ---
    seed_eval = _choose_eval_seed(run, inst)
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed_eval)

    # Use the same reset mode as training (ensures denoiser matches what was trained)
    handles  = stage3_qnodes(L, phi, reset_mode=RESET_MODE)
    denoiser = handles["denoiser_qnode_all"]

    tr_hat_w = denoise_windows(psi, denoiser, tr_n)
    te_hat_w = denoise_windows(psi, denoiser, te_n)

    # series-level (flattened) MSEs
    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_hat_w); te_hat = _flatten_avg(te_hat_w)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    d_tr = 100.0 * (1.0 - mse_tr_hat / max(mse_tr_noise, 1e-12))
    d_te = 100.0 * (1.0 - mse_te_hat / max(mse_te_noise, 1e-12))

    # --- save circuit PNG (in arch folder, NOT inside Lx) ---
    png_path = render_and_save_circuit(L, phi, psi, save_dir=ARCH_ROOT, inst=inst,
                                       style="pennylane", level="device",
                                       fname_prefix="circuit")

    # --- compact JSON bundle (path saved in CSV for traceability) ---
    bundle = {
        "schema": {"name": "half_qae_bundle", "version": "1.0"},
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "dataset": {
            "id": DATA_ID,
            "scale_low":  float(scale_low),
            "scale_high": float(scale_high),
            "window_size": int(wind_size),
            "window_step": int(wind_step),
            "split": float(split),
        },
        "run": {
            "instance_id": inst,
            "layer": L,
            "sigma_eval": float(EVAL_SIGMA),
            "test_seed_fixed": int(run["stage3"].get("TEST_SEED_FIXED", seed_eval)),
        },
        "environment": {
            "device": DEV_NAME,
            "reset_mode": RESET_MODE,
        },
        "architecture": {
            "n_qubits": int(n_qubits),
            "n_latent": int(n_latent),
            "n_trash":  int(n_trash),
        },
        "parameters": {
            "phi": phi.tolist(),
            "psi": psi.tolist(),
        },
        "metrics_series": {
            "mse_train_noise": mse_tr_noise,
            "mse_train_recovered": mse_tr_hat,
            "delta_train_pct": d_tr,
            "mse_test_noise": mse_te_noise,
            "mse_test_recovered": mse_te_hat,
            "delta_test_pct": d_te,
        }
    }
    bundle_path = dir_L[L] / f"bundle_{inst_fname(L, inst)}.json"
    with open(bundle_path, "w", encoding="utf-8") as f:
        json.dump(bundle, f, indent=2)

    # --- row for runs CSV ---
    rows.append([
        DATA_ID, arch_tag(), inst, L,
        int(wind_size), int(wind_step), float(EVAL_SIGMA),
        mse_tr_noise, mse_tr_hat, d_tr,
        mse_te_noise, mse_te_hat, d_te,
        float(run["stage1"].get("best_train", np.nan)),
        bundle["timestamp"],
        str(bundle_path)
    ])

# upsert rows into metrics_by_run.csv (deduplicate by instance_id+layer)
if rows:
    df_new = pd.DataFrame(rows, columns=RUNS_HEADER)
    if CSV_RUNS.exists():
        df_old = pd.read_csv(CSV_RUNS)
        key_cols = ["dataset","arch","instance_id","layer"]
        df_old = df_old.drop_duplicates(subset=key_cols, keep="last")
        df_new = pd.concat([df_old, df_new], ignore_index=True)
        df_new = df_new.drop_duplicates(subset=key_cols, keep="last")
    df_new.to_csv(CSV_RUNS, index=False)
    print(f"Updated per-run metrics → {CSV_RUNS}")

# # build a tiny per-layer summary
if Path(CSV_RUNS).exists():
    df = pd.read_csv(CSV_RUNS)
    summary = (df
        .groupby("layer", as_index=True)
        .agg(
            runs=("instance_id","count"),
            mse_test_noise_mean=("mse_test_noise","mean"),
            mse_test_recovered_mean=("mse_test_recovered","mean"),
            delta_test_pct_mean=("delta_test_pct","mean"),
        )
    )
    summary.to_csv(CSV_SUMMARY)
    print(f"Saved per-layer summary → {CSV_SUMMARY}")

print(f"Artifacts saved under → {ARCH_ROOT}")
# Out:
# Updated per-run metrics → qae_runs/mackey_glass_tau17_n200/4q_2l_2t/metrics_by_run.csv
# Saved per-layer summary → qae_runs/mackey_glass_tau17_n200/4q_2l_2t/summary_by_layer.csv
# Artifacts saved under → qae_runs/mackey_glass_tau17_n200/4q_2l_2t

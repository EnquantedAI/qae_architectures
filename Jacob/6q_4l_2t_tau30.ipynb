# %%
# ===========================
# Cell 0 — Config
# ===========================
DATA_ID = 'mackey_glass_tau30_n200'   # your dataset folder name

# Noise used in training & scoring
EVAL_SIGMA   = 0.20

# Windowing (must match qubit count for our QAE)
wind_size    = 6     # == n_qubits
wind_step    = 2

# Train/Test split on windows produced from the full series
split        = 0.75   # first 75% windows → train, last 25% → test

# Runs
INSTANCE_IDS = [1, 2, 3, 4, 5]
LAYER_OPTIONS = [1, 3]  # Stage-1/3 depth options

# Reset implementation for Stage-3:
#   'Jacob' → qml.measure(w, reset=True)  (keeps same wire count)
#   'swap'    → unitary SWAP to ancillas in |0>            (adds n_trash ancillas; enables adjoint on lightning)
RESET_MODE = 'swap'   # ← default approach

# Backends to use (you can keep both lightning; 'measure' may fall back from adjoint automatically)
STAGE1_BACKEND = 'lightning.qubit'
STAGE3_BACKEND = 'lightning.qubit'

# Logging
LOG_NAME = 'aintern'
CASE_NAME = 'half_qae'
DATA_PATH = f'{LOG_NAME}/data'
FIGURES_PATH = f'{LOG_NAME}/figures'
TRAIN_PATH = f'{LOG_NAME}/training'
PARAMS_PATH = f'{LOG_NAME}/params'
ANALYSIS_PATH = f'{LOG_NAME}/analysis'

# %%
# ===========================
# Cell 1 — Imports & utils
# ===========================
import os, sys, time, math, random, json
from pathlib import Path
import numpy as np
import pennylane as qml
from pennylane import numpy as pnp
import matplotlib.pyplot as plt

# repo utils
sys.path.append('.'); sys.path.append('..')
from qae_utils.Files import create_folder_if_needed, read_json_file, read_ts_file
from qae_utils.Window import ts_wind_make, ts_wind_split, ts_wind_flatten_avg
from qae_utils.Window import ts_add_noise
from qae_utils.Charts import multi_plot_flat_ts

# folders
for p in [FIGURES_PATH, TRAIN_PATH, PARAMS_PATH, ANALYSIS_PATH]:
    create_folder_if_needed(p)

# plotting
np.set_printoptions(suppress=True, precision=6)
plt.rcParams["figure.figsize"] = (6.5, 4)

def set_global_seed(instance_id: int):
    base = 10_000 + int(instance_id)
    random.seed(base + 11)
    np.random.seed(base + 22)
    try:
        pnp.random.seed(base + 33)
    except Exception:
        pass
    return dict(global_seed=base, numpy_seed=base+22, pnp_seed=base+33)

# %%
# ===========================
# Cell 2 — Load data & embed (robust paths)
# ===========================
import os

# keep your DATA_ID, LOG_NAME, DATA_PATH from Cell 0
# this resolver tries several roots so relative paths won't break
def _find_data_folder(data_id, log_name='aintern', preferred_root=None):
    candidates = []
    if preferred_root:
        candidates.append(preferred_root)
    # common locations
    candidates += [
        f'./{log_name}/data',
        f'../{log_name}/data',
        f'../../{log_name}/data',
        './jacobs_examples/aintern/data',
        '../jacobs_examples/aintern/data',
        '../../jacobs_examples/aintern/data',
    ]
    tried = []
    for root in candidates:
        folder = os.path.join(root, data_id)
        info_p = os.path.join(folder, 'info.json')
        x_p    = os.path.join(folder, 'x_org.arr')
        y_p    = os.path.join(folder, 'y_org.arr')
        tried.append(folder)
        if os.path.isdir(folder) and all(os.path.exists(p) for p in (info_p, x_p, y_p)):
            return folder
    raise FileNotFoundError(
        "Could not find dataset folder with required files.\n"
        f"DATA_ID='{data_id}'. Tried:\n - " + "\n - ".join(tried)
    )

# resolve the folder (uses your DATA_PATH from Cell 0 as a preference)
try:
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=DATA_PATH)
except Exception as e:
    # last resort: try without preferred_root
    DATA_FOLDER = _find_data_folder(DATA_ID, log_name=LOG_NAME, preferred_root=None)

data_info_path = f'{DATA_FOLDER}/info.json'
x_org_path     = f'{DATA_FOLDER}/x_org.arr'
y_org_path     = f'{DATA_FOLDER}/y_org.arr'

info = read_json_file(data_info_path)
X = read_ts_file(x_org_path).astype(int)  # indices (for plotting only)
y = read_ts_file(y_org_path)              # values (original domain)

scale_low  = float(info['scale_low'])
scale_high = float(info['scale_high'])
print(f'Using data folder: {DATA_FOLDER}')
print(f'Loaded {len(y)} samples; scale = [{scale_low:.3f}, {scale_high:.3f}]')

# quick plot (optional)
multi_plot_flat_ts([y], X_list=[0], colors=['blue'], labels=['Original'],
                   lines=['solid'], legend_cols=1, rcParams=(8, 3),
                   xlabel=f'Range (samples={len(y)})',
                   title=f'Data for model training (data=\"{DATA_ID}\")')

def embed_input(x, info_=None):
    """Map window values to RY(π·v01) with v01 from [scale_low, scale_high] → [0,1]."""
    if info_ is None: info_ = info
    lo, hi = float(info_['scale_low']), float(info_['scale_high'])
    xn = (pnp.array(x) - lo) / max(hi - lo, 1e-12)
    for i, v in enumerate(xn):
        qml.RY(v * pnp.pi, wires=i)
# Out:
# Using data folder: ../jacobs_examples/aintern/data/mackey_glass_tau30_n200
# Loaded 200 samples; scale = [0.200, 0.800]

# %%
# ===========================
# Cell 3 — Architecture (4q, 3 latent, 1 trash)
# ===========================
n_qubits = wind_size      # must equal window size
n_latent = 4
n_trash  = n_qubits - n_latent
trash_wires  = list(range(n_latent, n_qubits))  # [3] for 4q
signal_wires = list(range(n_qubits))            # diagnostics / full outputs

def make_device(nwires, backend='lightning.qubit'):
    return qml.device(backend, wires=nwires, shots=None)

def encoder_template(params, n_layers):
    """RX/RY/RZ per qubit + ring CNOT per layer."""
    assert len(params) == n_layers * n_qubits * 3
    for l in range(n_layers):
        for q in range(n_qubits):
            idx = l * n_qubits * 3 + q * 3
            qml.RX(params[idx + 0], wires=q)
            qml.RY(params[idx + 1], wires=q)
            qml.RZ(params[idx + 2], wires=q)
        for q in range(n_qubits - 1):
            qml.CNOT(wires=[q, q + 1])
        qml.CNOT(wires=[n_qubits - 1, 0])

print(f"Architecture set: {n_qubits}q ({n_latent} latent, {n_trash} trash).")
# Out:
# Architecture set: 6q (4 latent, 2 trash).

# %%
# ===========================
# Cell 4 — Stage-1 training
# ===========================
def stage1_qnodes(n_layers):
    dev = make_device(n_qubits, backend=STAGE1_BACKEND)

    @qml.qnode(dev, interface="autograd", diff_method="adjoint")
    def trash_expectations(phi, x_clean):
        embed_input(x_clean)
        encoder_template(phi, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in trash_wires]

    return trash_expectations

def stage1_loss_on_windows(trash_expect, phi, windows_clean):
    # P(|1>) = (1 - Z)/2 on trash wires
    total = pnp.array(0.0)
    for w in windows_clean:
        z = pnp.array(trash_expect(phi, w))
        total = total + pnp.mean((1.0 - z) * 0.5)
    return total / max(len(windows_clean), 1)

def train_stage1_clean(windows_train_clean, n_layers, instance_id,
                       n_epochs=120, lr_init=0.010, patience=10, lr_patience=8):
    set_global_seed(instance_id)
    enc_shape = n_layers * n_qubits * 3
    phi = pnp.array(np.random.normal(0, 0.5, enc_shape), requires_grad=True)
    opt = qml.AdamOptimizer(stepsize=lr_init)
    lr = lr_init

    trash_expect = stage1_qnodes(n_layers)
    best_phi, best_cost = None, float("inf")
    no_improve = 0

    for ep in range(n_epochs):
        loss_fn = lambda p: stage1_loss_on_windows(trash_expect, p, windows_train_clean)
        phi, cost = opt.step_and_cost(loss_fn, phi)

        if cost < best_cost - 1e-9:
            best_cost, best_phi, no_improve = float(cost), pnp.array(phi, requires_grad=False), 0
        else:
            no_improve += 1
            if (no_improve % lr_patience) == 0:
                lr = max(lr * 0.5, 1e-4)
                opt = qml.AdamOptimizer(stepsize=lr)
                print(f"[Stage1] ↓ LR → {lr:.5f}")
            if no_improve >= patience:
                print("[Stage1] Early stopping."); break

        if ep % 5 == 0 or ep == n_epochs-1:
            print(f"[Stage1] L={n_layers} ep {ep:03d} | train {float(cost):.6f} | LR {lr:.5f}")

    return dict(phi=(best_phi if best_phi is not None else phi),
                best_train=float(best_cost))

# %%
# ===========================
# Cell 5 — Stage-3 QNodes
# ===========================
def stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET_MODE):

    need_anc = n_trash if (reset_mode == "swap" and n_trash > 0) else 0
    dev3 = make_device(n_qubits + need_anc)
    ancilla_wires = list(range(n_qubits, n_qubits + need_anc))

    theta_fixed = pnp.array(phi_stage1, requires_grad=False).reshape((n_layers, n_qubits, 3))

    def encoder_fixed_body(theta):
        for l in range(n_layers):
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=q)
                qml.RY(theta[l, q, 1], wires=q)
                qml.RZ(theta[l, q, 2], wires=q)
            for q in range(n_qubits-1):
                qml.CNOT(wires=[q, q+1])
            qml.CNOT(wires=[n_qubits-1, 0])

    def decoder_fixed():
        qml.adjoint(encoder_fixed_body)(theta_fixed)

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def encoder_only_expZ_all(flat_params, x_in):
        embed_input(x_in)
        encoder_template(flat_params, n_layers)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def teacher_code_latents(x_clean):
        embed_input(x_clean)
        encoder_fixed_body(theta_fixed)
        return [qml.expval(qml.PauliZ(w)) for w in range(n_latent)]

    @qml.qnode(dev3, interface="autograd", diff_method="adjoint")
    def denoiser_qnode_all(flat_params, x_noisy):
        embed_input(x_noisy)
        encoder_template(flat_params, n_layers)

        # --- reset trash ---
        if n_trash > 0:
            if reset_mode == "Jacob":
                for w in trash_wires:
                    qml.measure(w, reset=True)
            elif reset_mode == "swap":
                # one clean ancilla per trash wire
                for t, a in zip(trash_wires, ancilla_wires):
                    # ancillas start in |0>, so SWAP puts |0> into trash, old trash into ancilla
                    qml.SWAP(wires=[t, a])

        decoder_fixed()
        return [qml.expval(qml.PauliZ(w)) for w in range(n_qubits)]

    return dict(
        theta_fixed=theta_fixed,
        ancilla_wires=ancilla_wires,
        encoder_only_expZ_all=encoder_only_expZ_all,
        teacher_code_latents=teacher_code_latents,
        denoiser_qnode_all=denoiser_qnode_all
    )

def Z_to_values_autograd(z_all):
    z_all = pnp.clip(pnp.asarray(z_all), -0.999999, 0.999999)
    v01   = pnp.arccos(z_all) / pnp.pi
    return v01 * (scale_high - scale_low) + scale_low

def first_diff(x):
    x = pnp.array(x); return x[1:] - x[:-1]

def p1_from_expZ(z):
    return (1 - pnp.asarray(z)) * 0.5

def huber(residual, delta):
    r = pnp.abs(residual)
    return pnp.where(r <= delta, 0.5*r**2, delta*(r - 0.5*delta))

# %%
# ===========================
# Cell 6 — Noise & scoring helpers
# ===========================
def make_windows_from_series(y_vec, noise_sigma, seed, wind_size, wind_step):
    """
    Inject one noise vector into the whole series,
    then windowize both clean and noisy series the same way.
    """
    y_noisy = ts_add_noise(y_vec, noise=noise_sigma, noise_type='normal', clip=False,
                           range_low=scale_low, range_high=scale_high, seed=seed)

    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)

    # windows index array (not used by model, only for split helper)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])

    # split consistently
    X_tr, y_tr_clean, X_te, y_te_clean = ts_wind_split(X_ts, win_clean, split)
    X_tr, y_tr_noisy, X_te, y_te_noisy = ts_wind_split(X_ts, win_noisy, split)

    return (y_tr_clean, y_tr_noisy, y_te_clean, y_te_noisy)

def denoise_windows(params, denoise_qnode, windows_noisy):
    outs = []
    for w in windows_noisy:
        zD = pnp.array(denoise_qnode(params, w))
        outs.append(pnp.array(Z_to_values_autograd(zD)))
    return pnp.stack(outs)

def mse_on_windows(w_true, w_pred):
    w_true = np.asarray(w_true); w_pred = np.asarray(w_pred)
    return float(np.mean((w_true - w_pred)**2))

def mse_on_series_avg(w_true, w_pred, step):
    flat_true = ts_wind_flatten_avg(np.asarray(w_true), step)
    flat_pred = ts_wind_flatten_avg(np.asarray(w_pred), step)
    return float(np.mean((flat_true - flat_pred)**2))

# %%
# ===========================
# Cell 7 — Stage-3 (simple, fixed test seed, mini-batch)
# ===========================
def _series_to_train_test_windows(y_vec, sigma, seed):
    """Noise once → windowize → train/test split."""
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return np.asarray(tr_clean), np.asarray(tr_noisy), np.asarray(te_clean), np.asarray(te_noisy)

def _win_mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b)**2))

def _ser_mse(a, b):
    a = ts_wind_flatten_avg(np.asarray(a), wind_step)
    b = ts_wind_flatten_avg(np.asarray(b), wind_step)
    return float(np.mean((a - b)**2))

def train_stage3_series_noise_simple(
    y_full, phi_stage1, n_layers, instance_id,
    EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001, CLIP_NORM=1.0,
    USE_EMA=True, EMA_DECAY=0.995,
    TRAIN_SEED_BASE=88000, TEST_SEED_FIXED=99123,
    RESET=RESET_MODE,        # ← pass through
    BETA_TF=0.05,            # latent tug weight (teacher forcing)
    L_TV=0.02                # temporal smoothness weight
):
    set_global_seed(instance_id)
    handles = stage3_qnodes(n_layers, phi_stage1, reset_mode=RESET)
    enc_all   = handles["encoder_only_expZ_all"]
    teacher_l = handles["teacher_code_latents"]
    denoise   = handles["denoiser_qnode_all"]

    # init ψ near φ
    phi_flat = pnp.array(phi_stage1, requires_grad=False)
    psi = pnp.array(np.array(phi_flat) + 0.05*np.random.randn(len(phi_flat)), requires_grad=True)

    opt = qml.AdamOptimizer(stepsize=LR)
    ema = pnp.array(psi, requires_grad=False) if USE_EMA else None

    hist_train_win_mse, hist_test_win_mse = [], []
    hist_train_ser_mse, hist_test_ser_mse = [], []

    def loss_on_batch(params, batch_clean, batch_noisy):
        total = pnp.array(0.0)
        for c, n in zip(batch_clean, batch_noisy):
            z_all = pnp.array(enc_all(params, n))
            z_sig, z_tr = z_all[:n_latent], z_all[n_latent:]
            zD   = pnp.array(denoise(params, n))
            vhat = Z_to_values_autograd(zD)

            L_rec = pnp.mean((pnp.array(c) - vhat)**2)
            L_tf  = pnp.mean(huber(pnp.array(teacher_l(c)) - z_sig, 0.25))
            L_tr  = pnp.mean(p1_from_expZ(z_tr))
            L_tv  = pnp.mean(huber(first_diff(c) - first_diff(vhat), 0.02))

            total = total + (L_rec + BETA_TF*L_tf + 0.5*L_tr + L_TV*L_tv)
        return total / max(len(batch_clean), 1)

    for ep in range(EPOCHS):
        # epoch-specific train noise
        tr_clean, tr_noisy, _, _ = make_windows_from_series(
            y_full, EVAL_SIGMA, TRAIN_SEED_BASE + ep, wind_size, wind_step
        )
        # fixed test noise
        _, _, te_clean, te_noisy = make_windows_from_series(
            y_full, EVAL_SIGMA, TEST_SEED_FIXED, wind_size, wind_step
        )

        # inner SGD steps with mini-batches
        for _ in range(INNER_STEPS):
            idx = np.random.randint(0, len(tr_clean), size=min(BATCH_SIZE, len(tr_clean)))
            batch_c = [tr_clean[i] for i in idx]
            batch_n = [tr_noisy[i] for i in idx]
            psi, _ = opt.step_and_cost(lambda p: loss_on_batch(p, batch_c, batch_n), psi)
            if USE_EMA:
                ema = EMA_DECAY * ema + (1 - EMA_DECAY) * psi

        eval_params = ema if USE_EMA else psi

        # ---- metrics
        tr_pred = denoise_windows(eval_params, denoise, tr_noisy)
        te_pred = denoise_windows(eval_params, denoise, te_noisy)

        train_mse_win = mse_on_windows(tr_clean, tr_pred)
        test_mse_win  = mse_on_windows(te_clean, te_pred)
        train_mse_ser = mse_on_series_avg(tr_clean, tr_pred, wind_step)
        test_mse_ser  = mse_on_series_avg(te_clean, te_pred, wind_step)

        hist_train_win_mse.append(float(train_mse_win))
        hist_test_win_mse.append(float(test_mse_win))
        hist_train_ser_mse.append(float(train_mse_ser))
        hist_test_ser_mse.append(float(test_mse_ser))

        print(f"[Stage3] L={n_layers} ep {ep:03d} | "
              f"train MSE(win) {train_mse_win:.5f} | "
              f"test MSE(win) {test_mse_win:.5f} | "
              f"test MSE(series) {test_mse_ser:.5f}")

    return dict(
        psi=(ema if USE_EMA else psi),
        hist_train_win_mse=hist_train_win_mse,
        hist_test_win_mse=hist_test_win_mse,
        hist_train_ser_mse=hist_train_ser_mse,
        hist_test_ser_mse=hist_test_ser_mse,
        TEST_SEED_FIXED=int(TEST_SEED_FIXED),
        RESET_MODE=str(RESET),
    )

# %%
# ===========================
# Cell 8 — Runs (instances × layers)
# ===========================
ALL_RUNS = []

for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        print("\n" + "="*30)
        print(f"Instance {inst} | Layers {L}")
        print("="*30)
        set_global_seed(inst)

        # ---- CLEAN windows once (for Stage-1 only)
        clean_windows = ts_wind_make(y, wind_size, wind_step)
        X_ts = np.array([i*wind_step for i in range(len(clean_windows))])
        _, win_tr_clean, _, win_te_clean = ts_wind_split(X_ts, clean_windows, split)
        print(f"[Windows] train={len(win_tr_clean)}, test={len(win_te_clean)} (W={wind_size}, step={wind_step})")

        # ---- Stage 1
        s1 = train_stage1_clean(
            win_tr_clean, n_layers=L, instance_id=inst,
            n_epochs=150, lr_init=0.010, patience=10, lr_patience=8
        )
        phi = s1["phi"]
        print(f"[Stage1] best train cost = {s1['best_train']:.6f}")

        # ---- Stage 3 (mentor-style reset by default)
        s3 = train_stage3_series_noise_simple(
                y_full=y, phi_stage1=phi, n_layers=L, instance_id=inst,
                EPOCHS=24, INNER_STEPS=6, BATCH_SIZE=64, LR=0.001,
                RESET=RESET_MODE, BETA_TF=0.05, L_TV=0.02
        )

        # Final fixed-seed scoring (aligns with logs)
        seed_fix = s3.get("TEST_SEED_FIXED", 99123)
        trC, trN, teC, teN = _series_to_train_test_windows(y, EVAL_SIGMA, seed_fix)
        denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
        te_pred = denoise_windows(s3["psi"], denoise, teN)

        final_win = _win_mse(teC, te_pred)
        base_win  = _win_mse(teC, teN)
        final_ser = _ser_mse(teC, te_pred)
        base_ser  = _ser_mse(teC, teN)
        print(f"[Final TEST] MSE(win) {final_win:.6f} vs noisy {base_win:.6f} → Δ {100*(1-final_win/max(base_win,1e-12)):+.1f}%")
        print(f"[Final TEST] MSE(series) {final_ser:.6f} vs noisy {base_ser:.6f} → Δ {100*(1-final_ser/max(base_ser,1e-12)):+.1f}%")

        ALL_RUNS.append(dict(
            instance_id=inst, n_layers=L,
            stage1=dict(best_train=s1["best_train"], phi=np.array(phi)),
            stage3=dict(**s3)
        ))

print("\nCompleted", len(ALL_RUNS), "runs.")
# Out:
# ==============================
# Instance 1 | Layers 1
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=1 ep 000 | train 0.502531 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.499253 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.496164 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.493028 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.489790 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.486398 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.482817 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.479133 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.475495 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.472017 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.468775 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.465784 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.463036 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.460521 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.458220 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.456115 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.454203 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.452499 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.451012 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.449730 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.448617 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.447618 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.446660 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.445649 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.444486 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.443093 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.441430 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.439496 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.437304 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.434832 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.432602 | LR 0.01000
# [Stage1] best train cost = 0.432602
# [Stage3] L=1 ep 000 | train MSE(win) 0.02513 | test MSE(win) 0.02493 | test MSE(series) 0.02321
# [Stage3] L=1 ep 001 | train MSE(win) 0.02423 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 002 | train MSE(win) 0.02461 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 003 | train MSE(win) 0.02453 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 004 | train MSE(win) 0.02461 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 005 | train MSE(win) 0.02445 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 006 | train MSE(win) 0.02417 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 007 | train MSE(win) 0.02495 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 008 | train MSE(win) 0.02412 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 009 | train MSE(win) 0.02538 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 010 | train MSE(win) 0.02456 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 011 | train MSE(win) 0.02445 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 012 | train MSE(win) 0.02449 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 013 | train MSE(win) 0.02394 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 014 | train MSE(win) 0.02372 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 015 | train MSE(win) 0.02422 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 016 | train MSE(win) 0.02496 | test MSE(win) 0.02492 | test MSE(series) 0.02321
# [Stage3] L=1 ep 017 | train MSE(win) 0.02489 | test MSE(win) 0.02492 | test MSE(series) 0.02320
# [Stage3] L=1 ep 018 | train MSE(win) 0.02504 | test MSE(win) 0.02492 | test MSE(series) 0.02320
# [Stage3] L=1 ep 019 | train MSE(win) 0.02473 | test MSE(win) 0.02492 | test MSE(series) 0.02320
# [Stage3] L=1 ep 020 | train MSE(win) 0.02509 | test MSE(win) 0.02492 | test MSE(series) 0.02320
# [Stage3] L=1 ep 021 | train MSE(win) 0.02424 | test MSE(win) 0.02492 | test MSE(series) 0.02320
# [Stage3] L=1 ep 022 | train MSE(win) 0.02442 | test MSE(win) 0.02491 | test MSE(series) 0.02320
# [Stage3] L=1 ep 023 | train MSE(win) 0.02446 | test MSE(win) 0.02491 | test MSE(series) 0.02320
# [Final TEST] MSE(win) 0.024914 vs noisy 0.019911 → Δ -25.1%
# [Final TEST] MSE(series) 0.023199 vs noisy 0.018958 → Δ -22.4%
#
# ==============================
# Instance 2 | Layers 1
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=1 ep 000 | train 0.507015 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.504548 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.502581 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.501109 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.499990 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.499061 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.498209 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.497335 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.496339 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.495113 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.493537 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.491485 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.488877 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.485720 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.482091 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.478042 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.473561 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.468689 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.463665 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.458812 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.454424 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.450739 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.447788 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.445405 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.443357 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.441382 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.439179 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.436406 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.432818 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.428398 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.424379 | LR 0.01000
# [Stage1] best train cost = 0.424379
# [Stage3] L=1 ep 000 | train MSE(win) 0.02324 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 001 | train MSE(win) 0.02310 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 002 | train MSE(win) 0.02315 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 003 | train MSE(win) 0.02222 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 004 | train MSE(win) 0.02206 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 005 | train MSE(win) 0.02286 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 006 | train MSE(win) 0.02300 | test MSE(win) 0.02144 | test MSE(series) 0.01842
# [Stage3] L=1 ep 007 | train MSE(win) 0.02252 | test MSE(win) 0.02143 | test MSE(series) 0.01841
# [Stage3] L=1 ep 008 | train MSE(win) 0.02338 | test MSE(win) 0.02143 | test MSE(series) 0.01841
# [Stage3] L=1 ep 009 | train MSE(win) 0.02254 | test MSE(win) 0.02143 | test MSE(series) 0.01841
# [Stage3] L=1 ep 010 | train MSE(win) 0.02288 | test MSE(win) 0.02143 | test MSE(series) 0.01840
# [Stage3] L=1 ep 011 | train MSE(win) 0.02212 | test MSE(win) 0.02142 | test MSE(series) 0.01840
# [Stage3] L=1 ep 012 | train MSE(win) 0.02312 | test MSE(win) 0.02142 | test MSE(series) 0.01839
# [Stage3] L=1 ep 013 | train MSE(win) 0.02299 | test MSE(win) 0.02141 | test MSE(series) 0.01839
# [Stage3] L=1 ep 014 | train MSE(win) 0.02263 | test MSE(win) 0.02140 | test MSE(series) 0.01838
# [Stage3] L=1 ep 015 | train MSE(win) 0.02256 | test MSE(win) 0.02140 | test MSE(series) 0.01838
# [Stage3] L=1 ep 016 | train MSE(win) 0.02189 | test MSE(win) 0.02139 | test MSE(series) 0.01837
# [Stage3] L=1 ep 017 | train MSE(win) 0.02226 | test MSE(win) 0.02138 | test MSE(series) 0.01836
# [Stage3] L=1 ep 018 | train MSE(win) 0.02265 | test MSE(win) 0.02137 | test MSE(series) 0.01836
# [Stage3] L=1 ep 019 | train MSE(win) 0.02324 | test MSE(win) 0.02137 | test MSE(series) 0.01835
# [Stage3] L=1 ep 020 | train MSE(win) 0.02200 | test MSE(win) 0.02136 | test MSE(series) 0.01834
# [Stage3] L=1 ep 021 | train MSE(win) 0.02368 | test MSE(win) 0.02135 | test MSE(series) 0.01833
# [Stage3] L=1 ep 022 | train MSE(win) 0.02309 | test MSE(win) 0.02134 | test MSE(series) 0.01832
# [Stage3] L=1 ep 023 | train MSE(win) 0.02148 | test MSE(win) 0.02133 | test MSE(series) 0.01831
# [Final TEST] MSE(win) 0.021328 vs noisy 0.019911 → Δ -7.1%
# [Final TEST] MSE(series) 0.018312 vs noisy 0.018958 → Δ +3.4%
#
# ==============================
# Instance 3 | Layers 1
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=1 ep 000 | train 0.495805 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.493269 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.490295 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.486910 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.483036 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.478475 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.473173 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.467251 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.460938 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.454537 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.448379 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.442723 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.437649 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.433083 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.428919 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.425076 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.421474 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.418018 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.414604 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.411134 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.407527 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.403748 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.399803 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.395755 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.391729 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.387851 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.384126 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.380511 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.377080 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.373968 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.371799 | LR 0.01000
# [Stage1] best train cost = 0.371799
# [Stage3] L=1 ep 000 | train MSE(win) 0.02161 | test MSE(win) 0.02064 | test MSE(series) 0.01941
# [Stage3] L=1 ep 001 | train MSE(win) 0.02195 | test MSE(win) 0.02064 | test MSE(series) 0.01941
# [Stage3] L=1 ep 002 | train MSE(win) 0.02159 | test MSE(win) 0.02064 | test MSE(series) 0.01940
# [Stage3] L=1 ep 003 | train MSE(win) 0.02151 | test MSE(win) 0.02064 | test MSE(series) 0.01940
# [Stage3] L=1 ep 004 | train MSE(win) 0.02104 | test MSE(win) 0.02064 | test MSE(series) 0.01940
# [Stage3] L=1 ep 005 | train MSE(win) 0.02182 | test MSE(win) 0.02064 | test MSE(series) 0.01940
# [Stage3] L=1 ep 006 | train MSE(win) 0.02232 | test MSE(win) 0.02063 | test MSE(series) 0.01940
# [Stage3] L=1 ep 007 | train MSE(win) 0.02129 | test MSE(win) 0.02063 | test MSE(series) 0.01940
# [Stage3] L=1 ep 008 | train MSE(win) 0.02269 | test MSE(win) 0.02063 | test MSE(series) 0.01939
# [Stage3] L=1 ep 009 | train MSE(win) 0.02141 | test MSE(win) 0.02063 | test MSE(series) 0.01939
# [Stage3] L=1 ep 010 | train MSE(win) 0.02199 | test MSE(win) 0.02063 | test MSE(series) 0.01939
# [Stage3] L=1 ep 011 | train MSE(win) 0.02124 | test MSE(win) 0.02062 | test MSE(series) 0.01939
# [Stage3] L=1 ep 012 | train MSE(win) 0.02204 | test MSE(win) 0.02062 | test MSE(series) 0.01939
# [Stage3] L=1 ep 013 | train MSE(win) 0.02191 | test MSE(win) 0.02062 | test MSE(series) 0.01938
# [Stage3] L=1 ep 014 | train MSE(win) 0.02208 | test MSE(win) 0.02062 | test MSE(series) 0.01938
# [Stage3] L=1 ep 015 | train MSE(win) 0.02159 | test MSE(win) 0.02062 | test MSE(series) 0.01938
# [Stage3] L=1 ep 016 | train MSE(win) 0.02120 | test MSE(win) 0.02061 | test MSE(series) 0.01938
# [Stage3] L=1 ep 017 | train MSE(win) 0.02159 | test MSE(win) 0.02061 | test MSE(series) 0.01937
# [Stage3] L=1 ep 018 | train MSE(win) 0.02149 | test MSE(win) 0.02061 | test MSE(series) 0.01937
# [Stage3] L=1 ep 019 | train MSE(win) 0.02259 | test MSE(win) 0.02060 | test MSE(series) 0.01937
# [Stage3] L=1 ep 020 | train MSE(win) 0.02086 | test MSE(win) 0.02060 | test MSE(series) 0.01936
# [Stage3] L=1 ep 021 | train MSE(win) 0.02231 | test MSE(win) 0.02060 | test MSE(series) 0.01936
# [Stage3] L=1 ep 022 | train MSE(win) 0.02211 | test MSE(win) 0.02059 | test MSE(series) 0.01936
# [Stage3] L=1 ep 023 | train MSE(win) 0.02155 | test MSE(win) 0.02059 | test MSE(series) 0.01935
# [Final TEST] MSE(win) 0.020590 vs noisy 0.019911 → Δ -3.4%
# [Final TEST] MSE(series) 0.019353 vs noisy 0.018958 → Δ -2.1%
#
# ==============================
# Instance 4 | Layers 1
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=1 ep 000 | train 0.494366 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.492255 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.489879 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.487264 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.484429 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.481482 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.478579 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.475796 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.473098 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.470456 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.467866 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.465323 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.462844 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.460463 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.458209 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.456097 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.454129 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.452290 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.450551 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.448877 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.447225 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.445542 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.443764 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.441815 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.439606 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.437041 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.434018 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.430449 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.426270 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.421464 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.417194 | LR 0.01000
# [Stage1] best train cost = 0.417194
# [Stage3] L=1 ep 000 | train MSE(win) 0.02545 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 001 | train MSE(win) 0.02516 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 002 | train MSE(win) 0.02534 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 003 | train MSE(win) 0.02521 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 004 | train MSE(win) 0.02543 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 005 | train MSE(win) 0.02534 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 006 | train MSE(win) 0.02527 | test MSE(win) 0.02540 | test MSE(series) 0.02435
# [Stage3] L=1 ep 007 | train MSE(win) 0.02550 | test MSE(win) 0.02540 | test MSE(series) 0.02436
# [Stage3] L=1 ep 008 | train MSE(win) 0.02513 | test MSE(win) 0.02540 | test MSE(series) 0.02436
# [Stage3] L=1 ep 009 | train MSE(win) 0.02547 | test MSE(win) 0.02540 | test MSE(series) 0.02436
# [Stage3] L=1 ep 010 | train MSE(win) 0.02540 | test MSE(win) 0.02541 | test MSE(series) 0.02436
# [Stage3] L=1 ep 011 | train MSE(win) 0.02536 | test MSE(win) 0.02541 | test MSE(series) 0.02436
# [Stage3] L=1 ep 012 | train MSE(win) 0.02528 | test MSE(win) 0.02541 | test MSE(series) 0.02436
# [Stage3] L=1 ep 013 | train MSE(win) 0.02508 | test MSE(win) 0.02541 | test MSE(series) 0.02437
# [Stage3] L=1 ep 014 | train MSE(win) 0.02509 | test MSE(win) 0.02542 | test MSE(series) 0.02437
# [Stage3] L=1 ep 015 | train MSE(win) 0.02520 | test MSE(win) 0.02542 | test MSE(series) 0.02437
# [Stage3] L=1 ep 016 | train MSE(win) 0.02564 | test MSE(win) 0.02542 | test MSE(series) 0.02437
# [Stage3] L=1 ep 017 | train MSE(win) 0.02555 | test MSE(win) 0.02542 | test MSE(series) 0.02438
# [Stage3] L=1 ep 018 | train MSE(win) 0.02555 | test MSE(win) 0.02542 | test MSE(series) 0.02438
# [Stage3] L=1 ep 019 | train MSE(win) 0.02541 | test MSE(win) 0.02543 | test MSE(series) 0.02438
# [Stage3] L=1 ep 020 | train MSE(win) 0.02559 | test MSE(win) 0.02543 | test MSE(series) 0.02438
# [Stage3] L=1 ep 021 | train MSE(win) 0.02527 | test MSE(win) 0.02543 | test MSE(series) 0.02439
# [Stage3] L=1 ep 022 | train MSE(win) 0.02519 | test MSE(win) 0.02544 | test MSE(series) 0.02439
# [Stage3] L=1 ep 023 | train MSE(win) 0.02547 | test MSE(win) 0.02544 | test MSE(series) 0.02439
# [Final TEST] MSE(win) 0.025439 vs noisy 0.019911 → Δ -27.8%
# [Final TEST] MSE(series) 0.024392 vs noisy 0.018958 → Δ -28.7%
#
# ==============================
# Instance 5 | Layers 1
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=1 ep 000 | train 0.501798 | LR 0.01000
# [Stage1] L=1 ep 005 | train 0.499648 | LR 0.01000
# [Stage1] L=1 ep 010 | train 0.497947 | LR 0.01000
# [Stage1] L=1 ep 015 | train 0.496500 | LR 0.01000
# [Stage1] L=1 ep 020 | train 0.495146 | LR 0.01000
# [Stage1] L=1 ep 025 | train 0.493817 | LR 0.01000
# [Stage1] L=1 ep 030 | train 0.492453 | LR 0.01000
# [Stage1] L=1 ep 035 | train 0.490999 | LR 0.01000
# [Stage1] L=1 ep 040 | train 0.489419 | LR 0.01000
# [Stage1] L=1 ep 045 | train 0.487676 | LR 0.01000
# [Stage1] L=1 ep 050 | train 0.485680 | LR 0.01000
# [Stage1] L=1 ep 055 | train 0.483270 | LR 0.01000
# [Stage1] L=1 ep 060 | train 0.480263 | LR 0.01000
# [Stage1] L=1 ep 065 | train 0.476534 | LR 0.01000
# [Stage1] L=1 ep 070 | train 0.472090 | LR 0.01000
# [Stage1] L=1 ep 075 | train 0.467077 | LR 0.01000
# [Stage1] L=1 ep 080 | train 0.461726 | LR 0.01000
# [Stage1] L=1 ep 085 | train 0.456305 | LR 0.01000
# [Stage1] L=1 ep 090 | train 0.451100 | LR 0.01000
# [Stage1] L=1 ep 095 | train 0.446333 | LR 0.01000
# [Stage1] L=1 ep 100 | train 0.442087 | LR 0.01000
# [Stage1] L=1 ep 105 | train 0.438323 | LR 0.01000
# [Stage1] L=1 ep 110 | train 0.434960 | LR 0.01000
# [Stage1] L=1 ep 115 | train 0.431900 | LR 0.01000
# [Stage1] L=1 ep 120 | train 0.429035 | LR 0.01000
# [Stage1] L=1 ep 125 | train 0.426267 | LR 0.01000
# [Stage1] L=1 ep 130 | train 0.423529 | LR 0.01000
# [Stage1] L=1 ep 135 | train 0.420774 | LR 0.01000
# [Stage1] L=1 ep 140 | train 0.417955 | LR 0.01000
# [Stage1] L=1 ep 145 | train 0.415011 | LR 0.01000
# [Stage1] L=1 ep 149 | train 0.412514 | LR 0.01000
# [Stage1] best train cost = 0.412514
# [Stage3] L=1 ep 000 | train MSE(win) 0.02430 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 001 | train MSE(win) 0.02406 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 002 | train MSE(win) 0.02419 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 003 | train MSE(win) 0.02371 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 004 | train MSE(win) 0.02420 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 005 | train MSE(win) 0.02430 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 006 | train MSE(win) 0.02432 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 007 | train MSE(win) 0.02434 | test MSE(win) 0.02393 | test MSE(series) 0.02316
# [Stage3] L=1 ep 008 | train MSE(win) 0.02408 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 009 | train MSE(win) 0.02390 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 010 | train MSE(win) 0.02461 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 011 | train MSE(win) 0.02395 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 012 | train MSE(win) 0.02384 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 013 | train MSE(win) 0.02401 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 014 | train MSE(win) 0.02416 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 015 | train MSE(win) 0.02409 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 016 | train MSE(win) 0.02464 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 017 | train MSE(win) 0.02393 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 018 | train MSE(win) 0.02409 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 019 | train MSE(win) 0.02382 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 020 | train MSE(win) 0.02395 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 021 | train MSE(win) 0.02466 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 022 | train MSE(win) 0.02397 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Stage3] L=1 ep 023 | train MSE(win) 0.02398 | test MSE(win) 0.02393 | test MSE(series) 0.02315
# [Final TEST] MSE(win) 0.023930 vs noisy 0.019911 → Δ -20.2%
# [Final TEST] MSE(series) 0.023153 vs noisy 0.018958 → Δ -22.1%
#
# ==============================
# Instance 1 | Layers 3
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=3 ep 000 | train 0.496667 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.475002 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.455328 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.440202 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.429559 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.420516 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.411542 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.402724 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.394364 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.386561 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.378775 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.370451 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.361450 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.351871 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.341784 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.331433 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.320839 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.309748 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.298745 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.288729 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.280063 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.272714 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.266377 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.260364 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.253911 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.246409 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.237480 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.226864 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.214447 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.200378 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.188141 | LR 0.01000
# [Stage1] best train cost = 0.188141
# [Stage3] L=3 ep 000 | train MSE(win) 0.01735 | test MSE(win) 0.01664 | test MSE(series) 0.01579
# [Stage3] L=3 ep 001 | train MSE(win) 0.01723 | test MSE(win) 0.01663 | test MSE(series) 0.01579
# [Stage3] L=3 ep 002 | train MSE(win) 0.01684 | test MSE(win) 0.01663 | test MSE(series) 0.01578
# [Stage3] L=3 ep 003 | train MSE(win) 0.01627 | test MSE(win) 0.01663 | test MSE(series) 0.01578
# [Stage3] L=3 ep 004 | train MSE(win) 0.01636 | test MSE(win) 0.01663 | test MSE(series) 0.01578
# [Stage3] L=3 ep 005 | train MSE(win) 0.01663 | test MSE(win) 0.01662 | test MSE(series) 0.01577
# [Stage3] L=3 ep 006 | train MSE(win) 0.01663 | test MSE(win) 0.01662 | test MSE(series) 0.01577
# [Stage3] L=3 ep 007 | train MSE(win) 0.01676 | test MSE(win) 0.01662 | test MSE(series) 0.01576
# [Stage3] L=3 ep 008 | train MSE(win) 0.01670 | test MSE(win) 0.01661 | test MSE(series) 0.01575
# [Stage3] L=3 ep 009 | train MSE(win) 0.01731 | test MSE(win) 0.01660 | test MSE(series) 0.01575
# [Stage3] L=3 ep 010 | train MSE(win) 0.01733 | test MSE(win) 0.01660 | test MSE(series) 0.01574
# [Stage3] L=3 ep 011 | train MSE(win) 0.01606 | test MSE(win) 0.01659 | test MSE(series) 0.01573
# [Stage3] L=3 ep 012 | train MSE(win) 0.01801 | test MSE(win) 0.01659 | test MSE(series) 0.01573
# [Stage3] L=3 ep 013 | train MSE(win) 0.01671 | test MSE(win) 0.01658 | test MSE(series) 0.01572
# [Stage3] L=3 ep 014 | train MSE(win) 0.01601 | test MSE(win) 0.01657 | test MSE(series) 0.01571
# [Stage3] L=3 ep 015 | train MSE(win) 0.01681 | test MSE(win) 0.01657 | test MSE(series) 0.01570
# [Stage3] L=3 ep 016 | train MSE(win) 0.01686 | test MSE(win) 0.01656 | test MSE(series) 0.01570
# [Stage3] L=3 ep 017 | train MSE(win) 0.01732 | test MSE(win) 0.01655 | test MSE(series) 0.01569
# [Stage3] L=3 ep 018 | train MSE(win) 0.01657 | test MSE(win) 0.01655 | test MSE(series) 0.01568
# [Stage3] L=3 ep 019 | train MSE(win) 0.01787 | test MSE(win) 0.01654 | test MSE(series) 0.01567
# [Stage3] L=3 ep 020 | train MSE(win) 0.01599 | test MSE(win) 0.01653 | test MSE(series) 0.01566
# [Stage3] L=3 ep 021 | train MSE(win) 0.01685 | test MSE(win) 0.01652 | test MSE(series) 0.01565
# [Stage3] L=3 ep 022 | train MSE(win) 0.01774 | test MSE(win) 0.01652 | test MSE(series) 0.01564
# [Stage3] L=3 ep 023 | train MSE(win) 0.01635 | test MSE(win) 0.01651 | test MSE(series) 0.01563
# [Final TEST] MSE(win) 0.016506 vs noisy 0.019911 → Δ +17.1%
# [Final TEST] MSE(series) 0.015628 vs noisy 0.018958 → Δ +17.6%
#
# ==============================
# Instance 2 | Layers 3
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=3 ep 000 | train 0.499773 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.475652 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.453616 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.434525 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.419852 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.408175 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.397878 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.388708 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.380236 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.371467 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.361847 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.351368 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.340112 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.328348 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.316602 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.305553 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.295327 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.285393 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.275262 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.265153 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.255740 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.247440 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.240176 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.233671 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.227820 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.222646 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.218067 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.213768 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.209206 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.203662 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.198070 | LR 0.01000
# [Stage1] best train cost = 0.198070
# [Stage3] L=3 ep 000 | train MSE(win) 0.01813 | test MSE(win) 0.01760 | test MSE(series) 0.01665
# [Stage3] L=3 ep 001 | train MSE(win) 0.01769 | test MSE(win) 0.01760 | test MSE(series) 0.01665
# [Stage3] L=3 ep 002 | train MSE(win) 0.01729 | test MSE(win) 0.01760 | test MSE(series) 0.01664
# [Stage3] L=3 ep 003 | train MSE(win) 0.01745 | test MSE(win) 0.01759 | test MSE(series) 0.01664
# [Stage3] L=3 ep 004 | train MSE(win) 0.01699 | test MSE(win) 0.01759 | test MSE(series) 0.01664
# [Stage3] L=3 ep 005 | train MSE(win) 0.01726 | test MSE(win) 0.01758 | test MSE(series) 0.01663
# [Stage3] L=3 ep 006 | train MSE(win) 0.01740 | test MSE(win) 0.01757 | test MSE(series) 0.01662
# [Stage3] L=3 ep 007 | train MSE(win) 0.01709 | test MSE(win) 0.01757 | test MSE(series) 0.01662
# [Stage3] L=3 ep 008 | train MSE(win) 0.01776 | test MSE(win) 0.01756 | test MSE(series) 0.01661
# [Stage3] L=3 ep 009 | train MSE(win) 0.01805 | test MSE(win) 0.01755 | test MSE(series) 0.01660
# [Stage3] L=3 ep 010 | train MSE(win) 0.01762 | test MSE(win) 0.01754 | test MSE(series) 0.01659
# [Stage3] L=3 ep 011 | train MSE(win) 0.01697 | test MSE(win) 0.01753 | test MSE(series) 0.01658
# [Stage3] L=3 ep 012 | train MSE(win) 0.01818 | test MSE(win) 0.01752 | test MSE(series) 0.01657
# [Stage3] L=3 ep 013 | train MSE(win) 0.01733 | test MSE(win) 0.01751 | test MSE(series) 0.01657
# [Stage3] L=3 ep 014 | train MSE(win) 0.01671 | test MSE(win) 0.01750 | test MSE(series) 0.01656
# [Stage3] L=3 ep 015 | train MSE(win) 0.01717 | test MSE(win) 0.01749 | test MSE(series) 0.01655
# [Stage3] L=3 ep 016 | train MSE(win) 0.01717 | test MSE(win) 0.01748 | test MSE(series) 0.01654
# [Stage3] L=3 ep 017 | train MSE(win) 0.01766 | test MSE(win) 0.01747 | test MSE(series) 0.01653
# [Stage3] L=3 ep 018 | train MSE(win) 0.01737 | test MSE(win) 0.01746 | test MSE(series) 0.01652
# [Stage3] L=3 ep 019 | train MSE(win) 0.01851 | test MSE(win) 0.01744 | test MSE(series) 0.01651
# [Stage3] L=3 ep 020 | train MSE(win) 0.01683 | test MSE(win) 0.01743 | test MSE(series) 0.01649
# [Stage3] L=3 ep 021 | train MSE(win) 0.01747 | test MSE(win) 0.01742 | test MSE(series) 0.01648
# [Stage3] L=3 ep 022 | train MSE(win) 0.01779 | test MSE(win) 0.01740 | test MSE(series) 0.01647
# [Stage3] L=3 ep 023 | train MSE(win) 0.01695 | test MSE(win) 0.01739 | test MSE(series) 0.01646
# [Final TEST] MSE(win) 0.017391 vs noisy 0.019911 → Δ +12.7%
# [Final TEST] MSE(series) 0.016460 vs noisy 0.018958 → Δ +13.2%
#
# ==============================
# Instance 3 | Layers 3
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=3 ep 000 | train 0.492078 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.462801 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.437940 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.413872 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.387493 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.361497 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.340921 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.325449 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.310893 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.295806 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.280447 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.265650 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.252604 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.241394 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.231078 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.221115 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.211369 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.201956 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.193058 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.184600 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.176485 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.168670 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.161126 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.153863 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.146927 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.140352 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.134197 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.128596 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.123737 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.119779 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.117304 | LR 0.01000
# [Stage1] best train cost = 0.117304
# [Stage3] L=3 ep 000 | train MSE(win) 0.01415 | test MSE(win) 0.01614 | test MSE(series) 0.01445
# [Stage3] L=3 ep 001 | train MSE(win) 0.01434 | test MSE(win) 0.01613 | test MSE(series) 0.01445
# [Stage3] L=3 ep 002 | train MSE(win) 0.01419 | test MSE(win) 0.01613 | test MSE(series) 0.01444
# [Stage3] L=3 ep 003 | train MSE(win) 0.01292 | test MSE(win) 0.01612 | test MSE(series) 0.01444
# [Stage3] L=3 ep 004 | train MSE(win) 0.01312 | test MSE(win) 0.01611 | test MSE(series) 0.01443
# [Stage3] L=3 ep 005 | train MSE(win) 0.01382 | test MSE(win) 0.01610 | test MSE(series) 0.01441
# [Stage3] L=3 ep 006 | train MSE(win) 0.01426 | test MSE(win) 0.01608 | test MSE(series) 0.01440
# [Stage3] L=3 ep 007 | train MSE(win) 0.01370 | test MSE(win) 0.01607 | test MSE(series) 0.01439
# [Stage3] L=3 ep 008 | train MSE(win) 0.01375 | test MSE(win) 0.01605 | test MSE(series) 0.01437
# [Stage3] L=3 ep 009 | train MSE(win) 0.01378 | test MSE(win) 0.01604 | test MSE(series) 0.01436
# [Stage3] L=3 ep 010 | train MSE(win) 0.01405 | test MSE(win) 0.01602 | test MSE(series) 0.01434
# [Stage3] L=3 ep 011 | train MSE(win) 0.01364 | test MSE(win) 0.01600 | test MSE(series) 0.01433
# [Stage3] L=3 ep 012 | train MSE(win) 0.01522 | test MSE(win) 0.01599 | test MSE(series) 0.01431
# [Stage3] L=3 ep 013 | train MSE(win) 0.01305 | test MSE(win) 0.01597 | test MSE(series) 0.01430
# [Stage3] L=3 ep 014 | train MSE(win) 0.01211 | test MSE(win) 0.01595 | test MSE(series) 0.01428
# [Stage3] L=3 ep 015 | train MSE(win) 0.01330 | test MSE(win) 0.01593 | test MSE(series) 0.01427
# [Stage3] L=3 ep 016 | train MSE(win) 0.01378 | test MSE(win) 0.01592 | test MSE(series) 0.01425
# [Stage3] L=3 ep 017 | train MSE(win) 0.01489 | test MSE(win) 0.01590 | test MSE(series) 0.01424
# [Stage3] L=3 ep 018 | train MSE(win) 0.01343 | test MSE(win) 0.01588 | test MSE(series) 0.01422
# [Stage3] L=3 ep 019 | train MSE(win) 0.01535 | test MSE(win) 0.01586 | test MSE(series) 0.01421
# [Stage3] L=3 ep 020 | train MSE(win) 0.01247 | test MSE(win) 0.01585 | test MSE(series) 0.01420
# [Stage3] L=3 ep 021 | train MSE(win) 0.01397 | test MSE(win) 0.01583 | test MSE(series) 0.01418
# [Stage3] L=3 ep 022 | train MSE(win) 0.01447 | test MSE(win) 0.01581 | test MSE(series) 0.01417
# [Stage3] L=3 ep 023 | train MSE(win) 0.01315 | test MSE(win) 0.01579 | test MSE(series) 0.01416
# [Final TEST] MSE(win) 0.015793 vs noisy 0.019911 → Δ +20.7%
# [Final TEST] MSE(series) 0.014155 vs noisy 0.018958 → Δ +25.3%
#
# ==============================
# Instance 4 | Layers 3
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=3 ep 000 | train 0.510104 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.480643 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.452415 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.425340 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.402381 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.385489 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.371820 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.358619 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.346130 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.334723 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.323628 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.312174 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.299866 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.286180 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.271033 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.254984 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.238934 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.223855 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.210399 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.198693 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.188330 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.178763 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.169630 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.160847 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.152582 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.145123 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.138693 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.133323 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.128844 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.124976 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.122119 | LR 0.01000
# [Stage1] best train cost = 0.122119
# [Stage3] L=3 ep 000 | train MSE(win) 0.01226 | test MSE(win) 0.01219 | test MSE(series) 0.01065
# [Stage3] L=3 ep 001 | train MSE(win) 0.01216 | test MSE(win) 0.01218 | test MSE(series) 0.01065
# [Stage3] L=3 ep 002 | train MSE(win) 0.01177 | test MSE(win) 0.01218 | test MSE(series) 0.01065
# [Stage3] L=3 ep 003 | train MSE(win) 0.01120 | test MSE(win) 0.01218 | test MSE(series) 0.01064
# [Stage3] L=3 ep 004 | train MSE(win) 0.00993 | test MSE(win) 0.01218 | test MSE(series) 0.01064
# [Stage3] L=3 ep 005 | train MSE(win) 0.01198 | test MSE(win) 0.01218 | test MSE(series) 0.01064
# [Stage3] L=3 ep 006 | train MSE(win) 0.01253 | test MSE(win) 0.01217 | test MSE(series) 0.01063
# [Stage3] L=3 ep 007 | train MSE(win) 0.01209 | test MSE(win) 0.01217 | test MSE(series) 0.01062
# [Stage3] L=3 ep 008 | train MSE(win) 0.01139 | test MSE(win) 0.01216 | test MSE(series) 0.01062
# [Stage3] L=3 ep 009 | train MSE(win) 0.01280 | test MSE(win) 0.01216 | test MSE(series) 0.01061
# [Stage3] L=3 ep 010 | train MSE(win) 0.01289 | test MSE(win) 0.01216 | test MSE(series) 0.01061
# [Stage3] L=3 ep 011 | train MSE(win) 0.01189 | test MSE(win) 0.01215 | test MSE(series) 0.01060
# [Stage3] L=3 ep 012 | train MSE(win) 0.01269 | test MSE(win) 0.01215 | test MSE(series) 0.01059
# [Stage3] L=3 ep 013 | train MSE(win) 0.01111 | test MSE(win) 0.01214 | test MSE(series) 0.01059
# [Stage3] L=3 ep 014 | train MSE(win) 0.01172 | test MSE(win) 0.01214 | test MSE(series) 0.01058
# [Stage3] L=3 ep 015 | train MSE(win) 0.01245 | test MSE(win) 0.01213 | test MSE(series) 0.01057
# [Stage3] L=3 ep 016 | train MSE(win) 0.01109 | test MSE(win) 0.01212 | test MSE(series) 0.01056
# [Stage3] L=3 ep 017 | train MSE(win) 0.01314 | test MSE(win) 0.01211 | test MSE(series) 0.01055
# [Stage3] L=3 ep 018 | train MSE(win) 0.01161 | test MSE(win) 0.01210 | test MSE(series) 0.01054
# [Stage3] L=3 ep 019 | train MSE(win) 0.01392 | test MSE(win) 0.01209 | test MSE(series) 0.01053
# [Stage3] L=3 ep 020 | train MSE(win) 0.01135 | test MSE(win) 0.01208 | test MSE(series) 0.01052
# [Stage3] L=3 ep 021 | train MSE(win) 0.01139 | test MSE(win) 0.01207 | test MSE(series) 0.01051
# [Stage3] L=3 ep 022 | train MSE(win) 0.01335 | test MSE(win) 0.01206 | test MSE(series) 0.01050
# [Stage3] L=3 ep 023 | train MSE(win) 0.01169 | test MSE(win) 0.01205 | test MSE(series) 0.01049
# [Final TEST] MSE(win) 0.012054 vs noisy 0.019911 → Δ +39.5%
# [Final TEST] MSE(series) 0.010495 vs noisy 0.018958 → Δ +44.6%
#
# ==============================
# Instance 5 | Layers 3
# ==============================
# [Windows] train=74, test=24 (W=6, step=2)
# [Stage1] L=3 ep 000 | train 0.483310 | LR 0.01000
# [Stage1] L=3 ep 005 | train 0.461123 | LR 0.01000
# [Stage1] L=3 ep 010 | train 0.439273 | LR 0.01000
# [Stage1] L=3 ep 015 | train 0.420826 | LR 0.01000
# [Stage1] L=3 ep 020 | train 0.405901 | LR 0.01000
# [Stage1] L=3 ep 025 | train 0.393313 | LR 0.01000
# [Stage1] L=3 ep 030 | train 0.382516 | LR 0.01000
# [Stage1] L=3 ep 035 | train 0.373252 | LR 0.01000
# [Stage1] L=3 ep 040 | train 0.365047 | LR 0.01000
# [Stage1] L=3 ep 045 | train 0.357086 | LR 0.01000
# [Stage1] L=3 ep 050 | train 0.349044 | LR 0.01000
# [Stage1] L=3 ep 055 | train 0.341101 | LR 0.01000
# [Stage1] L=3 ep 060 | train 0.332827 | LR 0.01000
# [Stage1] L=3 ep 065 | train 0.323592 | LR 0.01000
# [Stage1] L=3 ep 070 | train 0.312952 | LR 0.01000
# [Stage1] L=3 ep 075 | train 0.300617 | LR 0.01000
# [Stage1] L=3 ep 080 | train 0.286710 | LR 0.01000
# [Stage1] L=3 ep 085 | train 0.271989 | LR 0.01000
# [Stage1] L=3 ep 090 | train 0.257308 | LR 0.01000
# [Stage1] L=3 ep 095 | train 0.243044 | LR 0.01000
# [Stage1] L=3 ep 100 | train 0.229474 | LR 0.01000
# [Stage1] L=3 ep 105 | train 0.217051 | LR 0.01000
# [Stage1] L=3 ep 110 | train 0.205992 | LR 0.01000
# [Stage1] L=3 ep 115 | train 0.196316 | LR 0.01000
# [Stage1] L=3 ep 120 | train 0.188233 | LR 0.01000
# [Stage1] L=3 ep 125 | train 0.182047 | LR 0.01000
# [Stage1] L=3 ep 130 | train 0.177815 | LR 0.01000
# [Stage1] L=3 ep 135 | train 0.175214 | LR 0.01000
# [Stage1] L=3 ep 140 | train 0.173688 | LR 0.01000
# [Stage1] L=3 ep 145 | train 0.172728 | LR 0.01000
# [Stage1] L=3 ep 149 | train 0.172143 | LR 0.01000
# [Stage1] best train cost = 0.172143
# [Stage3] L=3 ep 000 | train MSE(win) 0.01751 | test MSE(win) 0.01775 | test MSE(series) 0.01489
# [Stage3] L=3 ep 001 | train MSE(win) 0.01800 | test MSE(win) 0.01774 | test MSE(series) 0.01489
# [Stage3] L=3 ep 002 | train MSE(win) 0.01741 | test MSE(win) 0.01774 | test MSE(series) 0.01489
# [Stage3] L=3 ep 003 | train MSE(win) 0.01713 | test MSE(win) 0.01774 | test MSE(series) 0.01488
# [Stage3] L=3 ep 004 | train MSE(win) 0.01646 | test MSE(win) 0.01774 | test MSE(series) 0.01488
# [Stage3] L=3 ep 005 | train MSE(win) 0.01830 | test MSE(win) 0.01773 | test MSE(series) 0.01488
# [Stage3] L=3 ep 006 | train MSE(win) 0.01795 | test MSE(win) 0.01773 | test MSE(series) 0.01487
# [Stage3] L=3 ep 007 | train MSE(win) 0.01771 | test MSE(win) 0.01772 | test MSE(series) 0.01487
# [Stage3] L=3 ep 008 | train MSE(win) 0.01716 | test MSE(win) 0.01772 | test MSE(series) 0.01486
# [Stage3] L=3 ep 009 | train MSE(win) 0.01768 | test MSE(win) 0.01771 | test MSE(series) 0.01485
# [Stage3] L=3 ep 010 | train MSE(win) 0.01799 | test MSE(win) 0.01771 | test MSE(series) 0.01485
# [Stage3] L=3 ep 011 | train MSE(win) 0.01736 | test MSE(win) 0.01770 | test MSE(series) 0.01484
# [Stage3] L=3 ep 012 | train MSE(win) 0.01777 | test MSE(win) 0.01769 | test MSE(series) 0.01484
# [Stage3] L=3 ep 013 | train MSE(win) 0.01716 | test MSE(win) 0.01769 | test MSE(series) 0.01483
# [Stage3] L=3 ep 014 | train MSE(win) 0.01749 | test MSE(win) 0.01768 | test MSE(series) 0.01482
# [Stage3] L=3 ep 015 | train MSE(win) 0.01812 | test MSE(win) 0.01768 | test MSE(series) 0.01482
# [Stage3] L=3 ep 016 | train MSE(win) 0.01783 | test MSE(win) 0.01767 | test MSE(series) 0.01481
# [Stage3] L=3 ep 017 | train MSE(win) 0.01823 | test MSE(win) 0.01767 | test MSE(series) 0.01480
# [Stage3] L=3 ep 018 | train MSE(win) 0.01736 | test MSE(win) 0.01766 | test MSE(series) 0.01480
# [Stage3] L=3 ep 019 | train MSE(win) 0.01888 | test MSE(win) 0.01765 | test MSE(series) 0.01479
# [Stage3] L=3 ep 020 | train MSE(win) 0.01727 | test MSE(win) 0.01764 | test MSE(series) 0.01478
# [Stage3] L=3 ep 021 | train MSE(win) 0.01733 | test MSE(win) 0.01763 | test MSE(series) 0.01478
# [Stage3] L=3 ep 022 | train MSE(win) 0.01847 | test MSE(win) 0.01762 | test MSE(series) 0.01477
# [Stage3] L=3 ep 023 | train MSE(win) 0.01790 | test MSE(win) 0.01761 | test MSE(series) 0.01476
# [Final TEST] MSE(win) 0.017615 vs noisy 0.019911 → Δ +11.5%
# [Final TEST] MSE(series) 0.014763 vs noisy 0.018958 → Δ +22.1%
#
# Completed 10 runs.

# %%
# ===============================
# Cell 9 — final plots & stats for all instances
# ===============================
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

ARCH_TAG = f"{n_qubits}q_{n_latent}l_{n_trash}t"
SAVE_PLOTS = True  # set False if you don't want PNGs on disk

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _seed_for_run(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3:
        return int(s3["TEST_SEED_FIXED"])
    hist = s3.get("hist_train", [])
    return 88_000 + 100*instance_id + (len(hist) - 1 if len(hist) else 0)

def plot_one(run, save_dir=None, title_note=""):
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    seed = _seed_for_run(run, inst)

    denoise = stage3_qnodes(L, phi, reset_mode=RESET_MODE)["denoiser_qnode_all"]
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed)
    tr_rec = denoise_windows(psi, denoise, tr_n)
    te_rec = denoise_windows(psi, denoise, te_n)

    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_rec);te_hat  = _flatten_avg(te_rec)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    x_tr = np.arange(len(tr_pure)); x_te = np.arange(len(tr_pure), len(tr_pure)+len(te_pure))
    x_split = len(tr_pure)

    plt.figure(figsize=(12, 6))
    plt.scatter(x_tr, tr_noi, s=10, alpha=0.55, label=f"Train Noise (MSE={mse_tr_noise:0.5f})")
    plt.scatter(x_te, te_noi, s=10, alpha=0.55, label=f"Test  Noise (MSE={mse_te_noise:0.5f})")
    plt.plot(x_tr, tr_pure, linewidth=1.8, label="Train Pure")
    plt.plot(x_te, te_pure, linewidth=1.8, label="Test Pure")
    plt.plot(x_tr, tr_hat, linestyle="--", linewidth=2.0, label=f"Train Recovered (MSE={mse_tr_hat:0.5f})")
    plt.plot(x_te, te_hat, linestyle="--", linewidth=2.0, label=f"Test  Recovered (MSE={mse_te_hat:0.5f})")
    plt.axvline(x_split, color="grey", linestyle="--", alpha=0.7)
    plt.ylim(scale_low - 0.05*(scale_high - scale_low), scale_high + 0.05*(scale_high - scale_low))
    plt.xlabel(f'Range (samples={len(y)}, window size={wind_size}, step={wind_step})')
    plt.title(f'Pure vs Recovered (data=\"{DATA_ID}\", σ={EVAL_SIGMA:.3f}, '
              f'W={wind_size}, step={wind_step}, L={L}, inst={inst}) {title_note}')
    plt.legend(loc="upper center", ncol=3, frameon=False)
    plt.tight_layout()

    if SAVE_PLOTS and save_dir:
        Path(save_dir).mkdir(parents=True, exist_ok=True)
        out_png = Path(save_dir) / f"plot_{ARCH_TAG}_L{L}_inst{inst:02d}.png"
        plt.savefig(out_png, dpi=200, bbox_inches="tight", pad_inches=0.08)
        print(f"Saved plot → {out_png}")
    plt.show()

    dtr = 100*(1 - mse_tr_hat/max(mse_tr_noise,1e-12))
    dte = 100*(1 - mse_te_hat/max(mse_te_noise,1e-12))
    print(f"[Series-avg] TRAIN: noise={mse_tr_noise:0.8f}  recovered={mse_tr_hat:0.8f}  Δ={dtr:+.1f}%")
    print(f"[Series-avg] TEST : noise={mse_te_noise:0.8f}  recovered={mse_te_hat:0.8f}  Δ={dte:+.1f}%")

# -- Run plots for every trained (instance, L)
for L in LAYER_OPTIONS:
    for inst in INSTANCE_IDS:
        if any(r["n_layers"] == L and r["instance_id"] == inst for r in ALL_RUNS):
            run = next(r for r in ALL_RUNS if r["n_layers"] == L and r["instance_id"] == inst)
            print(f"\n=== Final plot for L={L}, inst={inst} ===")
            plot_one(run, save_dir=f"{FIGURES_PATH}/final2/{ARCH_TAG}/L{L}")
# Out:
# === Final plot for L=1, inst=1 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L1/plot_6q_4l_2t_L1_inst01.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.02337164  Δ=-22.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02319927  Δ=-22.4%
#
# === Final plot for L=1, inst=2 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L1/plot_6q_4l_2t_L1_inst02.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.02060682  Δ=-8.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01831164  Δ=+3.4%
#
# === Final plot for L=1, inst=3 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L1/plot_6q_4l_2t_L1_inst03.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.02106488  Δ=-10.5%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01935328  Δ=-2.1%
#
# === Final plot for L=1, inst=4 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L1/plot_6q_4l_2t_L1_inst04.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.02489230  Δ=-30.6%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02439225  Δ=-28.7%
#
# === Final plot for L=1, inst=5 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L1/plot_6q_4l_2t_L1_inst05.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.02368915  Δ=-24.2%
# [Series-avg] TEST : noise=0.01895794  recovered=0.02315310  Δ=-22.1%
#
# === Final plot for L=3, inst=1 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L3/plot_6q_4l_2t_L3_inst01.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.01729634  Δ=+9.3%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01562786  Δ=+17.6%
#
# === Final plot for L=3, inst=2 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L3/plot_6q_4l_2t_L3_inst02.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.01837095  Δ=+3.7%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01646048  Δ=+13.2%
#
# === Final plot for L=3, inst=3 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L3/plot_6q_4l_2t_L3_inst03.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.01416702  Δ=+25.7%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01415514  Δ=+25.3%
#
# === Final plot for L=3, inst=4 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L3/plot_6q_4l_2t_L3_inst04.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.01217703  Δ=+36.1%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01049495  Δ=+44.6%
#
# === Final plot for L=3, inst=5 ===
# Saved plot → aintern/figures/final2/6q_4l_2t/L3/plot_6q_4l_2t_L3_inst05.png
# [Series-avg] TRAIN: noise=0.01906716  recovered=0.01612848  Δ=+15.4%
# [Series-avg] TEST : noise=0.01895794  recovered=0.01476298  Δ=+22.1%

# %%
# ===============================
# Cell A — Circuit renderer (ψ + SWAP-reset + adjoint(φ))
# ===============================
from pathlib import Path
import matplotlib.pyplot as plt
import pennylane as qml
from pennylane import numpy as pnp

def render_and_save_circuit(
    L, phi_vec, psi_vec, save_dir, inst,
    style="pennylane", level="device", fname_prefix="circuit"
):
    """
    Draw the denoiser circuit exactly as used in Stage-3:
      1) embed_input(x)
      2) encoder with ψ
      3) SWAP-reset of the trash qubits using |0> ancillas
      4) adjoint(encoder) with fixed φ
      5) Z measurements (on the main data wires only)

    Notes:
    - Device wires: [0, 1, ..., n_qubits-1, 'anc0', 'anc1', ...]
    - SWAPs occur between trash wires (n_latent ... n_qubits-1) and the ancillas.
    """
    # --- wires: main data wires + ancillas for reset ---
    main_wires = list(range(n_qubits))
    anc_wires  = [f"anc{k}" for k in range(n_trash)]  # pretty labels
    dev_wires  = main_wires + anc_wires

    dev = qml.device("default.qubit", wires=dev_wires, shots=None)

    # freeze φ & ψ for drawing
    theta_fixed = pnp.array(phi_vec, requires_grad=False).reshape((L, n_qubits, 3))
    psi_flat    = pnp.array(psi_vec, requires_grad=False)

    # ----- Encoder body used in Stage-1/3 (matches your training template) -----
    def encoder_body(theta):
        # theta shape: (L, n_qubits, 3) for RX/RY/RZ on each qubit per layer
        for l in range(L):
            # single-qubit rotations
            for q in range(n_qubits):
                qml.RX(theta[l, q, 0], wires=main_wires[q])
                qml.RY(theta[l, q, 1], wires=main_wires[q])
                qml.RZ(theta[l, q, 2], wires=main_wires[q])
            # ring CNOT entanglers across data wires
            for q in range(n_qubits - 1):
                qml.CNOT(wires=[main_wires[q], main_wires[q + 1]])
            qml.CNOT(wires=[main_wires[-1], main_wires[0]])

    # fixed decoder = adjoint(φ)
    def decoder_fixed():
        qml.adjoint(encoder_body)(theta_fixed)

    # --- explicit SWAP-reset (trash -> ancilla, main trash becomes |0>)
    def swap_reset_trash_to_ancilla():
        for k in range(n_trash):
            t_wire = main_wires[n_latent + k]  # trash wire in main register
            a_wire = anc_wires[k]              # corresponding ancilla at |0>
            qml.SWAP(wires=[t_wire, a_wire])

    # --- QNode for drawing (deterministic dummy input) ---
    @qml.qnode(dev)
    def denoiser_for_draw(x_in):
        # 1) input embedding on main wires (same function you use in training)
        embed_input(x_in)

        # 2) encoder with learned ψ (reuse your training helper if you prefer)
        #    If your 'encoder_template' writes to the current device wires,
        #    it will act on main_wires because those are numbered 0..n_qubits-1.
        encoder_template(psi_flat, L)

        # 3) SWAP-reset of trash qubits into ancillas
        if n_trash > 0:
            swap_reset_trash_to_ancilla()

        # 4) fixed decoder = adjoint(φ)
        decoder_fixed()

        # 5) measure main data wires (not the ancillas)
        return [qml.expval(qml.PauliZ(w)) for w in main_wires]

    # ---- render & save ----
    x_dummy = pnp.zeros(wind_size, dtype=float)  # just to build the tape
    qml.drawer.use_style(style)
    fig, ax = qml.draw_mpl(denoiser_for_draw, decimals=2, level=level)(x_dummy)

    save_dir = Path(save_dir); save_dir.mkdir(parents=True, exist_ok=True)
    out_png = save_dir / f"{fname_prefix}_L{L}_inst{int(inst):02d}.png"
    fig.savefig(out_png, dpi=220, bbox_inches="tight", pad_inches=0.1)
    plt.close(fig)
    return out_png

# %%
# ===============================
# Cell B — Save φ/ψ + circuit PNGs + CSVs
# ===============================
import json, csv, time, os
from pathlib import Path
import numpy as np
import pandas as pd

# --- helpers (local, robust) ---
def ensure_dir(p: str | Path) -> Path:
    p = Path(p); p.mkdir(parents=True, exist_ok=True); return p

def arch_tag():
    # e.g. "4q_3l_1t"
    return f"{n_qubits}q_{n_latent}l_{n_trash}t"

def inst_fname(L, inst):
    return f"inst{int(inst):02d}_L{int(L)}"

def _windows_from_seed(y_vec, sigma, seed):
    y_noisy = ts_add_noise(
        y_vec, noise=sigma, noise_type='normal', clip=False,
        range_low=scale_low, range_high=scale_high, seed=seed
    )
    win_clean = ts_wind_make(y_vec,   wind_size, wind_step)
    win_noisy = ts_wind_make(y_noisy, wind_size, wind_step)
    X_ts = np.array([i*wind_step for i in range(len(win_clean))])
    _, tr_clean, _, te_clean = ts_wind_split(X_ts, win_clean, split)
    _, tr_noisy, _, te_noisy = ts_wind_split(X_ts, win_noisy, split)
    return tr_clean, tr_noisy, te_clean, te_noisy

def _flatten_avg(windows):
    return ts_wind_flatten_avg(np.asarray(windows), wind_step)

def _mse(a, b):
    a = np.asarray(a); b = np.asarray(b)
    return float(np.mean((a - b) ** 2))

def _choose_eval_seed(run, instance_id):
    s3 = run["stage3"]
    if "TEST_SEED_FIXED" in s3 and s3["TEST_SEED_FIXED"] is not None:
        return int(s3["TEST_SEED_FIXED"])
    # fallback to "last-epoch" convention
    eplen = len(s3.get("hist_train", []))
    return 88_000 + 100*instance_id + max(eplen - 1, 0)

# Respect global choices if set elsewhere
DEV_NAME   = globals().get("DEV_NAME", "default.qubit")
RESET_MODE = globals().get("RESET_MODE", "swap")   # "swap" (unitary) or "measure"

# --- roots ---
ROOT = ensure_dir("qae_runs")
DATA_ROOT = ensure_dir(ROOT / DATA_ID)
ARCH_ROOT = ensure_dir(DATA_ROOT / arch_tag())

# per-layer dirs
dir_L = {L: ensure_dir(ARCH_ROOT / f"L{int(L)}") for L in set(LAYER_OPTIONS)}

# CSV paths (within arch folder)
CSV_RUNS   = ARCH_ROOT / "metrics_by_run.csv"
CSV_SUMMARY= ARCH_ROOT / "summary_by_layer.csv"

# create/ensure CSV headers
RUNS_HEADER = [
    "dataset","arch","instance_id","layer",
    "window_size","step","sigma_eval",
    "mse_train_noise","mse_train_recovered","delta_train_pct",
    "mse_test_noise","mse_test_recovered","delta_test_pct",
    "s1_best_train_cost","timestamp","bundle_json"
]
if not CSV_RUNS.exists():
    with open(CSV_RUNS, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow(RUNS_HEADER)

# ---- iterate runs and save artifacts ----
rows = []
for run in ALL_RUNS:
    inst = int(run["instance_id"])
    L    = int(run["n_layers"])
    phi  = np.array(run["stage1"]["phi"])
    psi  = np.array(run["stage3"]["psi"])

    # --- params to .npy ---
    np.save(dir_L[L] / f"phi_{inst_fname(L, inst)}.npy", phi)
    np.save(dir_L[L] / f"psi_{inst_fname(L, inst)}.npy", psi)

    # --- evaluate metrics on the run's fixed test seed (or fallback) ---
    seed_eval = _choose_eval_seed(run, inst)
    tr_c, tr_n, te_c, te_n = _windows_from_seed(y, EVAL_SIGMA, seed_eval)

    # Use the same reset mode as training (ensures denoiser matches what was trained)
    handles  = stage3_qnodes(L, phi, reset_mode=RESET_MODE)
    denoiser = handles["denoiser_qnode_all"]

    tr_hat_w = denoise_windows(psi, denoiser, tr_n)
    te_hat_w = denoise_windows(psi, denoiser, te_n)

    # series-level (flattened) MSEs
    tr_pure = _flatten_avg(tr_c);  te_pure = _flatten_avg(te_c)
    tr_noi  = _flatten_avg(tr_n);  te_noi  = _flatten_avg(te_n)
    tr_hat  = _flatten_avg(tr_hat_w); te_hat = _flatten_avg(te_hat_w)

    mse_tr_noise = _mse(tr_pure, tr_noi)
    mse_te_noise = _mse(te_pure, te_noi)
    mse_tr_hat   = _mse(tr_pure, tr_hat)
    mse_te_hat   = _mse(te_pure, te_hat)

    d_tr = 100.0 * (1.0 - mse_tr_hat / max(mse_tr_noise, 1e-12))
    d_te = 100.0 * (1.0 - mse_te_hat / max(mse_te_noise, 1e-12))

    # --- save circuit PNG (in arch folder, NOT inside Lx) ---
    png_path = render_and_save_circuit(L, phi, psi, save_dir=ARCH_ROOT, inst=inst,
                                       style="pennylane", level="device",
                                       fname_prefix="circuit")

    # --- compact JSON bundle (path saved in CSV for traceability) ---
    bundle = {
        "schema": {"name": "half_qae_bundle", "version": "1.0"},
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "dataset": {
            "id": DATA_ID,
            "scale_low":  float(scale_low),
            "scale_high": float(scale_high),
            "window_size": int(wind_size),
            "window_step": int(wind_step),
            "split": float(split),
        },
        "run": {
            "instance_id": inst,
            "layer": L,
            "sigma_eval": float(EVAL_SIGMA),
            "test_seed_fixed": int(run["stage3"].get("TEST_SEED_FIXED", seed_eval)),
        },
        "environment": {
            "device": DEV_NAME,
            "reset_mode": RESET_MODE,
        },
        "architecture": {
            "n_qubits": int(n_qubits),
            "n_latent": int(n_latent),
            "n_trash":  int(n_trash),
        },
        "parameters": {
            "phi": phi.tolist(),
            "psi": psi.tolist(),
        },
        "metrics_series": {
            "mse_train_noise": mse_tr_noise,
            "mse_train_recovered": mse_tr_hat,
            "delta_train_pct": d_tr,
            "mse_test_noise": mse_te_noise,
            "mse_test_recovered": mse_te_hat,
            "delta_test_pct": d_te,
        }
    }
    bundle_path = dir_L[L] / f"bundle_{inst_fname(L, inst)}.json"
    with open(bundle_path, "w", encoding="utf-8") as f:
        json.dump(bundle, f, indent=2)

    # --- row for runs CSV ---
    rows.append([
        DATA_ID, arch_tag(), inst, L,
        int(wind_size), int(wind_step), float(EVAL_SIGMA),
        mse_tr_noise, mse_tr_hat, d_tr,
        mse_te_noise, mse_te_hat, d_te,
        float(run["stage1"].get("best_train", np.nan)),
        bundle["timestamp"],
        str(bundle_path)
    ])

# upsert rows into metrics_by_run.csv (deduplicate by instance_id+layer)
if rows:
    df_new = pd.DataFrame(rows, columns=RUNS_HEADER)
    if CSV_RUNS.exists():
        df_old = pd.read_csv(CSV_RUNS)
        key_cols = ["dataset","arch","instance_id","layer"]
        df_old = df_old.drop_duplicates(subset=key_cols, keep="last")
        df_new = pd.concat([df_old, df_new], ignore_index=True)
        df_new = df_new.drop_duplicates(subset=key_cols, keep="last")
    df_new.to_csv(CSV_RUNS, index=False)
    print(f"Updated per-run metrics → {CSV_RUNS}")

# # build a tiny per-layer summary
if Path(CSV_RUNS).exists():
    df = pd.read_csv(CSV_RUNS)
    summary = (df
        .groupby("layer", as_index=True)
        .agg(
            runs=("instance_id","count"),
            mse_test_noise_mean=("mse_test_noise","mean"),
            mse_test_recovered_mean=("mse_test_recovered","mean"),
            delta_test_pct_mean=("delta_test_pct","mean"),
        )
    )
    summary.to_csv(CSV_SUMMARY)
    print(f"Saved per-layer summary → {CSV_SUMMARY}")

print(f"Artifacts saved under → {ARCH_ROOT}")
# Out:
# Updated per-run metrics → qae_runs/mackey_glass_tau30_n200/6q_4l_2t/metrics_by_run.csv
# Saved per-layer summary → qae_runs/mackey_glass_tau30_n200/6q_4l_2t/summary_by_layer.csv
# Artifacts saved under → qae_runs/mackey_glass_tau30_n200/6q_4l_2t
